# %% [markdown]
# # 6-3. Hybrid RAG (Advanced) - 재난대응 시스템 (로컬 모델)
#
# Graph RAG와 Vector RAG를 결합한 하이브리드 검색 시스템입니다.
# - **Graph RAG**: Neo4j 그래프 데이터베이스에서 구조화된 정보 검색
# - **Vector RAG**: Chroma 벡터 DB에서 문서 검색
# - **Ollama 로컬 모델**: Qwen3:4B를 사용한 자연어 생성
#
# 레퍼런스: [gptsquare_ontology_study_rag_vs_graphrag](https://github.com/faeqsu10/gptsquare_ontology_study_rag_vs_graphrag)
#
# **사전 준비사항:**
# 1. Ollama 설치: `curl https://ollama.ai/install.sh | sh`
# 2. Qwen3:4B 모델 다운로드: `ollama pull qwen3:4b`

# %%
# 필요한 라이브러리 import
import os
from typing import List, Dict, Optional
from dotenv import load_dotenv 
import pandas as pd
import warnings
import requests
import json
warnings.filterwarnings('ignore')

# Neo4j
from neo4j import GraphDatabase

# Chroma
import chromadb
from chromadb.config import Settings

load_dotenv()
print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %% [markdown]
# ## 1. 데이터베이스 연결 설정

# %%
# Neo4j 연결 설정
NEO4J_URI = os.getenv("NEO4J_URI", "bolt://localhost:7687")
NEO4J_USER = os.getenv("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "password")

neo4j_driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

def get_neo4j_session():
    return neo4j_driver.session()

# Neo4j 연결 확인
try:
    with get_neo4j_session() as session:
        result = session.run("RETURN 1 as test")
        print(f"✓ Neo4j 연결 성공: {NEO4J_URI}")
except Exception as e:
    print(f"✗ Neo4j 연결 실패: {e}")
# Out:
# ✓ Neo4j 연결 성공: bolt://localhost:7687

# %%
# Chroma 벡터 DB 연결
CHROMA_PERSIST_DIR = "data/chroma"
DOCS_DIR = "docs"

chroma_client = chromadb.PersistentClient(
    path=CHROMA_PERSIST_DIR,
    settings=Settings(anonymized_telemetry=False)
)

# 컬렉션 가져오기 또는 생성
try:
    chroma_collection = chroma_client.get_collection("disaster_docs")
    print(f"✓ Chroma 컬렉션 로드 성공: {chroma_collection.count()} 문서")
except Exception as e:
    print(f"✗ Chroma 컬렉션 로드 실패: {e}")
    print("새 컬렉션 생성 및 문서 적재 중...")
    
    # 새 컬렉션 생성
    chroma_collection = chroma_client.create_collection(
        name="disaster_docs",
        metadata={"description": "재난 행동요령 문서"}
    )
    
    # docs 폴더의 마크다운 파일 읽기 및 적재
    import glob
    
    doc_files = glob.glob(f"{DOCS_DIR}/*.md")
    print(f"\n찾은 문서 파일: {len(doc_files)}개")
    
    documents = []
    ids = []
    metadatas = []
    
    for doc_file in doc_files:
        try:
            with open(doc_file, 'r', encoding='utf-8') as f:
                content = f.read()
            
            filename = os.path.basename(doc_file)
            doc_id = filename.replace('.md', '')
            
            documents.append(content)
            ids.append(doc_id)
            metadatas.append({"source": filename, "type": "disaster_guide"})
            
            print(f"  ✓ {filename} 적재 완료 ({len(content)}자)")
        except Exception as e:
            print(f"  ✗ {doc_file} 적재 실패: {e}")
    
    # Chroma에 문서 추가
    if documents:
        chroma_collection.add(
            documents=documents,
            ids=ids,
            metadatas=metadatas
        )
        print(f"\n✓ 총 {len(documents)}개 문서를 Chroma에 적재했습니다.")
    else:
        print("\n✗ 적재할 문서가 없습니다.")
# Out:
# ✓ Chroma 컬렉션 로드 성공: 16 문서

# %% [markdown]
# ## 1-1. Neo4j 데이터 적재 (필요시)

# %%
# Neo4j 데이터 적재 함수 (배치 처리로 성능 향상)
def load_neo4j_data(nodes_csv: str, relationships_csv: str, session):
    """CSV 파일에서 Neo4j로 데이터를 적재합니다."""
    
    # 기존 데이터 삭제
    session.run("MATCH (n) DETACH DELETE n")
    print("✓ 기존 데이터 삭제 완료")
    
    # 노드 CSV 읽기
    nodes_df = pd.read_csv(nodes_csv, encoding='utf-8-sig')
    print(f"\n노드 CSV 로드: {len(nodes_df)}개")
    
    # 노드 타입별로 배치 적재
    node_types = nodes_df['type'].unique()
    
    for node_type in node_types:
        type_nodes = nodes_df[nodes_df['type'] == node_type]
        print(f"\n{node_type} 노드 적재 중... ({len(type_nodes)}개)")
        
        # 배치 크기 설정
        batch_size = 100
        
        for batch_start in range(0, len(type_nodes), batch_size):
            batch_end = min(batch_start + batch_size, len(type_nodes))
            batch = type_nodes.iloc[batch_start:batch_end]
            
            # 배치별 쿼리 생성
            queries = []
            for _, row in batch.iterrows():
                props = {}
                for col in type_nodes.columns:
                    if col not in ['id', 'type'] and pd.notna(row[col]):
                        value = row[col]
                        # 숫자 변환 시도
                        try:
                            if isinstance(value, (int, float)) or (isinstance(value, str) and value.replace('.', '').replace('-', '').isdigit()):
                                value = float(value) if '.' in str(value) else int(float(value))
                        except:
                            pass
                        props[col] = value
                
                # CREATE 쿼리 작성
                prop_strs = [f"{k}: ${k}" for k in props.keys()]
                create_props = ", ".join(["id: $id"] + prop_strs)
                query = f"CREATE (n:{node_type} {{{create_props}}})"
                params = {"id": row['id'], **props}
                queries.append((query, params))
            
            # 배치 실행
            for query, params in queries:
                try:
                    session.run(query, **params)
                except Exception as e:
                    print(f"  ⚠ 오류: {params.get('id')} - {e}")
            
            if (batch_start // batch_size + 1) % 10 == 0:
                print(f"  진행 중: {batch_end}/{len(type_nodes)} ({batch_end*100//len(type_nodes)}%)")
        
        print(f"  ✓ {node_type} 노드 적재 완료")
    
    # 관계 CSV 읽기 및 배치 적재
    relationships_df = pd.read_csv(relationships_csv, encoding='utf-8-sig')
    print(f"\n관계 CSV 로드: {len(relationships_df)}개")
    
    batch_size = 500
    for batch_start in range(0, len(relationships_df), batch_size):
        batch_end = min(batch_start + batch_size, len(relationships_df))
        batch = relationships_df.iloc[batch_start:batch_end]
        
        for _, rel in batch.iterrows():
            query = f"""
            MATCH (from:{rel['from_type']} {{id: $from_id}})
            MATCH (to:{rel['to_type']} {{id: $to_id}})
            MERGE (from)-[:{rel['relationship_type']}]->(to)
            """
            try:
                session.run(query, from_id=rel['from_id'], to_id=rel['to_id'])
            except Exception as e:
                print(f"  ⚠ 관계 오류: {rel['from_id']} -> {rel['to_id']} - {e}")
        
        if (batch_start // batch_size + 1) % 5 == 0:
            print(f"  진행 중: {batch_end}/{len(relationships_df)} ({batch_end*100//len(relationships_df)}%)")
    
    print(f"  ✓ 관계 적재 완료: {len(relationships_df)}개")
    
    # 최종 통계
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    print(f"\n✓ Neo4j 데이터 적재 완료: 노드 {node_count}개, 관계 {rel_count}개")

# 데이터 상태 확인 및 적재
with get_neo4j_session() as session:
    # 현재 상태 확인
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    
    # 예상 데이터 개수 (CSV 확인)
    NODES_CSV = "data/processed/neo4j_nodes.csv"
    REL_CSV = "data/processed/neo4j_relationships.csv"
    
    expected_nodes = 0
    expected_rels = 0
    
    if os.path.exists(NODES_CSV):
        nodes_df = pd.read_csv(NODES_CSV, encoding='utf-8-sig')
        expected_nodes = len(nodes_df)
    
    if os.path.exists(REL_CSV):
        rels_df = pd.read_csv(REL_CSV, encoding='utf-8-sig')
        expected_rels = len(rels_df)
    
    print(f"\n{'='*60}")
    print("Neo4j 데이터 상태 확인")
    print(f"{'='*60}")
    print(f"현재 노드: {node_count}개 (예상: {expected_nodes}개)")
    print(f"현재 관계: {rel_count}개 (예상: {expected_rels}개)")
    
    # 데이터가 없거나 불완전한 경우 적재
    if node_count == 0 or node_count < expected_nodes * 0.9:  # 90% 미만이면 재적재
        if node_count > 0:
            print(f"\n⚠ 데이터가 불완전합니다. 재적재를 진행합니다...")
        else:
            print(f"\n데이터 적재 시작...")
        
        if os.path.exists(NODES_CSV) and os.path.exists(REL_CSV):
            load_neo4j_data(NODES_CSV, REL_CSV, session)
        else:
            print(f"\n✗ CSV 파일을 찾을 수 없습니다:")
            print(f"  - {NODES_CSV}")
            print(f"  - {REL_CSV}")
            print("  먼저 3_preprocessing.ipynb를 실행하여 데이터를 생성하세요.")
    else:
        print(f"\n✓ Neo4j 데이터가 정상적으로 적재되어 있습니다.")
        
        # 노드 타입별 통계
        print("\n노드 타입별 통계:")
        for label in session.run("CALL db.labels()").values():
            label_name = label[0]
            count = session.run(f"MATCH (n:{label_name}) RETURN count(n) as count").single()["count"]
            print(f"  - {label_name}: {count}개")
        
        # 관계 통계 확인
        print("\n관계 통계:")
        rel_stats = session.run("""
        MATCH ()-[r]->()
        RETURN type(r) as rel_type, count(r) as count
        ORDER BY count DESC
        """).data()
        for stat in rel_stats:
            print(f"  - {stat['rel_type']}: {stat['count']}개")
        
        # 예시: 강남구 관계 확인 (IN 관계)
        print("\n강남구 관계 확인 (예시):")
        gangnam_test = session.run("""
        MATCH (s:Shelter)-[r:IN]->(a:Admin {gu: '강남구'})
        RETURN count(s) as shelter_count
        """).single()
        if gangnam_test:
            print(f"  - 강남구 Shelter 노드 수 (IN 관계): {gangnam_test['shelter_count']}개")
        else:
            print("  - 강남구 관계를 찾을 수 없습니다.")
# Out:
# ============================================================
# Neo4j 데이터 상태 확인
# ============================================================
# 현재 노드: 0개 (예상: 3982개)
# 현재 관계: 0개 (예상: 3957개)
#
# 데이터 적재 시작...
# ✓ 기존 데이터 삭제 완료
#
# 노드 CSV 로드: 3982개
#
# Shelter 노드 적재 중... (3136개)
#   진행 중: 1000/3136 (31%)
#   진행 중: 2000/3136 (63%)
#   진행 중: 3000/3136 (95%)
#   ✓ Shelter 노드 적재 완료
#
# TemporaryHousing 노드 적재 중... (821개)
#   ✓ TemporaryHousing 노드 적재 완료
#
# Admin 노드 적재 중... (25개)
#   ✓ Admin 노드 적재 완료
#
# 관계 CSV 로드: 3957개
#   진행 중: 2500/3957 (63%)
#   ✓ 관계 적재 완료: 3957개
#
# ✓ Neo4j 데이터 적재 완료: 노드 3982개, 관계 6797개

# %%
# Ollama 설정
OLLAMA_BASE_URL = os.getenv("OLLAMA_BASE_URL", "http://localhost:11434")
OLLAMA_MODEL = "gemma3:4b"

def ollama_generate(prompt: str, model: str = OLLAMA_MODEL) -> str:
    """Ollama를 사용하여 텍스트를 생성합니다."""
    url = f"{OLLAMA_BASE_URL}/api/generate"
    
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }
    
    try:
        response = requests.post(url, json=payload, timeout=120)
        response.raise_for_status()
        result = response.json()
        answer = result.get("response", "").strip()
        # 응답이 비어있으면 None 반환
        if not answer:
            print("⚠ Ollama 응답이 비어있습니다.")
            return None
        # 디버깅을 위해 응답 일부만 출력 (너무 길면 자르기)
        if len(answer) > 200:
            print(f"✓ Ollama 응답 생성: {answer[:200]}...")
        else:
            print(f"✓ Ollama 응답 생성: {answer}")
        return answer
    except requests.exceptions.RequestException as e:
        print(f"✗ Ollama API 호출 오류: {e}")
        return None

# Ollama 연결 확인
try:
    test_response = ollama_generate("안녕하세요")
    if test_response:
        print(f"✓ Ollama 연결 성공: {OLLAMA_BASE_URL}")
        print(f"✓ 모델: {OLLAMA_MODEL}")
        print(f"  테스트 응답: {test_response[:50]}...")
    else:
        print(f"✗ Ollama 연결 실패: 응답이 없습니다.")
except Exception as e:
    print(f"✗ Ollama 연결 실패: {e}")
    print(f"  Ollama가 실행 중인지 확인하세요: ollama serve")
    print(f"  모델이 설치되어 있는지 확인하세요: ollama list")
# Out:
# ✓ Ollama 응답 생성: 안녕하세요! 무엇을 도와드릴까요? 궁금한 점이 있거나, 필요한 정보가 있다면 언제든지 말씀해주세요. 😊
# ✓ Ollama 연결 성공: http://localhost:11434
# ✓ 모델: gemma3:4b
#   테스트 응답: 안녕하세요! 무엇을 도와드릴까요? 궁금한 점이 있거나, 필요한 정보가 있다면 언제든지 말씀...

# %% [markdown]
# ## 2. Neo4j 스키마 정보 가져오기

# %%
def get_neo4j_schema(session) -> str:
    """Neo4j 그래프 스키마 정보를 가져옵니다."""
    
    # 노드 라벨 조회
    node_labels_query = "CALL db.labels()"
    node_labels = [record["label"] for record in session.run(node_labels_query)]
    
    # 관계 타입 조회
    rel_types_query = "CALL db.relationshipTypes()"
    rel_types = [record["relationshipType"] for record in session.run(rel_types_query)]
    
    # 실제로 사용되는 관계 타입만 필터링 (LOCATED_IN 제외)
    # 실제 데이터에서 사용되는 관계만 포함
    actual_rels = []
    for rel_type in rel_types:
        count = session.run(f"MATCH ()-[r:{rel_type}]->() RETURN count(r) as count").single()["count"]
        if count > 0:  # 실제로 데이터가 있는 관계만 포함
            actual_rels.append(rel_type)
    
    # 노드별 속성 정보 조회
    node_properties = {}
    for label in node_labels:
        props_query = f"""
        MATCH (n:{label})
        RETURN keys(n) as props
        LIMIT 1
        """
        result = session.run(props_query)
        record = result.single()
        if record:
            node_properties[label] = record["props"]
    
    # 스키마 문자열 생성
    schema_parts = ["# Neo4j Graph Schema\n\n"]
    
    schema_parts.append("## Node Labels:\n")
    for label in node_labels:
        props = node_properties.get(label, [])
        props_str = ", ".join(props) if props else "(no properties)"
        schema_parts.append(f"- {label}: {{{props_str}}}")
    
    schema_parts.append("\n## Relationship Types:\n")
    # 실제 사용되는 관계 타입만 표시
    for rel_type in actual_rels:
        schema_parts.append(f"- {rel_type}")
    
    return "\n".join(schema_parts)

# 스키마 정보 확인
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    print(schema)
# Out:
# # Neo4j Graph Schema
#
#
# ## Node Labels:
#
# - Shelter: {lat, id, shelter_id, sido, sigungu, lon, shelter_type, area, address, name}
# - TemporaryHousing: {facility_id, id, lat, name, sido, sigungu, lon, area, address}
# - Admin: {sido, sigungu, id, gu}
#
# ## Relationship Types:
#
# - IN

# %% [markdown]
# ## 3. Graph RAG 검색 함수

# %%
def generate_cypher_query(question: str, schema: str) -> str:
    """Ollama를 사용하여 자연어 질문을 Cypher 쿼리로 변환합니다."""
    
    prompt = f"""
당신은 Neo4j Cypher 쿼리 전문가입니다.
다음 그래프 스키마 정보를 참고하여, 사용자의 자연어 질문을 Cypher 쿼리로 변환하세요.

# Graph Schema:
{schema}

# 중요: 관계 타입은 'IN'만 사용하세요. 'LOCATED_IN'이나 'INTERSECTS'는 사용하지 마세요.
# 예시:
# - "몇 개" 질문: MATCH (s:Shelter)-[:IN]->(a:Admin {{gu: '강남구'}}) RETURN count(s)
# - "알려주세요" 질문: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10

# 사용자 질문:
{question}

지침:
1. 질문의 의도를 정확히 파악하여 적절한 Cypher 쿼리를 생성하세요.
2. 노드 라벨과 관계 타입을 정확히 사용하세요. 특히 관계는 'IN'만 사용해야 합니다.
3. **중요**: "알려주세요", "찾고 싶어요", "알려주세요" 같은 질문이면 반드시 실제 대피소 정보를 반환하도록 RETURN 절을 작성하세요.
   - 예: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
   - 또는: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s.name, s.address, s.shelter_type LIMIT 10
   - COUNT()를 사용하지 마세요. 실제 노드 정보를 반환해야 합니다.
4. "몇 개" 또는 "개수" 질문이면 COUNT()를 사용하세요.
5. 쿼리만 반환하고 설명은 제외하세요.

Cypher 쿼리:
"""
    
    try:
        response = ollama_generate(prompt.strip())
        
        if not response:
            return None
        
        cypher_query = response.strip()
        # 코드 블록 제거 (```cypher 등)
        if cypher_query.startswith("```"):
            lines = cypher_query.split("\n")
            cypher_query = "\n".join(lines[1:-1]) if len(lines) > 2 else cypher_query
        
        return cypher_query
    except Exception as e:
        print(f"Cypher 쿼리 생성 오류: {e}")
        return None

# %%
def graph_rag_search(question: str, schema: str, session) -> Dict:
    """Graph RAG 검색: Neo4j에서 구조화된 정보를 검색합니다."""
    
    # 1. Cypher 쿼리 생성
    cypher_query = generate_cypher_query(question, schema)
    
    if not cypher_query:
        return {"query": None, "results": [], "count": 0, "error": "Cypher 쿼리 생성 실패"}
    
    print(f"\n[생성된 Cypher 쿼리]\n{cypher_query}\n")
    
    # 2. 쿼리 실행
    try:
        result = session.run(cypher_query)
        records = [dict(record) for record in result]
        
        # COUNT 등의 집계 함수 결과 처리
        # 집계 쿼리는 단일 레코드를 반환하므로, 결과 값 자체를 카운트로 사용
        actual_count = len(records)
        if actual_count == 1 and records:
            # COUNT 쿼리 결과 추출 시도
            for key, value in records[0].items():
                if 'count' in key.lower() or isinstance(value, (int, float)):
                    actual_count = int(value) if isinstance(value, (int, float)) else actual_count
        
        return {
            "query": cypher_query,
            "results": records,
            "count": actual_count
        }
    except Exception as e:
        print(f"  ⚠ Cypher 쿼리 실행 오류: {e}")
        return {
            "query": cypher_query,
            "results": [],
            "count": 0,
            "error": str(e)
        }

# %% [markdown]
# ## 4. Vector RAG 검색 함수

# %%
def vector_rag_search(question: str, collection, top_k: int = 5) -> Dict:
    """Vector RAG 검색: Chroma에서 관련 문서를 검색합니다."""
    
    if collection is None:
        return {"results": [], "error": "Chroma 컬렉션이 없습니다."}
    
    try:
        # 질문을 임베딩으로 변환하여 검색 (Chroma가 자동으로 처리)
        results = collection.query(
            query_texts=[question],
            n_results=top_k
        )
        
        documents = []
        for i in range(len(results["ids"][0])):
            doc_id = results["ids"][0][i]
            doc_text = results["documents"][0][i] if results["documents"] else ""
            distance = results["distances"][0][i] if results["distances"] else None
            
            documents.append({
                "id": doc_id,
                "text": doc_text,
                "distance": distance
            })
        
        return {
            "results": documents,
            "count": len(documents)
        }
    except Exception as e:
        return {
            "results": [],
            "error": str(e)
        }

# %% [markdown]
# ## 5. Hybrid RAG: Graph + Vector 병합

# %%
def format_graph_results(graph_results: Dict, max_length: int = 2000) -> str:
    """Graph RAG 결과를 텍스트로 포맷팅합니다."""
    
    if graph_results.get("error"):
        return f"오류: {graph_results['error']}"
    
    result_count = graph_results.get('count', 0)
    result_parts = ["# Graph RAG 검색 결과\n"]
    result_parts.append(f"Cypher 쿼리: {graph_results.get('query', 'N/A')}\n")
    result_parts.append(f"결과 개수: {result_count}\n")
    
    if not graph_results.get("results"):
        result_parts.append("\n검색 결과가 없습니다.")
    else:
        results = graph_results["results"]
        # 결과가 많으면 요약
        if len(results) > 20:
            result_parts.append(f"\n## 요약: 총 {len(results)}개 결과 중 처음 10개만 표시\n")
            results = results[:10]
        
        for i, record in enumerate(results, 1):
            result_parts.append(f"\n## 결과 {i}")
            for key, value in record.items():
                # 값이 너무 길면 자르기
                value_str = str(value)
                if len(value_str) > 200:
                    value_str = value_str[:200] + "..."
                result_parts.append(f"- {key}: {value_str}")
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략 - 결과가 너무 많습니다]"
    
    return text


def format_vector_results(vector_results: Dict, max_length: int = 3000) -> str:
    """Vector RAG 결과를 텍스트로 포맷팅합니다."""
    
    if vector_results.get("error"):
        return f"오류: {vector_results['error']}"
    
    if not vector_results.get("results"):
        return "검색 결과가 없습니다."
    
    result_parts = ["# Vector RAG 검색 결과\n"]
    result_parts.append(f"결과 개수: {vector_results.get('count', 0)}\n")
    
    for i, doc in enumerate(vector_results["results"], 1):
        result_parts.append(f"\n## 문서 {i} (거리: {doc.get('distance', 'N/A')})")
        doc_text = doc.get('text', '')
        # 문서가 너무 길면 자르기
        if len(doc_text) > 800:
            doc_text = doc_text[:800] + "..."
        result_parts.append(doc_text)
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략]"
    
    return text


def extract_shelter_info(graph_results: Dict, question: str = "") -> str:
    """Graph RAG 결과에서 대피소 정보를 추출하여 형식화된 답변을 생성합니다."""
    
    if not graph_results.get("results"):
        return None
    
    results = graph_results["results"]
    count = graph_results.get("count", 0)
    
    # Shelter 노드 정보 추출
    shelters = []
    
    for record in results:
        # record는 딕셔너리 형태: {'s': <Node ...>} 또는 {'name': '...', 'address': '...'} 등
        for key, value in record.items():
            # Neo4j Node 객체인 경우 (properties 속성이 있음)
            if hasattr(value, 'properties'):
                try:
                    props = value.properties
                    # Shelter 노드인지 확인 (labels 확인)
                    is_shelter = False
                    if hasattr(value, '_labels'):
                        labels = value._labels
                        is_shelter = 'Shelter' in labels or isinstance(labels, frozenset) and 'Shelter' in labels
                    elif hasattr(value, 'labels'):
                        labels = value.labels
                        is_shelter = 'Shelter' in labels
                    else:
                        # labels 속성이 없으면 문자열로 확인
                        value_str = str(value)
                        is_shelter = 'Shelter' in value_str or 'shelter' in key.lower()
                    
                    if is_shelter or 'name' in props or 'address' in props:  # Shelter 속성이 있으면 추가
                        shelter_name = props.get('name', '이름 없음')
                        shelter_address = props.get('address', '주소 없음')
                        shelter_type = props.get('shelter_type', '')
                        # 실제 값이 있는 경우만 추가
                        if shelter_name != '이름 없음' or shelter_address != '주소 없음':
                            shelters.append({
                                'name': shelter_name,
                                'address': shelter_address,
                                'type': shelter_type
                            })
                except Exception as e:
                    # properties 접근 실패 시 무시
                    pass
            # 딕셔너리인 경우 (직접 속성이 있는 경우 또는 dict(record)로 변환된 경우)
            elif isinstance(value, dict):
                if 'name' in value or 'address' in value or 'shelter_type' in value:
                    shelters.append({
                        'name': value.get('name', value.get('s.name', '이름 없음')),
                        'address': value.get('address', value.get('s.address', '주소 없음')),
                        'type': value.get('shelter_type', value.get('s.shelter_type', ''))
                    })
        # record 자체가 속성 딕셔너리인 경우 (RETURN s.name, s.address 같은 쿼리)
        # 모든 값을 확인했는데도 shelters에 추가되지 않은 경우
        if isinstance(record, dict):
            # record의 직접 속성 확인 (RETURN s.name 같은 경우)
            if 'name' in record or 'address' in record:
                record_name = record.get('name', record.get('s.name', ''))
                record_address = record.get('address', record.get('s.address', ''))
                if record_name or record_address:
                    # 중복 체크
                    is_duplicate = any(
                        s.get('name') == record_name and s.get('address') == record_address 
                        for s in shelters
                    )
                    if not is_duplicate:
                        shelters.append({
                            'name': record_name if record_name else '이름 없음',
                            'address': record_address if record_address else '주소 없음',
                            'type': record.get('shelter_type', record.get('s.shelter_type', ''))
                        })
    
    # Shelter 정보가 없으면 None 반환
    if not shelters:
        # 디버깅: 결과 구조 확인
        if results:
            print(f"  ⚠ 대피소 정보 추출 실패: 결과 {len(results)}개, 첫 번째 결과 타입: {type(results[0])}")
            if isinstance(results[0], dict):
                print(f"    첫 번째 결과 키: {list(results[0].keys())}")
                for key, value in list(results[0].items())[:3]:  # 처음 3개만
                    print(f"    - {key}: {type(value)}")
        return None
    
    # 중복 제거 (name과 address가 같은 경우)
    unique_shelters = []
    seen = set()
    for shelter in shelters:
        # '이름 없음'이나 '주소 없음'은 제외
        if shelter['name'] != '이름 없음' and shelter['address'] != '주소 없음':
            key = (shelter['name'], shelter['address'])
            if key not in seen:
                seen.add(key)
                unique_shelters.append(shelter)
    
    # 중복 제거 후에도 없으면 None
    if not unique_shelters:
        return None
    
    # 최대 10개만 표시
    display_shelters = unique_shelters[:10]
    remaining_count = len(unique_shelters) - len(display_shelters)
    
    # 질문에서 구 이름 추출
    import re
    gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
    gu_name = gu_match.group(1) if gu_match else ""
    
    # 답변 생성
    answer_parts = []
    
    if count > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {count}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {count}개의 대피소를 찾았습니다.\n")
    elif len(unique_shelters) > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
    
    if display_shelters:
        answer_parts.append("주요 대피소 목록:")
        for i, shelter in enumerate(display_shelters, 1):
            shelter_type = shelter['type'] if shelter['type'] else '대피소'
            answer_parts.append(f"{i}. {shelter['name']} ({shelter_type})")
            if shelter['address'] and shelter['address'] != '주소 없음':
                answer_parts.append(f"   주소: {shelter['address']}")
        
        if remaining_count > 0:
            answer_parts.append(f"\n이 외에 {remaining_count}개의 대피소가 더 있습니다.")
    
    return "\n".join(answer_parts) if answer_parts else None

# %%
def hybrid_rag(question: str, schema: str, neo4j_session, chroma_collection) -> Dict:
    """Hybrid RAG: Graph RAG와 Vector RAG를 결합하여 검색하고 답변을 생성합니다."""
    
    # 1. Graph RAG 검색
    print("=" * 60)
    print("[Graph RAG 검색 중...]")
    graph_results = graph_rag_search(question, schema, neo4j_session)
    
    # 2. Vector RAG 검색
    print("\n" + "=" * 60)
    print("[Vector RAG 검색 중...]")
    vector_results = vector_rag_search(question, chroma_collection)
    
    # 3. 결과 포맷팅 (길이 제한)
    graph_text = format_graph_results(graph_results, max_length=2000)
    vector_text = format_vector_results(vector_results, max_length=3000)
    
    # 4. Ollama를 사용하여 최종 답변 생성
    print("\n" + "=" * 60)
    print("[Ollama를 통한 최종 답변 생성 중...]")
    print("  프롬프트 길이:", len(f"{question}\n{graph_text}\n{vector_text}"), "자")
    
    # 간결한 프롬프트 생성
    # 질문 유형에 따라 다른 지침 제공
    if '알려주세요' in question or '찾고 싶어요' in question or '어디' in question:
        instructions = """- Graph RAG 결과에 실제 대피소 목록이 있으면 구체적인 이름과 주소를 제시하세요
- 대피소가 많으면 주요 대피소 몇 개를 예시로 제시하고, 총 개수를 알려주세요
- 간결하고 실행 가능한 답변 제공"""
    else:
        instructions = """- 구체적인 데이터(개수, 위치 등)를 명확히 제시
- 간결하고 실행 가능한 답변 제공
- 근거를 간단히 명시"""
    
    final_prompt = f"""재난대응 전문가로서 아래 질문에 답변하세요.

질문: {question}

[Graph RAG 결과]
{graph_text}

[Vector RAG 결과]  
{vector_text}

지침:
{instructions}

답변:"""
    
    try:
        # "알려주세요", "찾고 싶어요" 같은 질문에 대해 먼저 extract_shelter_info로 구체적인 답변 생성
        graph_count = graph_results.get('count', 0)
        is_list_question = '알려주세요' in question or '찾고 싶어요' in question or ('어디' in question and graph_count > 0)
        
        extracted_info = None
        if is_list_question and graph_count > 0:
            # Graph RAG 결과에서 대피소 정보 추출
            extracted_info = extract_shelter_info(graph_results, question)
            if extracted_info:
                print(f"  ✓ 대피소 정보 추출 완료: {len(extracted_info)}자")
        
        final_answer = ollama_generate(final_prompt.strip())
        
        # Ollama 응답 검증: 구체적인 대피소 정보가 포함되어 있는지 확인
        if final_answer and is_list_question and extracted_info:
            # Ollama 답변에 구체적인 대피소 이름이나 주소가 포함되어 있는지 확인
            has_specific_info = any(keyword in final_answer for keyword in ['주소:', '위치:', '명', '곳', '서울', '구'])
            # Ollama 답변이 일반적인 설명만 포함하고 있으면 추출된 정보 사용
            if not has_specific_info or len(final_answer) < 100:
                print(f"  ⚠ Ollama 답변이 일반적입니다. 추출된 정보를 사용합니다.")
                final_answer = extracted_info
        
        # Ollama 응답이 None이거나 비어있는 경우 fallback 답변 생성
        if not final_answer or (isinstance(final_answer, str) and final_answer.strip() == ""):
            print("  ⚠ Ollama 응답 생성 실패: 응답이 None이거나 비어있습니다.")
            # Fallback: 추출된 정보 또는 Graph RAG 결과 기반으로 답변 생성
            
            # 질문에서 구 이름 및 키워드 추출
            import re
            gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
            gu_name = gu_match.group(1) if gu_match else ""
            
            # 질문 유형에 따라 답변 생성
            if '몇 개' in question or '개수' in question or 'count' in question.lower():
                if graph_count > 0:
                    if gu_name:
                        final_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다."
                    else:
                        final_answer = f"검색 결과: {graph_count}개를 찾았습니다."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어디' in question or '위치' in question or '알려주세요' in question or '찾고 싶어요' in question:
                if extracted_info:
                    final_answer = extracted_info
                elif graph_count > 0:
                    final_answer = f"{gu_name if gu_name else '해당 지역'}에 있는 대피소는 총 {graph_count}개입니다. 상세 정보는 Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어떻게' in question or '행동' in question:
                # Vector RAG 결과를 활용한 답변
                vector_count = vector_results.get('count', 0)
                if vector_count > 0:
                    final_answer = "Vector RAG 검색 결과에 관련 행동 요령이 포함되어 있습니다. 문서를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            else:
                if graph_count > 0:
                    final_answer = f"검색 결과를 {graph_count}개 찾았습니다. Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            
            print(f"  ✓ Fallback 답변 생성: {final_answer[:50]}...")
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": final_answer
        }
    except Exception as e:
        print(f"  ⚠ 최종 답변 생성 오류: {e}")
        # Fallback 답변 생성
        graph_count = graph_results.get('count', 0)
        
        # 질문에서 구 이름 추출
        import re
        gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
        gu_name = gu_match.group(1) if gu_match else "해당 구"
        
        if '몇 개' in question or '개수' in question:
            if graph_count > 0:
                fallback_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        else:
            if graph_count > 0:
                fallback_answer = f"검색 결과를 {graph_count}개 찾았습니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": fallback_answer,
            "error": str(e)
        }

# %% [markdown]
# ## 6. 테스트 질의 실행

# %%
# Neo4j 스키마 가져오기
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    # 시민 시나리오 테스트 질의
    test_questions = [
        "강남구에 있는 대피소는 몇 개인가요?",
        "지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.",
        "임시주거시설은 어디에 있나요?",
        "지진 발생 시 어떻게 행동해야 하나요?",
        "공습경보가 발령되면 어떻게 해야 하나요?",
        "서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?"
    ]
    
    # 첫 번째 질의 테스트
    question = test_questions[0]
    print(f"\n{'='*60}")
    print(f"질문: {question}")
    print(f"{'='*60}\n")
    
    result = hybrid_rag(
        question=question,
        schema=schema,
        neo4j_session=session,
        chroma_collection=chroma_collection
    )
    
    print("\n" + "=" * 60)
    print("=" * 60)
    print(result.get("answer", "답변 생성 실패"))
# Out:
# ============================================================
# 질문: 강남구에 있는 대피소는 몇 개인가요?
# ============================================================
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sigungu = '강남구' RETURN count(s)
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sigungu = '강남구' RETURN count(s)
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3156 자
# ✓ Ollama 응답 생성: 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 검색 결과에서 240를 반환)
#
# ============================================================
# ============================================================
# 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 검색 결과에서 240를 반환)

# %%
# 여러 질의 일괄 실행
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    results = []
    for i, question in enumerate(test_questions, 1):
        print(f"\n\n{'#'*60}")
        print(f"질의 {i}/{len(test_questions)}: {question}")
        print(f"{'#'*60}\n")
        
        result = hybrid_rag(
            question=question,
            schema=schema,
            neo4j_session=session,
            chroma_collection=chroma_collection
        )
        
        results.append(result)
        
        print(f"\n{'='*60}")
        print("[최종 답변]")
        print(f"{'='*60}")
        print(result)
        print(result.get("answer", "답변 생성 실패"))
        print(f"\n{'='*60}\n")
# Out:
# ############################################################
# 질의 1/6: 강남구에 있는 대피소는 몇 개인가요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter {sigungu: '강남구'})
# RETURN count(s)
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter {sigungu: '강남구'})
# RETURN count(s)
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3149 자
# ✓ Ollama 응답 생성: 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 결과에서 확인)
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '강남구에 있는 대피소는 몇 개인가요?', 'graph_results': {'query': "MATCH (s:Shelter {sigungu: '강남구'})\nRETURN count(s)", 'results': [{'count(s)': 240}], 'count': 240}, 'vector_results': {'results': [{'id': '화재행동요령', 'text': '# 재난 행동요령: 화재\n\n## 평소 대비 요령\n\n### 1. 사전점검\n\n화재 예방을 위해 평소에 다음과 같이 확인합니다.\n\n#### 눈으로 확인\n- 사용하지 않는 전열기구 코드를 확인합니다.\n- 가스레인지 중간 벨브 잠금을 확인합니다.\n\n#### 귀로 확인\n- 평소에 나지 않던 이상한 소리를 확인합니다.\n\n#### 코로 확인\n- 타는 냄새가 나지 않는지 확인합니다.\n\n#### 손으로 확인\n- 만져보거나 두들겨 봅니다.\n\n#### 행동으로 확인\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n### 2. 대피훈련\n\n화재 상황에 대비한 훈련을 정기적으로 실시합니다.\n\n- 배워보자: 소화기 사용법, 표시해보자: 2곳 이상의 비상통로, 찾아보자: 대피장소, 막아보자: 문틈\n- 전화해보자: 우리 가족, 정해보자: 만날 장소, 어디있을까: 경량칸막이\n\n### 3. 비상용품 준비\n\n- 대피방법과 대피해서 만나는 장소를 사전에 약속합니다.\n- 대피할때 가져가야할 중요물건 목록을 작성하고 챙길 사람을 선정합니다.\n- 비상연락 전화번호 및 연락해야 할 대상을 선정합니다.\n- 문틈을 막아야할 경우 청테이프 또는 수건을 준비합니다.\n- 외부 대피 시 사용할 수건 등 대피에 사용할 물건을 준비합니다.\n- 긴급 대피한 경우 만날 장소와 비상연락망을 정해둡니다.\n\n---\n\n## 화재 발생 시 행동 요령\n\n### 화재경보가 울릴 때\n\n#### 1. 주변 사람에게 알립니다.\n\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려고 하기보다는 소리를 질러 주변 사람에게 알립니다.\n\n#### 2. 대피방법을 결정합니다.\n\n- 손등으로 출입문 손잡이를 만져보아 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져 보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n#### 3. 신속히 대피합니다.\n\n- 대피할 때는 엘리베이터를 절대 이용하지 않고 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n#### 4. 119로 신고합니다.\n\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n#### 5. 대피 후 인원을 확인합니다.\n\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n### 불을 발견했을 때\n\n#### 1. 연기가 발생하거나 불이 난 것을 보았을 때\n\n- 불이 난 것을 발견하면 "불이야!"라고 소리치거나 비상벨을 눌러 주변에 알리도록 합니다.\n\n#### 2. 불을 끌 것인지 대피할 것인지 판단합니다.\n\n- 불길이 천장까지 닿지 않은 작은 불이라면 소화기나 물양동이 등을 활용하여 신속히 끄도록 합니다.\n- 불길이 커져서 대피해야 할 경우 젖은 수건 또는 담요를 활용하여 계단을 통해 밖으로 대피합니다.\n- 세대 밖으로 대피가 어려운 경우 경량칸막이를 이용하여 이웃집으로 대피하거나 완강기를 이용하여 창문으로 나가는 방법, 실내대피 공간으로 대피하였다가 불이 꺼진 후 나오는 방법 등을 활용합니다.\n\n### 소화기 사용법\n\n#### 실내에서 사용할 때는 밖으로 대피할 때를 대비하여 문을 등지고\n\n1. 소화기를 가져와서 몸통을 단단히 잡고 안전핀을 뽑습니다.\n2. 노즐을 잡고 불쪽을 향해 가까이 이동합니다.\n3. 손잡이를 꽉 움켜쥡니다.\n4. 분말이 골고루 불을 덮을 수 있도록 쏩니다.\n\n### 완강기 사용법\n\n1. 지지대 고리에 완강기 고리를 걸고 잠근다.\n2. 지지대를 창밖으로 밀고 릴(줄)을 던진다.\n3. 완강기 벨트를 가슴 높이까지 걸고 조인다.\n4. 벽을 짚으며 안전하게 내려간다.\n\n### 옷에 불이 붙었을 때\n\n1. 옷에 불이 붙었을 때는 하던 일을 멈춥니다.\n2. 얼굴(눈, 코, 입)에 화상을 입지 않도록 두 손으로 감싼다.\n3. 바닥에 엎드린 후 몸을 뒹굴어서 불이 꺼지도록 합니다.\n\n---\n\n## 화재 대피 후 행동 요령\n\n### 1. 가족의 상황을 확인하고 부상자에 대한 응급처치를 실시합니다.\n\n- 대피 후 가족 모두의 안전 여부를 확인합니다.\n- 부상자가 있으면 응급처치를 실시하고 119에 신고하여 이송받습니다.\n\n### 2. 주변의 피해 상황을 파악합니다.\n\n- 대피 후 집으로 돌아온 경우 반드시 주택 등의 안전 여부를 확인하고 출입합니다.\n- 파손된 시설물(주택, 상하수도 등)은 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n\n### 3. 파손된 물품에 대한 기록을 남깁니다.\n\n- 파손된 사유시설을 보수 또는 복구할 때에는 반드시 사진을 찍어 둡니다.\n\n### 4. 올바른 정보를 확인합니다.\n\n- 근거 없는 유언비어에 유의하고, TV·라디오나 공공기관에서 제공하는 정보를 확인합니다.\n- 정부 안내방송을 계속 청취하고 이에 따라 행동합니다.\n\n### 5. 재난 상황에 따라 행동합니다.\n\n- 화재가 계속 진행 중이면 추가 대피 지시에 따릅니다.\n- 대피소에 도착한 후에는 도착사실을 알리고 통제에 따릅니다.\n- 구조 활동에 적극 협조합니다.\n', 'distance': 0.9835575819015503}, {'id': '폭발사고 국민행동요령', 'text': '# 국민재난안전포털 폭발사고 국민행동요령 (2025)\n\n**한국가스안전공사 & 행정안전부 발행**\n\n---\n\n## 폭발사고 개요 및 통계\n\n### 폭발사고의 위험성\n\n폭발사고는 순간적으로 발생하며 **매우 광범위한 피해를 유발**합니다. 인명피해뿐만 아니라 건물 붕괴, 대규모 화재 등 연쇄 재난으로 이어질 수 있습니다.\n\n### 폭발사고 통계 (2020~2022년)\n\n**발생 장소:**\n- **공동주택·단독주택**: 37%\n- **자동차**: 14%\n- **기타 장소**: 49%\n\n**인명피해:**\n- **총 재해자 수**: 323명\n- **사망자 수**: 19명\n- **사망률**: 약 5.9%\n\n**주요 원인:**\n- 가스누출 및 폭발\n- 부탄가스, 헤어스프레이 등 폭발성 용기\n- 배터리 과열\n- 부주의한 폭발물 소지\n\n---\n\n## 폭발사고 예방\n\n### 1. 가스 누출 예방 및 관리\n\n**가스 누출 시 즉시 조치:**\n- 체류가스를 **밖으로 내보내기** (환기)\n- **전기스위치 사용 금지** (스파크 위험)\n- **화기 사용 절대 금지**\n- 창문과 출입문 **활짝 열기**\n\n**가스 누출 감지:**\n- 특이한 냄새 감지 시 신속히 조치\n- 이웃과 공동으로 환기\n- 관리사무소 또는 가스회사에 신고\n\n### 2. 먼지 폭발 예방\n\n**밀폐공간 먼지 관리:**\n- 먼지가 많이 발생하는 밀폐공간에서 **집진설비 설치**\n- **화기사용 억제**\n- 정기적인 청소로 먼지 축적 방지\n\n**위험 장소:**\n- 제조공장 (밀가루, 톱밥 등 가연성 분진)\n- 곡물 저장소\n- 화학 공장\n- 광산 등\n\n### 3. 가전제품 및 보일러 안전 관리\n\n**과열 방지:**\n- 과열이 되기 쉬운 가전제품은 **무리해서 사용 금지**\n- 보일러, 히터 등 **안전밸브 항상 확인·점검**\n- 정기적인 정비 및 AS 실시\n\n**가전제 ...
# 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 결과에서 확인)
#
# ============================================================
#
#
#
# ############################################################
# 질의 2/6: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 5080 자
#   ⚠ 대피소 정보 추출 실패: 결과 10개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['s']
#     - s: <class 'neo4j.graph.Node'>
# ✓ Ollama 응답 생성: 서초구 대피소 정보는 다음과 같습니다. Graph RAG 검색 결과에 따르면 서초구에는 총 9개의 옥외 대피소가 있습니다. 아래는 주요 대피소 정보입니다.
#
# *   **반포역 대피소:** 서울특별시 서초구 반포대로 217 (반포동)
# *   **잠원동 옥외대피소:** 서울특별시 서초구 잠원동 160-3
# *   **잠원동 옥외대피소2:** 서울특별시 서초구 잠...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10", 'results': [{'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:0' labels=frozenset({'Shelter'}) properties={'area': 1184.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포대로 217(반포동)', 'sido': '서울특별시', 'name': '서울지방조달청 테니스장', 'lon': 127.002453, 'id': 'shelter_185', 'shelter_id': 185.0, 'lat': 37.499301}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:4' labels=frozenset({'Shelter'}) properties={'area': 1720.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 160-3', 'sido': '서울특별시', 'name': '누에소공원', 'lon': 127.008449, 'id': 'shelter_189', 'shelter_id': 189.0, 'lat': 37.50923}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:9' labels=frozenset({'Shelter'}) properties={'area': 2000.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 162-1', 'sido': '서울특별시', 'name': '잠원흥동소공원', 'lon': 127.000426, 'id': 'shelter_194', 'shelter_id': 194.0, 'lat': 37.507746}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:10' labels=frozenset({'Shelter'}) properties={'area': 840.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초동 1686-10', 'sido': '서울특별시', 'name': '새싹어린이공원', 'lon': 127.018272, 'id': 'shelter_195', 'shelter_id': 195.0, 'lat': 37.497541}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:14' labels=frozenset({'Shelter'}) properties={'area': 1432.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 방배동 906-14', 'sido': '서울특별시', 'name': '효령어린이공원', 'lon': 126.997549, 'id': 'shelter_199', 'shelter_id': 199.0, 'lat': 37.483163}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:15' labels=frozenset({'Shelter'}) properties={'area': 21609.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 우면동 749', 'sido': '서울특별시', 'name': '우면수변공원', 'lon': 127.013599, 'id': 'shelter_200', 'shelter_id': 200.0, 'lat': 37.45584}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:25' labels=frozenset({'Shelter'}) properties={'area': 708.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포동 68-2', 'sido': '서울특별시', 'name': '파리15구공원', 'lon': 126.999165, 'id': 'shelter_210', 'shelter_id': 210.0, 'lat': 37.499517}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:206' labels=frozenset({'Shelter'}) properties={'area': 988.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포동 53-1', 'sido': '서울특별시', 'name': '미도어린이공원', 'lon': 127.010758, 'id': 'shelter_160', 'shelter_id': 160.0, 'lat': 37.501711}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:208' labels=frozenset({'Shelter'}) properties={'area': 2254.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초중앙로 96(서초동)', 'sido': '서울특별시', 'name': '서울교육대학교 부설초등학교 운동장', 'lon': 127.016948, 'id': 'shelter_162', 'shelter_id': 162.0, 'lat': 37.490249}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:217' labels=frozenset({'Shelter'}) properties={'area': 2233.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초동 1301-25', 'sido': '서울특별시', 'name': '누리숲어린이공원', 'lon': 127.021195, 'id': 'shelter_171', 'shelter_id': 171.0, 'lat': 37.502051}>}], 'count': 10}, 'vector_results': {'results': [{'id': '테러 대응 국민행동요령', 'text': '# 국민재난안전포털 테러 대응 국민행동요령 (2025)\n\n---\n\n## 테러개요 및 위험성\n\n최근 국내외에서 드론, 차량돌진, 우편물·택배 등 다양한 테러 유형이 늘고 있습니다. 테러는 국적, 인종, 지역을 가리지 않으며 안전지대가 없습니다.\n\n---\n\n## 테러 유형별 행동요령\n\n### [현장 테러 대응]\n- 즉시 대피(RUN) → 안전확보(HIDE Safety) → 신고(TELL)\n- 폭발물테러, 화학·생물테러, 방사능 테러 모두 해당\n- 차분하고 신중한 태도로, 상황별 신속 대피와 신고가 기본\n\n### [우편물·택배 테러]\n- 외국발송, 발신자 미상, 과도하게 포장, 무겁거나 화학냄새 등 의심물은 절대 개봉하지 말고 덮은 후 현장을 밀폐하고 즉시 벗어나야 함\n- 주변 인원 대피 후 111, 112로 신고\n\n### [화학·생물 테러]\n- 증상: 눈·피부 따가움, 어지러움, 구토, 기침, 호흡곤란\n- 즉시 방독면·손수건, 휴지 등으로 코·입 가리고 호흡\n- 오염지역과 오염원 즉시 확인하여 탈출\n- 안내받 ...
# 서초구 대피소 정보는 다음과 같습니다. Graph RAG 검색 결과에 따르면 서초구에는 총 9개의 옥외 대피소가 있습니다. 아래는 주요 대피소 정보입니다.
#
# *   **반포역 대피소:** 서울특별시 서초구 반포대로 217 (반포동)
# *   **잠원동 옥외대피소:** 서울특별시 서초구 잠원동 160-3
# *   **잠원동 옥외대피소2:** 서울특별시 서초구 잠원동 162-1
# *   **서초동 옥외대피소:** 서울특별시 서초구 서초동 1686-10
# *   **방배동 옥외대피소:** 서울특별시 서초구 방배동 906-14
# *   **우면동 옥외대피소:** 서울특별시 서초구 우면동 749
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 68-2
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 217 (반포동)
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 217 (반포동)
#
# **참고:** 위 정보는 Graph RAG 검색 결과에 기반하며, 실제 상황과 다를 수 있습니다. 재난 상황 발생 시에는 공지되는 최신 정보를 확인하시기 바랍니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 3/6: 임시주거시설은 어디에 있나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (t:TemporaryHousing)
# RETURN t.name, t.address, t.sido, t.sigungu
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (t:TemporaryHousing)
# RETURN t.name, t.address, t.sido, t.sigungu
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 4108 자
#   ⚠ 대피소 정보 추출 실패: 결과 821개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['t.name', 't.address', 't.sido', 't.sigungu']
#     - t.name: <class 'str'>
#     - t.address: <class 'str'>
#     - t.sido: <class 'str'>
# ✓ Ollama 응답 생성: 임시 주거 시설 정보는 Graph RAG 결과에 따라 다음과 같습니다.
#
# *   **총 821개**의 임시 주거 시설이 등록되어 있습니다.
# *   현재까지 확인된 내용은 **서울특별시 은평구**에 집중되어 있습니다.
#
# **구체적인 위치 정보:**
#
# *   증산동주민센터 (서울특별시 은평구 증산동 187-19)
# *   증산초등학교 체육관 (서울특별시 은평구...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '임시주거시설은 어디에 있나요?', 'graph_results': {'query': 'MATCH (t:TemporaryHousing)\nRETURN t.name, t.address, t.sido, t.sigungu', 'results': [{'t.name': '증산동주민센터', 't.address': '서울특별시 은평구 증산동 187-19', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '증산초등학교 체육관', 't.address': '서울특별시 은평구 증산동 212-0', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '수색초등학교', 't.address': '서울특별시 은평구 수색동 129', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '수색동 주민센터', 't.address': '서울특별시 은평구 수색동 363-11', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '진관동 주민센터', 't.address': '서울특별시 은평구 진관동 78', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '구산동주민센터', 't.address': '서울특별시 은평구 구산동 27-5', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '역촌동 주민센터', 't.address': '서울특별시 은평구 역촌동 62-26', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '덕산중학교 체육관', 't.address': '서울특별시 은평구 신사동 265-4', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '신사1동주민센터', 't.address': '서울특별시 은평구 신사동 29-2', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '신사2동주민센터', 't.address': '서울특별시 은평구 신사동 163-17', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '서울서신초등학교', 't.address': '서울특별시 은평구 신사동 194-0', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '증산중학교 다목적강당', 't.address': '서울특별시 은평구 증산동 산24-4', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '염리생활체육관', 't.address': '서울특별시 마포구 염리동 174-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '염리생활체육관', 't.address': '서울특별시 마포구 염리동 174-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '용강초등학교', 't.address': '서울특별시 마포구 대흥동 35-1', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '서문교회', 't.address': '서울특별시 은평구 응암동 577-57', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '은평다목적체육관', 't.address': '서울특별시 은평구 진관동 362-0', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '보훈회관', 't.address': '서울특별시 은평구 진관동 78-0', 't.sido': '서울특별시', 't.sigungu': '은평구'}, {'t.name': '용강동주민센터', 't.address': '서울특별시 마포구 용강동 505-0', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '염리초등학교', 't.address': '서울특별시 마포구 염리동 173-4', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.sido': '서울특별시', 't.sigungu': '마포구'}, {'t.name': '원묵초등학교', 't.address': '서울특별시 중랑구 묵동 11', 't.sido': '서울특별시', 't.sigungu': '중랑구'}, {'t.name': '원묵고등학교', 't.address': '서울특별시 중랑구 묵동 23', 't.sido': '서울특별시', 't.sigungu': '중랑구'}, {'t.name': '양천구민체육센터', 't.address': '서울특별시 양천구 신정동 322-10', 't.sido': '서울특별시', 't.sigungu': '양천구'}, {'t.name': '신정초등학교', 't.address': '서울특별시 강서구 화곡동 869-42', 't.sido': '서울특별시', 't.sigungu': '강서구'}, {'t.name': '장안중학교', 't.address': '서울특별시 중랑구 중화동 288-26', 't.sido': '서울특별시', 't.sigungu': '중랑구'}, {'t.name': '수산교회', 't.address': '서울특별시 중랑구 중화동 316-30', 't.sido': '서울특별시', 't.sigungu': '중랑구'}, {'t.name': '구현고등학교', 't.address': '서울특별시 구로구 구로동 620-30', 't.sido': '서울특별시', 't.sigungu': '구로구'}, {'t.name': '화원종합사회복지관', 't.address': '서울특별시 구로구 구로동 476-134', 't.sido': '서울특별시', 't.sigungu': '구로구'}, {'t.name': '송화초등학교', 't.address': '서울특별시 강서구 방화동 217-35', 't.sido': '서울특별시', 't.sigungu': '강서구'}, {'t.name': '송정중학교', 't.address': '서울특별시 강서구 공항동 770-1', 't.sido': '서울특별시', 't.sigungu': '강서구'}, {'t.name': '서울과학고등학교', 't.address': '서울특별시 종로구 명륜1가 1-0', 't.sido': '서울특별시', 't.sigungu': '종로구'}, {'t.name': '이화동주민센터', 't.address': '서울특별시 종로구 이화동 27-4', 't.sido': '서울특별시', 't.sigungu': '종로구'}, {'t.name': '혜화동자치회관', 't.address': '서울특별시 종로구 혜화동 74-30', 't.sido': '서울특별시', 't.sigungu': '종로구'}, {'t.name': '독립문초등학교', 't.address': '서울특별시 종로구 무악동 46-82', 't.sido': '서울특별시', 't.sigungu': '종로구'}, {'t.name': '창신초등학교', 't.address': '서울특별시 종로구 창신동  ...
# 임시 주거 시설 정보는 Graph RAG 결과에 따라 다음과 같습니다.
#
# *   **총 821개**의 임시 주거 시설이 등록되어 있습니다.
# *   현재까지 확인된 내용은 **서울특별시 은평구**에 집중되어 있습니다.
#
# **구체적인 위치 정보:**
#
# *   증산동주민센터 (서울특별시 은평구 증산동 187-19)
# *   증산초등학교 체육관 (서울특별시 은평구 증산동 212-0)
# *   수색초등학교 (서울특별시 은평구 수색동 129)
# *   수색동 주민센터 (서울특별시 은평구 수색동 363-11)
# *   진관동 주민센터 (서울특별시 은평구 진관동 78)
# *   구산동주민센터 (서울특별시 은평구 구산동 27-5)
# *   역촌동 주민센터 (서울특별시 은평구 역촌동 62-26)
# *   덕산중학교 체육관 (서울특별시 은평구 신사동 265-4)
# *   신사1동주민센터 (서울특별시 은평구 신사동 29-2)
# *   신사2동주민센터 (서울특별시 은평구 신사동 163-17)
#
# **참고:** Graph RAG 결과는 지속적으로 업데이트될 수 있으며, 위 정보는 현재까지 제공된 데이터 기반입니다. 더 자세한 정보는 관련 기관에 문의하시기 바랍니다. 또한, 위 정보는 방응구역에 한정된 것입니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 4/6: 지진 발생 시 어떻게 행동해야 하나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter)
# RETURN s
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter)
# RETURN s
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 5055 자
# ✓ Ollama 응답 생성: 지진 발생 시 안전하게 대피하는 것은 매우 중요합니다. 제공된 정보들을 바탕으로 다음과 같은 행동 요령을 제시합니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 판단합니다.
# *   **머물 곳에서 대피:** 가능하다면 현재 위치에서 안전을 확보합니다. 탁자 아래나 가구 밑으로 몸을 피하는 것이 좋습...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진 발생 시 어떻게 행동해야 하나요?', 'graph_results': {'query': 'MATCH (s:Shelter)\nRETURN s', 'results': [{'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:0' labels=frozenset({'Shelter'}) properties={'area': 1184.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포대로 217(반포동)', 'sido': '서울특별시', 'name': '서울지방조달청 테니스장', 'lon': 127.002453, 'id': 'shelter_185', 'shelter_id': 185.0, 'lat': 37.499301}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:1' labels=frozenset({'Shelter'}) properties={'area': 339.0, 'shelter_type': '옥외대피소', 'sigungu': '관악구', 'address': '서울특별시 관악구 신림동 1555-1', 'sido': '서울특별시', 'name': '사우촌어린이공원', 'lon': 126.934174, 'id': 'shelter_186', 'shelter_id': 186.0, 'lat': 37.467563}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:2' labels=frozenset({'Shelter'}) properties={'area': 345.0, 'shelter_type': '옥외대피소', 'sigungu': '관악구', 'address': '서울특별시 관악구 신림동 1542-1', 'sido': '서울특별시', 'name': '태양어린이공원', 'lon': 126.936486, 'id': 'shelter_187', 'shelter_id': 187.0, 'lat': 37.468497}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:3' labels=frozenset({'Shelter'}) properties={'area': 660.0, 'shelter_type': '옥외대피소', 'sigungu': '관악구', 'address': '서울특별시 관악구 신림동 645-1', 'sido': '서울특별시', 'name': '무궁화어린이공원', 'lon': 126.923566, 'id': 'shelter_188', 'shelter_id': 188.0, 'lat': 37.469681}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:4' labels=frozenset({'Shelter'}) properties={'area': 1720.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 160-3', 'sido': '서울특별시', 'name': '누에소공원', 'lon': 127.008449, 'id': 'shelter_189', 'shelter_id': 189.0, 'lat': 37.50923}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:5' labels=frozenset({'Shelter'}) properties={'area': 2303.0, 'shelter_type': '옥외대피소', 'sigungu': '송파구', 'address': '서울특별시 송파구 송파대로37길 45(가락동)', 'sido': '서울특별시', 'name': '가락초등학교', 'lon': 127.107791, 'id': 'shelter_190', 'shelter_id': 190.0, 'lat': 37.499908}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:6' labels=frozenset({'Shelter'}) properties={'area': 514.0, 'shelter_type': '옥외대피소', 'sigungu': '관악구', 'address': '서울특별시 관악구 신림동 744-1', 'sido': '서울특별시', 'name': '신라어린이공원', 'lon': 126.912582, 'id': 'shelter_191', 'shelter_id': 191.0, 'lat': 37.473606}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:7' labels=frozenset({'Shelter'}) properties={'area': 479.0, 'shelter_type': '옥외대피소', 'sigungu': '관악구', 'address': '서울특별시 관악구 신림동 750-39', 'sido': '서울특별시', 'name': '한라어린이공원', 'lon': 126.914744, 'id': 'shelter_192', 'shelter_id': 192.0, 'lat': 37.475677}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:8' labels=frozenset({'Shelter'}) properties={'area': 3735.0, 'shelter_type': '옥외대피소', 'sigungu': '성북구', 'address': '서울특별시 성북구 길음동 1287-3', 'sido': '서울특별시', 'name': '아름어린이공원', 'lon': 127.015968, 'id': 'shelter_193', 'shelter_id': 193.0, 'lat': 37.607553}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:9' labels=frozenset({'Shelter'}) properties={'area': 2000.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 162-1', 'sido': '서울특별시', 'name': '잠원흥동소공원', 'lon': 127.000426, 'id': 'shelter_194', 'shelter_id': 194.0, 'lat': 37.507746}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:10' labels=frozenset({'Shelter'}) properties={'area': 840.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초동 1686-10', 'sido': '서울특별시', 'name': '새싹어린이공원', 'lon': 127.018272, 'id': 'shelter_195', 'shelter_id': 195.0, 'lat': 37.497541}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:11' labels=frozenset({'Shelter'}) properties={'area': 13685.0, 'shelter_type': '옥외대피소', 'sigungu': '중구', 'address': '서울특별시 중구 을지로 227(을지로5가)', 'sido': '서울특별시', 'name': '훈련원공원', 'lon': 127.003892, 'id': 'shelter_196', 'shelter_id': 196.0, 'lat': 37.56737}>}, {'s': <Node element_id='4:6ae09e0b-304f-4806-9a4 ...
# 지진 발생 시 안전하게 대피하는 것은 매우 중요합니다. 제공된 정보들을 바탕으로 다음과 같은 행동 요령을 제시합니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 판단합니다.
# *   **머물 곳에서 대피:** 가능하다면 현재 위치에서 안전을 확보합니다. 탁자 아래나 가구 밑으로 몸을 피하는 것이 좋습니다.
# *   **떨어지는 물건 주의:** 유리창, 가구 등 떨어질 수 있는 물건에 주의합니다.
#
# **2. 지진 진정 후 (지진 진동이 멈춘 후):**
#
# *   **외부 환경 확인:** 건물, 도로, 전선 등 주변 환경에 피해가 없는지 확인합니다.
# *   **가스 누출 확인:** 가스 냄새가 나면 즉시 창문을 열어 환기하고 가스 밸브를 잠급니다.
# *   **전기 차단:** 감전 사고를 예방하기 위해 전기 차단기를 내립니다.
# *   **대피 준비:** 대피할 장소를 정하고, 비상용품을 챙깁니다.
#
# **3. 대피 시:**
#
# *   **대피 경로 확인:** 미리 정해둔 대피 경로를 따라 이동합니다. (제공된 문서의 옥외 대피소 정보를 활용)
# *   **안전한 장소로 이동:** 건물 밖으로 나갈 때는 넘어지지 않도록 주의하고, 사람이 많은 곳으로 이동합니다.
# *   **지하 공간 피하기:** 지반이 약해져 발생할 수 있는 균열이나 낙하물에 주의합니다.
#
# **4. 추가 정보 활용:**
#
# *   **옥외 대피소 위치:** 제공된 문서의 옥외 대피소 정보(서초구, 관악구 등)를 활용하여 가까운 대피소로 이동합니다.
# *   **비상용품 준비:**  물, 비상식량, 구급약품, 손전등, 라디오 등을 준비합니다.
# *   **가족과의 연락:** 가족 구성원들과 연락하여 안전한 위치를 확인합니다.
#
# **핵심 행동 요령:** 지진 발생 시 침착하게 대응하고, 제공된 정보를 활용하여 안전하게 대피하는 것이 중요합니다.
#
# **참고:** 제공된 텍스트 데이터의 주요 내용은 다음과 같습니다.
#
# *   **지하 공간 피하기:** 지진 발생 시 건물 붕괴 위험이 있으므로 지하 공간은 피합니다.
# *   **가스 누출 주의:** 가스 누출은 폭발의 원인이 될 수 있으므로 주의합니다.
# *   **옥외 대피소 활용:** 가까운 옥외 대피소를 활용하여 안전을 확보합니다. (제공된 데이터베이스에서 옥외 대피소 위치 정보를 얻을 수 있습니다.)
#
# 이 답변이 지진 발생 시 안전하게 대피하는 데 도움이 되기를 바랍니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 5/6: 공습경보가 발령되면 어떻게 해야 하나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.shelter_type = '대피소' RETURN s LIMIT 10
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.shelter_type = '대피소' RETURN s LIMIT 10
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3152 자
# ✓ Ollama 응답 생성: 공습경보가 발령되면 즉시 다음 조치를 취해야 합니다.
#
# 1. **경보 확인 및 정보 습득:** 먼저 공습경보가 발령되었는지 확인하고, 발령 이유와 예상되는 공격 경로, 목표물 등에 대한 정보를 수집합니다. 정부 또는 지자체에서 발표하는 정보를 통해 상황을 정확히 파악하는 것이 중요합니다.
#
# 2. **안전한 장소로 대피:** 대피할 수 있는 가장 안전한 장소...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '공습경보가 발령되면 어떻게 해야 하나요?', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.shelter_type = '대피소' RETURN s LIMIT 10", 'results': [], 'count': 0}, 'vector_results': {'results': [{'id': '화재행동요령', 'text': '# 재난 행동요령: 화재\n\n## 평소 대비 요령\n\n### 1. 사전점검\n\n화재 예방을 위해 평소에 다음과 같이 확인합니다.\n\n#### 눈으로 확인\n- 사용하지 않는 전열기구 코드를 확인합니다.\n- 가스레인지 중간 벨브 잠금을 확인합니다.\n\n#### 귀로 확인\n- 평소에 나지 않던 이상한 소리를 확인합니다.\n\n#### 코로 확인\n- 타는 냄새가 나지 않는지 확인합니다.\n\n#### 손으로 확인\n- 만져보거나 두들겨 봅니다.\n\n#### 행동으로 확인\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n### 2. 대피훈련\n\n화재 상황에 대비한 훈련을 정기적으로 실시합니다.\n\n- 배워보자: 소화기 사용법, 표시해보자: 2곳 이상의 비상통로, 찾아보자: 대피장소, 막아보자: 문틈\n- 전화해보자: 우리 가족, 정해보자: 만날 장소, 어디있을까: 경량칸막이\n\n### 3. 비상용품 준비\n\n- 대피방법과 대피해서 만나는 장소를 사전에 약속합니다.\n- 대피할때 가져가야할 중요물건 목록을 작성하고 챙길 사람을 선정합니다.\n- 비상연락 전화번호 및 연락해야 할 대상을 선정합니다.\n- 문틈을 막아야할 경우 청테이프 또는 수건을 준비합니다.\n- 외부 대피 시 사용할 수건 등 대피에 사용할 물건을 준비합니다.\n- 긴급 대피한 경우 만날 장소와 비상연락망을 정해둡니다.\n\n---\n\n## 화재 발생 시 행동 요령\n\n### 화재경보가 울릴 때\n\n#### 1. 주변 사람에게 알립니다.\n\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려고 하기보다는 소리를 질러 주변 사람에게 알립니다.\n\n#### 2. 대피방법을 결정합니다.\n\n- 손등으로 출입문 손잡이를 만져보아 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져 보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n#### 3. 신속히 대피합니다.\n\n- 대피할 때는 엘리베이터를 절대 이용하지 않고 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n#### 4. 119로 신고합니다.\n\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n#### 5. 대피 후 인원을 확인합니다.\n\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n### 불을 발견했을 때\n\n#### 1. 연기가 발생하거나 불이 난 것을 보았을 때\n\n- 불이 난 것을 발견하면 "불이야!"라고 소리치거나 비상벨을 눌러 주변에 알리도록 합니다.\n\n#### 2. 불을 끌 것인지 대피할 것인지 판단합니다.\n\n- 불길이 천장까지 닿지 않은 작은 불이라면 소화기나 물양동이 등을 활용하여 신속히 끄도록 합니다.\n- 불길이 커져서 대피해야 할 경우 젖은 수건 또는 담요를 활용하여 계단을 통해 밖으로 대피합니다.\n- 세대 밖으로 대피가 어려운 경우 경량칸막이를 이용하여 이웃집으로 대피하거나 완강기를 이용하여 창문으로 나가는 방법, 실내대피 공간으로 대피하였다가 불이 꺼진 후 나오는 방법 등을 활용합니다.\n\n### 소화기 사용법\n\n#### 실내에서 사용할 때는 밖으로 대피할 때를 대비하여 문을 등지고\n\n1. 소화기를 가져와서 몸통을 단단히 잡고 안전핀을 뽑습니다.\n2. 노즐을 잡고 불쪽을 향해 가까이 이동합니다.\n3. 손잡이를 꽉 움켜쥡니다.\n4. 분말이 골고루 불을 덮을 수 있도록 쏩니다.\n\n### 완강기 사용법\n\n1. 지지대 고리에 완강기 고리를 걸고 잠근다.\n2. 지지대를 창밖으로 밀고 릴(줄)을 던진다.\n3. 완강기 벨트를 가슴 높이까지 걸고 조인다.\n4. 벽을 짚으며 안전하게 내려간다.\n\n### 옷에 불이 붙었을 때\n\n1. 옷에 불이 붙었을 때는 하던 일을 멈춥니다.\n2. 얼굴(눈, 코, 입)에 화상을 입지 않도록 두 손으로 감싼다.\n3. 바닥에 엎드린 후 몸을 뒹굴어서 불이 꺼지도록 합니다.\n\n---\n\n## 화재 대피 후 행동 요령\n\n### 1. 가족의 상황을 확인하고 부상자에 대한 응급처치를 실시합니다.\n\n- 대피 후 가족 모두의 안전 여부를 확인합니다.\n- 부상자가 있으면 응급처치를 실시하고 119에 신고하여 이송받습니다.\n\n### 2. 주변의 피해 상황을 파악합니다.\n\n- 대피 후 집으로 돌아온 경우 반드시 주택 등의 안전 여부를 확인하고 출입합니다.\n- 파손된 시설물(주택, 상하수도 등)은 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n\n### 3. 파손된 물품에 대한 기록을 남깁니다.\n\n- 파손된 사유시설을 보수 또는 복구할 때에는 반드시 사진을 찍어 둡니다.\n\n### 4. 올바른 정보를 확인합니다.\n\n- 근거 없는 유언비어에 유의하고, TV·라디오나 공공기관에서 제공하는 정보를 확인합니다.\n- 정부 안내방송을 계속 청취하고 이에 따라 행동합니다.\n\n### 5. 재난 상황에 따라 행동합니다.\n\n- 화재가 계속 진행 중이면 추가 대피 지시에 따릅니다.\n- 대피소에 도착한 후에는 도착사실을 알리고 통제에 따릅니다.\n- 구조 활동에 적극 협조합니다.\n', 'distance': 1.002604365348816}, {'id': '폭발사고 국민행동요령', 'text': '# 국민재난안전포털 폭발사고 국민행동요령 (2025)\n\n**한국가스안전공사 & 행정안전부 발행**\n\n---\n\n## 폭발사고 개요 및 통계\n\n### 폭발사고의 위험성\n\n폭발사고는 순간적으로 발생하며 **매우 광범위한 피해를 유발**합니다. 인명피해뿐만 아니라 건물 붕괴, 대규모 화재 등 연쇄 재난으로 이어질 수 있습니다.\n\n### 폭발사고 통계 (2020~2022년)\n\n**발생 장소:**\n- **공동주택·단독주택**: 37%\n- **자동차**: 14%\n- **기타 장소**: 49%\n\n**인명피해:**\n- **총 재해자 수**: 323명\n- **사망자 수**: 19명\n- **사망률**: 약 5.9%\n\n**주요 원인:**\n- 가스누출 및 폭발\n- 부탄가스, 헤어스프레이 등 폭발성 용기\n- 배터리 과열\n- 부주의한 폭발물 소지\n\n---\n\n## 폭발사고 예방\n\n### 1. 가스 누출 예방 및 관리\n\n**가스 누출 시 즉시 조치:**\n- 체류가스를 **밖으로 내보내기** (환기)\n- **전기스위치 사용 금지** (스파크 위험)\n- **화기 사용 절대 금지**\n- 창문과 출입문 **활짝 열기**\n\n**가스 누출 감지:**\n- 특이한 냄새 감지 시 신속히 조치\n- 이웃과 공동으로 환기\n- 관리사무소 또는 가스회사에 신고\n\n### 2. 먼지 폭발 예방\n\n**밀폐공간 먼지 관리:**\n- 먼지가 많이 발생하는 밀폐공간에서 **집진설비 설치**\n- **화기사용 억제**\n- 정기적인 청소로 먼지 축적 방지\n\n**위험 장소:**\n- 제조공장 (밀가루, 톱밥 등 가연성 분진)\n- 곡물 저장소\n- 화학 공장\n- 광산 등\n\n### 3. 가전제품 및 보일러 안전 관리\n\n**과열 방지:**\n- 과열이 되기 쉬운 가전제품은 **무리해서 사용 금지**\n- 보일러, 히터 등 **안전밸브 항상 확인·점검**\n- 정기적인 정비 및 AS 실시\n\n**가전제품 점검: ...
# 공습경보가 발령되면 즉시 다음 조치를 취해야 합니다.
#
# 1. **경보 확인 및 정보 습득:** 먼저 공습경보가 발령되었는지 확인하고, 발령 이유와 예상되는 공격 경로, 목표물 등에 대한 정보를 수집합니다. 정부 또는 지자체에서 발표하는 정보를 통해 상황을 정확히 파악하는 것이 중요합니다.
#
# 2. **안전한 장소로 대피:** 대피할 수 있는 가장 안전한 장소를 찾습니다. 건물이라면 가장 안쪽에 있는 튼튼한 건물로 이동하고, 지하 대피소, 주민센터, 학교 등의 대피 시설을 이용할 수 있습니다. 야외라면 콘크리트 건물이나 움푹 들어간 곳 등 건물 밑으로 대피합니다.
#
# 3. **보호  실시:** 대피 장소에 도착하면 테이블 밑이나 의자 아래에 엎드려 머리를 보호하며, 주변 사람들과 함께 몸을 웅크려 안전을 확보합니다.
#
# 4. **정보 공유 및 협력:** 가족, 이웃, 동료와 함께 상황을 공유하고, 지침을 따르며 협력합니다.
#
# 5. **추가 지시 이행:** 정부 또는 지자체에서 추가적인 지침이 내려지면 즉시 따릅니다.
#
# **주의사항:**
#
# *   **침착하게 행동:** 공포에 질려 당황하지 않고 침착하게 대응하는 것이 중요합니다.
# *   **정보의 신뢰성 확인:** 인터넷이나 SNS 등에서 유통되는 정보의 진위를 확인하고, 공식적인 정보를 우선적으로 따릅니다.
# *   **지속적인 상황 확인:** 상황이 변화할 수 있으므로 지속적으로 정보를 확인하고, 필요에 따라 대피 계획을 수정합니다.
#
# **현재 제공된 정보에 따르면, 공습경보 상황에 대한 직접적인 대피 방법이나 장소 정보는 없습니다.**  하지만 화재 발생 시 행동 요령과 폭발 사고, 전기 사고 등 다양한 재난 상황에 대한 정보를 제공하고 있습니다.  따라서, 현재 상황에 맞는 안전 정보를 참고하여 침착하게 대응하는 것이 중요합니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 6/6: 서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.area DESC LIMIT 1
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.area DESC LIMIT 1
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3377 자
#   ⚠ 대피소 정보 추출 실패: 결과 1개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['s']
#     - s: <class 'neo4j.graph.Node'>
# ✓ Ollama 응답 생성: 서초구에서 가장 큰 옥외대피소는 ‘반포동 옥외대피소’입니다.
#
# Graph RAG 검색 결과에서 해당 대피소는 ‘area’: 77499.0으로 가장 큰 면적을 가지고 있습니다. 서초구에는 총 37개의 옥외대피소가 있습니다.
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.area DESC LIMIT 1", 'results': [{'s': <Node element_id='4:6ae09e0b-304f-4806-9a41-93b5ced43d52:887' labels=frozenset({'Shelter'}) properties={'area': 77499.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 신반포로16길 30(반포동)', 'sido': '서울특별시', 'name': '반포종합운동장', 'lon': 126.994297, 'id': 'shelter_659', 'shelter_id': 659.0, 'lat': 37.500578}>}], 'count': 1}, 'vector_results': {'results': [{'id': '전기·가스사고 국민행동요령', 'text': "# 국민재난안전포털 전기·가스사고 국민행동요령 (2025)\n\n**한국전기안전공사 & 한국가스안전공사 & 행정안전부 발행**\n\n---\n\n## 전기사고 개요\n\n전기사고는 화재, 감전, 폭발 등 심각한 피해를 야기할 수 있습니다. 평소 안전관리와 올바른 사용으로 대부분의 전기사고를 예방할 수 있습니다.\n\n---\n\n## 전기로 인한 화재 예방\n\n### 1. 단락(합선)에 의한 화재 예방\n\n**퓨즈 및 차단기:**\n- 퓨즈나 과전류 차단기는 **반드시 정격용량의 것 사용**\n- 용량에 맞지 않는 제품 사용 금지\n\n**전선 관리:**\n- 용량에 적합한 규격 전선 사용\n- 노후되었거나 손상된 전선은 **새 전선으로 교체**\n- 배선은 가능한 **보호관 사용**\n- 열이나 외부 충격에 노출 방지\n\n**전선 고정:**\n- 못이나 스테이플러로 전선 고정 금지\n- 바닥이나 문틀을 통과하는 전선은 **배관 등으로 보호**\n\n**정기 점검:**\n- 스위치, 배전반 내부 **정기적으로 점검**\n- 전기가 통할 수 있는 물질, 가연성 물질 제거\n- 보이지 않는 장소의 전선도 **수시로 점검**\n\n### 2. 누전에 의한 화재 예방\n\n**누전차단기 설치:**\n- 건물이나 대용량 전기기구에 **배선별로 누전차단기 설치**\n\n**배선 점검:**\n- 배선의 **피복손상 여부를 수시로 확인**\n\n**배선 배치:**\n- 전선이 금속체나 젖은 구조물에 **직접 접촉되지 않도록 배선**\n\n### 3. 전기 스파크에 의한 화재 예방\n\n**전기기기 관리:**\n- 각종 전기기기는 사용 후 **반드시 플러그 뽑기**\n- 정전이 되면 **플러그를 뽑거나 스위치 끄기**\n\n**배전반 점검:**\n- 배전반 내의 **먼지, 금속가루 등 분진 제거**\n\n**분진 관리:**\n- 밀가루, 톱밥, 섬유 먼지 등 가연성 분진이 많은 장소\n- **수시로 청소하여 분진 축적 방지**\n\n**전기시설 주변:**\n- 배전반 등 전기시설 부근에 **가구, 위험물, 기타 가연물 배치 금지**\n\n### 4. 과부하에 의한 전기화재 예방\n\n**문어발식 사용 금지:**\n- 한 콘센트에 여러 개의 플러그 접속 금지\n- 각 콘센트에 한두 개 정도만 사용\n\n**전선 규격:**\n- 전기기기의 전기용량 및 전압에 **적합한 규격전선 사용**\n\n### 5. 과열에 의한 전기화재 예방\n\n**외출 전:**\n- 사용한 전기기구는 **반드시 플러그를 뽑고 외출**\n\n**발열체 관리:**\n- 전기장판 등 발열체를 **장시간 전원 켠 상태로 사용 금지**\n\n**자동 온도 조절기:**\n- 전열기 등의 **자동 온도 조절기 고장 여부 수시 확인**\n\n**백열전구:**\n- 고열이 발생하는 백열전구는 **열이 잘 발산되도록 관리**\n- **가연물을 가까이 두지 말기**\n\n**접속부위 관리:**\n- 전선과 전선, 단자와 전선 등 **접속부위는 단단히 조여서 느슨하지 않도록 유지**\n\n---\n\n## 전기 안전수칙\n\n### 기본 안전수칙\n\n- **전기코드는 반드시 플러그를 잡고 뽑기** (피복 내 구리선 단선 방지)\n- **문어발식 배선 피하기** (전선마다 정해진 전기량 제한)\n- **손상된 전선은 즉시 교체** (감전, 합선 원인)\n- **젖은 손으로 플러그나 스위치 접촉 금지**\n- **유아·어린이 감전사고 예방**: 덮개 있는 콘센트 사용\n\n### 위험지역 주의\n\n- '위험', '고압' 등이 쓰인 장소에는 **절대로 가까이 가지 말기**\n- **전봇대 오르기, 전선 긴 막대기로 찌르기 등 절대 금지**\n\n### 떨어진 전선\n\n- 땅에 떨어진 전선 가까이 **절대 가지 말기**\n- 발견 시 **한국전력공사 123으로 신고**\n\n### 누전차단기\n\n- **누전차단기는 감전사고 방지를 위해 꼭 사용**\n- 위급 시 **즉시 전기 차단**\n\n---\n\n## 계절별 전기안전요령\n\n### 봄철\n\n**눈이 녹은 후 점검:**\n- 건물 안팎이나 전선관으로 **물기 스며듦 확인**\n- 언 땅이 내려앉은 자리에 **배전설비 손상 여부 확인**\n\n### 여름철\n\n**물 고인 신호등·맨홀 조심:**\n- 빗물 고인 **맨홀과 신호등에는 전기가 흐를 수 있음**\n- **가능한 멀리 떨어져 다니기**\n- 맨홀 뚜껑 접근 금지\n\n### 환절기\n\n**가습기 위치 관리:**\n- 콘센트나 전기기기는 습도 상승 시 **누전이나 합선사고 발생 가능**\n- 가습기와 **멀리 떨어져 사용**\n\n### 겨울철\n\n**가연성 물질 정리:**\n- 전기장판과 난로 옆에서 **종이, 담요 등 가연성 물질 제거**\n- **화재 예방의 중요한 수칙**\n\n**전기장판 보관:**\n- **전기장판을 집에서 쌓아두지 말기**\n- **둥글게 말아 세워서 보관** (전선 손상 방지)\n\n---\n\n## 장소별 전기안전요령\n\n### 사무실\n\n**승인받은 제품 사용:**\n- KS, KC 등 인증마크가 있는 제품은 정부 안정성 인증 제품\n- 전기용품 구매 시 **꼭 승인마크 확인**\n\n### 피서지\n\n**임시 전선 주의:**\n- 파가 몰리는 피서지, 음식점, 상점의 **임시 전선은 감전·누전사고 위험**\n- **전기 이용에 주의**\n\n### 전통시장\n\n**노출된 전선 주의:**\n- 야생동물이나 행인에 의해 **전선 훼손으로 누전·합선 위험**\n- 영업종료 후 **콘센트에서 플러그 뽑기**\n\n### 음식점\n\n**환풍기 과열 주의:**\n- 기름 찌꺼기 등으로 환풍기 내부 오염 시 **전기설비 영향**\n- 모터과열로 인한 **화재 위험**\n\n### 길거리\n\n**전깃줄 접촉 금지:**\n- 길거리 전깃줄에는 **높은 전압의 전기 흐름**\n- 만지거나 장난 시 **크게 다칠 수 있음**\n\n---\n\n## 가정에서의 전기안전요령\n\n### 가전제품 권장사용기간\n\n**권장사용기간 초과 주의:**\n- 냉장고, 세탁기, 건조기 등 가전제품도 **권장사용기간 있음**\n- 초과 사용 시 **화재·안전사고 발생 가능**\n\n**점검 및 서비스:**\n- 권장사용기간 내에 **안전점검 받기**\n- 정기적인 **AS 또는 먼지제거 서비스** 받기\n\n**먼지 제거의 효과:**\n- 가전제품 속 먼지만 제거해도 **전기화재 확률 대폭 낮아짐**\n\n---\n\n## 전기재해 용어와 예방법\n\n### 단락 (Short Circuit)\n\n**발생 원인:**\n- 손상된 전선의 회복으로 **서로 다른 도체가 맞닿아 발생**\n\n**예방법:**\n- 전선이 무거운 물체에 걸리지 않도록 관리\n- 날카로운 물질에 의해 손상되지 않도록 보호\n- 노후된 전선은 **즉시 교체**\n\n### 과부하 (Overload)\n\n**발생 원인:**\n- 허용 용량 이상의 전류가 전선에 흘러 발생\n ...
# 서초구에서 가장 큰 옥외대피소는 ‘반포동 옥외대피소’입니다.
#
# Graph RAG 검색 결과에서 해당 대피소는 ‘area’: 77499.0으로 가장 큰 면적을 가지고 있습니다. 서초구에는 총 37개의 옥외대피소가 있습니다.
#
# ============================================================

# %% [markdown]
# ## 7. 결과 분석

# %%
# 결과 요약
print("\n" + "="*60)
print("# Hybrid RAG 검색 결과 요약")
print("="*60 + "\n")

for i, result in enumerate(results, 1):
    question = result.get("question", "N/A")
    graph_count = result.get("graph_results", {}).get("count", 0)
    vector_count = result.get("vector_results", {}).get("count", 0)
    has_answer = result.get("answer") is not None
    
    print(f"질의 {i}: {question}")
    print(f"  - Graph RAG: {graph_count}개 결과")
    print(f"  - Vector RAG: {vector_count}개 결과")
    print(f"  - 최종 답변: {'✓ 생성됨' if has_answer else '✗ 생성 실패'}")
    print(result.get("answer", "답변 생성 실패"))
    print()
# Out:
# ============================================================
# # Hybrid RAG 검색 결과 요약
# ============================================================
#
# 질의 1: 강남구에 있는 대피소는 몇 개인가요?
#   - Graph RAG: 240개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 결과에서 확인)
#
# 질의 2: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
#   - Graph RAG: 10개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 서초구 대피소 정보는 다음과 같습니다. Graph RAG 검색 결과에 따르면 서초구에는 총 9개의 옥외 대피소가 있습니다. 아래는 주요 대피소 정보입니다.
#
# *   **반포역 대피소:** 서울특별시 서초구 반포대로 217 (반포동)
# *   **잠원동 옥외대피소:** 서울특별시 서초구 잠원동 160-3
# *   **잠원동 옥외대피소2:** 서울특별시 서초구 잠원동 162-1
# *   **서초동 옥외대피소:** 서울특별시 서초구 서초동 1686-10
# *   **방배동 옥외대피소:** 서울특별시 서초구 방배동 906-14
# *   **우면동 옥외대피소:** 서울특별시 서초구 우면동 749
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 68-2
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 217 (반포동)
# *   **반포동 옥외대피소:** 서울특별시 서초구 반포대로 217 (반포동)
#
# **참고:** 위 정보는 Graph RAG 검색 결과에 기반하며, 실제 상황과 다를 수 있습니다. 재난 상황 발생 시에는 공지되는 최신 정보를 확인하시기 바랍니다.
#
# 질의 3: 임시주거시설은 어디에 있나요?
#   - Graph RAG: 821개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 임시 주거 시설 정보는 Graph RAG 결과에 따라 다음과 같습니다.
#
# *   **총 821개**의 임시 주거 시설이 등록되어 있습니다.
# *   현재까지 확인된 내용은 **서울특별시 은평구**에 집중되어 있습니다.
#
# **구체적인 위치 정보:**
#
# *   증산동주민센터 (서울특별시 은평구 증산동 187-19)
# *   증산초등학교 체육관 (서울특별시 은평구 증산동 212-0)
# *   수색초등학교 (서울특별시 은평구 수색동 129)
# *   수색동 주민센터 (서울특별시 은평구 수색동 363-11)
# *   진관동 주민센터 (서울특별시 은평구 진관동 78)
# *   구산동주민센터 (서울특별시 은평구 구산동 27-5)
# *   역촌동 주민센터 (서울특별시 은평구 역촌동 62-26)
# *   덕산중학교 체육관 (서울특별시 은평구 신사동 265-4)
# *   신사1동주민센터 (서울특별시 은평구 신사동 29-2)
# *   신사2동주민센터 (서울특별시 은평구 신사동 163-17)
#
# **참고:** Graph RAG 결과는 지속적으로 업데이트될 수 있으며, 위 정보는 현재까지 제공된 데이터 기반입니다. 더 자세한 정보는 관련 기관에 문의하시기 바랍니다. 또한, 위 정보는 방응구역에 한정된 것입니다.
#
# 질의 4: 지진 발생 시 어떻게 행동해야 하나요?
#   - Graph RAG: 3136개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 지진 발생 시 안전하게 대피하는 것은 매우 중요합니다. 제공된 정보들을 바탕으로 다음과 같은 행동 요령을 제시합니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 판단합니다.
# *   **머물 곳에서 대피:** 가능하다면 현재 위치에서 안전을 확보합니다. 탁자 아래나 가구 밑으로 몸을 피하는 것이 좋습니다.
# *   **떨어지는 물건 주의:** 유리창, 가구 등 떨어질 수 있는 물건에 주의합니다.
#
# **2. 지진 진정 후 (지진 진동이 멈춘 후):**
#
# *   **외부 환경 확인:** 건물, 도로, 전선 등 주변 환경에 피해가 없는지 확인합니다.
# *   **가스 누출 확인:** 가스 냄새가 나면 즉시 창문을 열어 환기하고 가스 밸브를 잠급니다.
# *   **전기 차단:** 감전 사고를 예방하기 위해 전기 차단기를 내립니다.
# *   **대피 준비:** 대피할 장소를 정하고, 비상용품을 챙깁니다.
#
# **3. 대피 시:**
#
# *   **대피 경로 확인:** 미리 정해둔 대피 경로를 따라 이동합니다. (제공된 문서의 옥외 대피소 정보를 활용)
# *   **안전한 장소로 이동:** 건물 밖으로 나갈 때는 넘어지지 않도록 주의하고, 사람이 많은 곳으로 이동합니다.
# *   **지하 공간 피하기:** 지반이 약해져 발생할 수 있는 균열이나 낙하물에 주의합니다.
#
# **4. 추가 정보 활용:**
#
# *   **옥외 대피소 위치:** 제공된 문서의 옥외 대피소 정보(서초구, 관악구 등)를 활용하여 가까운 대피소로 이동합니다.
# *   **비상용품 준비:**  물, 비상식량, 구급약품, 손전등, 라디오 등을 준비합니다.
# *   **가족과의 연락:** 가족 구성원들과 연락하여 안전한 위치를 확인합니다.
#
# **핵심 행동 요령:** 지진 발생 시 침착하게 대응하고, 제공된 정보를 활용하여 안전하게 대피하는 것이 중요합니다.
#
# **참고:** 제공된 텍스트 데이터의 주요 내용은 다음과 같습니다.
#
# *   **지하 공간 피하기:** 지진 발생 시 건물 붕괴 위험이 있으므로 지하 공간은 피합니다.
# *   **가스 누출 주의:** 가스 누출은 폭발의 원인이 될 수 있으므로 주의합니다.
# *   **옥외 대피소 활용:** 가까운 옥외 대피소를 활용하여 안전을 확보합니다. (제공된 데이터베이스에서 옥외 대피소 위치 정보를 얻을 수 있습니다.)
#
# 이 답변이 지진 발생 시 안전하게 대피하는 데 도움이 되기를 바랍니다.
#
# 질의 5: 공습경보가 발령되면 어떻게 해야 하나요?
#   - Graph RAG: 0개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 공습경보가 발령되면 즉시 다음 조치를 취해야 합니다.
#
# 1. **경보 확인 및 정보 습득:** 먼저 공습경보가 발령되었는지 확인하고, 발령 이유와 예상되는 공격 경로, 목표물 등에 대한 정보를 수집합니다. 정부 또는 지자체에서 발표하는 정보를 통해 상황을 정확히 파악하는 것이 중요합니다.
#
# 2. **안전한 장소로 대피:** 대피할 수 있는 가장 안전한 장소를 찾습니다. 건물이라면 가장 안쪽에 있는 튼튼한 건물로 이동하고, 지하 대피소, 주민센터, 학교 등의 대피 시설을 이용할 수 있습니다. 야외라면 콘크리트 건물이나 움푹 들어간 곳 등 건물 밑으로 대피합니다.
#
# 3. **보호  실시:** 대피 장소에 도착하면 테이블 밑이나 의자 아래에 엎드려 머리를 보호하며, 주변 사람들과 함께 몸을 웅크려 안전을 확보합니다.
#
# 4. **정보 공유 및 협력:** 가족, 이웃, 동료와 함께 상황을 공유하고, 지침을 따르며 협력합니다.
#
# 5. **추가 지시 이행:** 정부 또는 지자체에서 추가적인 지침이 내려지면 즉시 따릅니다.
#
# **주의사항:**
#
# *   **침착하게 행동:** 공포에 질려 당황하지 않고 침착하게 대응하는 것이 중요합니다.
# *   **정보의 신뢰성 확인:** 인터넷이나 SNS 등에서 유통되는 정보의 진위를 확인하고, 공식적인 정보를 우선적으로 따릅니다.
# *   **지속적인 상황 확인:** 상황이 변화할 수 있으므로 지속적으로 정보를 확인하고, 필요에 따라 대피 계획을 수정합니다.
#
# **현재 제공된 정보에 따르면, 공습경보 상황에 대한 직접적인 대피 방법이나 장소 정보는 없습니다.**  하지만 화재 발생 시 행동 요령과 폭발 사고, 전기 사고 등 다양한 재난 상황에 대한 정보를 제공하고 있습니다.  따라서, 현재 상황에 맞는 안전 정보를 참고하여 침착하게 대응하는 것이 중요합니다.
#
# 질의 6: 서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?
#   - Graph RAG: 1개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# 서초구에서 가장 큰 옥외대피소는 ‘반포동 옥외대피소’입니다.
#
# Graph RAG 검색 결과에서 해당 대피소는 ‘area’: 77499.0으로 가장 큰 면적을 가지고 있습니다. 서초구에는 총 37개의 옥외대피소가 있습니다.

# %%
# Neo4j 연결 종료
neo4j_driver.close()
print("✓ Neo4j 연결 종료")
# Out:
# ✓ Neo4j 연결 종료

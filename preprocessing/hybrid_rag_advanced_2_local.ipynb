# %% [markdown]
# # 6-3. Hybrid RAG (Advanced) - 재난대응 시스템 (로컬 모델)
#
# Graph RAG와 Vector RAG를 결합한 하이브리드 검색 시스템입니다.
# - **Graph RAG**: Neo4j 그래프 데이터베이스에서 구조화된 정보 검색
# - **Vector RAG**: Chroma 벡터 DB에서 문서 검색
# - **Ollama 로컬 모델**: Qwen3:4B를 사용한 자연어 생성
#
# 레퍼런스: [gptsquare_ontology_study_rag_vs_graphrag](https://github.com/faeqsu10/gptsquare_ontology_study_rag_vs_graphrag)
#
# **사전 준비사항:**
# 1. Ollama 설치: `curl https://ollama.ai/install.sh | sh`
# 2. Qwen3:4B 모델 다운로드: `ollama pull qwen3:4b`

# %%
# 필요한 라이브러리 import
import os
from typing import List, Dict, Optional
from dotenv import load_dotenv
import pandas as pd
import warnings
import requests
import json
warnings.filterwarnings('ignore')

# Neo4j
from neo4j import GraphDatabase

# Chroma
import chromadb
from chromadb.config import Settings

load_dotenv()
print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %% [markdown]
# ## 1. 데이터베이스 연결 설정

# %%
# Neo4j 연결 설정
NEO4J_URI = os.getenv("NEO4J_URI", "bolt://localhost:7687")
NEO4J_USER = os.getenv("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "password")

neo4j_driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

def get_neo4j_session():
    return neo4j_driver.session()

# Neo4j 연결 확인
try:
    with get_neo4j_session() as session:
        result = session.run("RETURN 1 as test")
        print(f"✓ Neo4j 연결 성공: {NEO4J_URI}")
except Exception as e:
    print(f"✗ Neo4j 연결 실패: {e}")
# Out:
# ✓ Neo4j 연결 성공: bolt://localhost:7687

# %%
# Chroma 벡터 DB 연결
CHROMA_PERSIST_DIR = "data/chroma"
DOCS_DIR = "docs"

chroma_client = chromadb.PersistentClient(
    path=CHROMA_PERSIST_DIR,
    settings=Settings(anonymized_telemetry=False)
)

# 컬렉션 가져오기 또는 생성
try:
    chroma_collection = chroma_client.get_collection("disaster_docs")
    print(f"✓ Chroma 컬렉션 로드 성공: {chroma_collection.count()} 문서")
except Exception as e:
    print(f"✗ Chroma 컬렉션 로드 실패: {e}")
    print("새 컬렉션 생성 및 문서 적재 중...")
    
    # 새 컬렉션 생성
    chroma_collection = chroma_client.create_collection(
        name="disaster_docs",
        metadata={"description": "재난 행동요령 문서"}
    )
    
    # docs 폴더의 마크다운 파일 읽기 및 적재
    import glob
    
    doc_files = glob.glob(f"{DOCS_DIR}/*.md")
    print(f"\n찾은 문서 파일: {len(doc_files)}개")
    
    documents = []
    ids = []
    metadatas = []
    
    for doc_file in doc_files:
        try:
            with open(doc_file, 'r', encoding='utf-8') as f:
                content = f.read()
            
            filename = os.path.basename(doc_file)
            doc_id = filename.replace('.md', '')
            
            documents.append(content)
            ids.append(doc_id)
            metadatas.append({"source": filename, "type": "disaster_guide"})
            
            print(f"  ✓ {filename} 적재 완료 ({len(content)}자)")
        except Exception as e:
            print(f"  ✗ {doc_file} 적재 실패: {e}")
    
    # Chroma에 문서 추가
    if documents:
        chroma_collection.add(
            documents=documents,
            ids=ids,
            metadatas=metadatas
        )
        print(f"\n✓ 총 {len(documents)}개 문서를 Chroma에 적재했습니다.")
    else:
        print("\n✗ 적재할 문서가 없습니다.")
# Out:
# ✓ Chroma 컬렉션 로드 성공: 4 문서

# %% [markdown]
# ## 1-1. Neo4j 데이터 적재 (필요시)

# %%
# Neo4j 데이터 적재 함수 (배치 처리로 성능 향상)
def load_neo4j_data(nodes_csv: str, relationships_csv: str, session):
    """CSV 파일에서 Neo4j로 데이터를 적재합니다."""
    
    # 기존 데이터 삭제
    session.run("MATCH (n) DETACH DELETE n")
    print("✓ 기존 데이터 삭제 완료")
    
    # 노드 CSV 읽기
    nodes_df = pd.read_csv(nodes_csv, encoding='utf-8-sig')
    print(f"\n노드 CSV 로드: {len(nodes_df)}개")
    
    # 노드 타입별로 배치 적재
    node_types = nodes_df['type'].unique()
    
    for node_type in node_types:
        type_nodes = nodes_df[nodes_df['type'] == node_type]
        print(f"\n{node_type} 노드 적재 중... ({len(type_nodes)}개)")
        
        # 배치 크기 설정
        batch_size = 100
        
        for batch_start in range(0, len(type_nodes), batch_size):
            batch_end = min(batch_start + batch_size, len(type_nodes))
            batch = type_nodes.iloc[batch_start:batch_end]
            
            # 배치별 쿼리 생성
            queries = []
            for _, row in batch.iterrows():
                props = {}
                for col in type_nodes.columns:
                    if col not in ['id', 'type'] and pd.notna(row[col]):
                        value = row[col]
                        # 숫자 변환 시도
                        try:
                            if isinstance(value, (int, float)) or (isinstance(value, str) and value.replace('.', '').replace('-', '').isdigit()):
                                value = float(value) if '.' in str(value) else int(float(value))
                        except:
                            pass
                        props[col] = value
                
                # CREATE 쿼리 작성
                prop_strs = [f"{k}: ${k}" for k in props.keys()]
                create_props = ", ".join(["id: $id"] + prop_strs)
                query = f"CREATE (n:{node_type} {{{create_props}}})"
                params = {"id": row['id'], **props}
                queries.append((query, params))
            
            # 배치 실행
            for query, params in queries:
                try:
                    session.run(query, **params)
                except Exception as e:
                    print(f"  ⚠ 오류: {params.get('id')} - {e}")
            
            if (batch_start // batch_size + 1) % 10 == 0:
                print(f"  진행 중: {batch_end}/{len(type_nodes)} ({batch_end*100//len(type_nodes)}%)")
        
        print(f"  ✓ {node_type} 노드 적재 완료")
    
    # 관계 CSV 읽기 및 배치 적재
    relationships_df = pd.read_csv(relationships_csv, encoding='utf-8-sig')
    print(f"\n관계 CSV 로드: {len(relationships_df)}개")
    
    batch_size = 500
    for batch_start in range(0, len(relationships_df), batch_size):
        batch_end = min(batch_start + batch_size, len(relationships_df))
        batch = relationships_df.iloc[batch_start:batch_end]
        
        for _, rel in batch.iterrows():
            query = f"""
            MATCH (from:{rel['from_type']} {{id: $from_id}})
            MATCH (to:{rel['to_type']} {{id: $to_id}})
            MERGE (from)-[:{rel['relationship_type']}]->(to)
            """
            try:
                session.run(query, from_id=rel['from_id'], to_id=rel['to_id'])
            except Exception as e:
                print(f"  ⚠ 관계 오류: {rel['from_id']} -> {rel['to_id']} - {e}")
        
        if (batch_start // batch_size + 1) % 5 == 0:
            print(f"  진행 중: {batch_end}/{len(relationships_df)} ({batch_end*100//len(relationships_df)}%)")
    
    print(f"  ✓ 관계 적재 완료: {len(relationships_df)}개")
    
    # 최종 통계
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    print(f"\n✓ Neo4j 데이터 적재 완료: 노드 {node_count}개, 관계 {rel_count}개")

# 데이터 상태 확인 및 적재
with get_neo4j_session() as session:
    # 현재 상태 확인
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    
    # 예상 데이터 개수 (CSV 확인)
    NODES_CSV = "data/processed/neo4j_nodes.csv"
    REL_CSV = "data/processed/neo4j_relationships.csv"
    
    expected_nodes = 0
    expected_rels = 0
    
    if os.path.exists(NODES_CSV):
        nodes_df = pd.read_csv(NODES_CSV, encoding='utf-8-sig')
        expected_nodes = len(nodes_df)
    
    if os.path.exists(REL_CSV):
        rels_df = pd.read_csv(REL_CSV, encoding='utf-8-sig')
        expected_rels = len(rels_df)
    
    print(f"\n{'='*60}")
    print("Neo4j 데이터 상태 확인")
    print(f"{'='*60}")
    print(f"현재 노드: {node_count}개 (예상: {expected_nodes}개)")
    print(f"현재 관계: {rel_count}개 (예상: {expected_rels}개)")
    
    # 데이터가 없거나 불완전한 경우 적재
    if node_count == 0 or node_count < expected_nodes * 0.9:  # 90% 미만이면 재적재
        if node_count > 0:
            print(f"\n⚠ 데이터가 불완전합니다. 재적재를 진행합니다...")
        else:
            print(f"\n데이터 적재 시작...")
        
        if os.path.exists(NODES_CSV) and os.path.exists(REL_CSV):
            load_neo4j_data(NODES_CSV, REL_CSV, session)
        else:
            print(f"\n✗ CSV 파일을 찾을 수 없습니다:")
            print(f"  - {NODES_CSV}")
            print(f"  - {REL_CSV}")
            print("  먼저 3_preprocessing.ipynb를 실행하여 데이터를 생성하세요.")
    else:
        print(f"\n✓ Neo4j 데이터가 정상적으로 적재되어 있습니다.")
        
        # 노드 타입별 통계
        print("\n노드 타입별 통계:")
        for label in session.run("CALL db.labels()").values():
            label_name = label[0]
            count = session.run(f"MATCH (n:{label_name}) RETURN count(n) as count").single()["count"]
            print(f"  - {label_name}: {count}개")
        
        # 관계 통계 확인
        print("\n관계 통계:")
        rel_stats = session.run("""
        MATCH ()-[r]->()
        RETURN type(r) as rel_type, count(r) as count
        ORDER BY count DESC
        """).data()
        for stat in rel_stats:
            print(f"  - {stat['rel_type']}: {stat['count']}개")
        
        # 예시: 강남구 관계 확인 (IN 관계)
        print("\n강남구 관계 확인 (예시):")
        gangnam_test = session.run("""
        MATCH (s:Shelter)-[r:IN]->(a:Admin {gu: '강남구'})
        RETURN count(s) as shelter_count
        """).single()
        if gangnam_test:
            print(f"  - 강남구 Shelter 노드 수 (IN 관계): {gangnam_test['shelter_count']}개")
        else:
            print("  - 강남구 관계를 찾을 수 없습니다.")
# Out:
# ============================================================
# Neo4j 데이터 상태 확인
# ============================================================
# 현재 노드: 3982개 (예상: 3982개)
# 현재 관계: 6797개 (예상: 3957개)
#
# ✓ Neo4j 데이터가 정상적으로 적재되어 있습니다.
#
# 노드 타입별 통계:
#   - Admin: 25개
#   - Shelter: 3136개
#   - Hazard: 0개
#   - TemporaryHousing: 821개
#
# 관계 통계:
#   - IN: 6797개
#
# 강남구 관계 확인 (예시):
#   - 강남구 Shelter 노드 수 (IN 관계): 449개

# %%
# Ollama 설정
OLLAMA_BASE_URL = os.getenv("OLLAMA_BASE_URL", "http://localhost:11434")
OLLAMA_MODEL = "gemma3:4b"

def ollama_generate(prompt: str, model: str = OLLAMA_MODEL) -> str:
    """Ollama를 사용하여 텍스트를 생성합니다."""
    url = f"{OLLAMA_BASE_URL}/api/generate"
    
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }
    
    try:
        response = requests.post(url, json=payload, timeout=120)
        response.raise_for_status()
        result = response.json()
        answer = result.get("response", "").strip()
        # 응답이 비어있으면 None 반환
        if not answer:
            print("⚠ Ollama 응답이 비어있습니다.")
            return None
        # 디버깅을 위해 응답 일부만 출력 (너무 길면 자르기)
        if len(answer) > 200:
            print(f"✓ Ollama 응답 생성: {answer[:200]}...")
        else:
            print(f"✓ Ollama 응답 생성: {answer}")
        return answer
    except requests.exceptions.RequestException as e:
        print(f"✗ Ollama API 호출 오류: {e}")
        return None

# Ollama 연결 확인
try:
    test_response = ollama_generate("안녕하세요")
    if test_response:
        print(f"✓ Ollama 연결 성공: {OLLAMA_BASE_URL}")
        print(f"✓ 모델: {OLLAMA_MODEL}")
        print(f"  테스트 응답: {test_response[:50]}...")
    else:
        print(f"✗ Ollama 연결 실패: 응답이 없습니다.")
except Exception as e:
    print(f"✗ Ollama 연결 실패: {e}")
    print(f"  Ollama가 실행 중인지 확인하세요: ollama serve")
    print(f"  모델이 설치되어 있는지 확인하세요: ollama list")
# Out:
# ✓ Ollama 응답 생성: 안녕하세요! 무엇을 도와드릴까요? 궁금한 점이 있거나, 필요한 정보가 있다면 언제든지 말씀해주세요. 😊
# ✓ Ollama 연결 성공: http://localhost:11434
# ✓ 모델: gemma3:4b
#   테스트 응답: 안녕하세요! 무엇을 도와드릴까요? 궁금한 점이 있거나, 필요한 정보가 있다면 언제든지 말씀...

# %% [markdown]
# ## 2. Neo4j 스키마 정보 가져오기

# %%
def get_neo4j_schema(session) -> str:
    """Neo4j 그래프 스키마 정보를 가져옵니다."""
    
    # 노드 라벨 조회
    node_labels_query = "CALL db.labels()"
    node_labels = [record["label"] for record in session.run(node_labels_query)]
    
    # 관계 타입 조회
    rel_types_query = "CALL db.relationshipTypes()"
    rel_types = [record["relationshipType"] for record in session.run(rel_types_query)]
    
    # 실제로 사용되는 관계 타입만 필터링 (LOCATED_IN 제외)
    # 실제 데이터에서 사용되는 관계만 포함
    actual_rels = []
    for rel_type in rel_types:
        count = session.run(f"MATCH ()-[r:{rel_type}]->() RETURN count(r) as count").single()["count"]
        if count > 0:  # 실제로 데이터가 있는 관계만 포함
            actual_rels.append(rel_type)
    
    # 노드별 속성 정보 조회
    node_properties = {}
    for label in node_labels:
        props_query = f"""
        MATCH (n:{label})
        RETURN keys(n) as props
        LIMIT 1
        """
        result = session.run(props_query)
        record = result.single()
        if record:
            node_properties[label] = record["props"]
    
    # 스키마 문자열 생성
    schema_parts = ["# Neo4j Graph Schema\n\n"]
    
    schema_parts.append("## Node Labels:\n")
    for label in node_labels:
        props = node_properties.get(label, [])
        props_str = ", ".join(props) if props else "(no properties)"
        schema_parts.append(f"- {label}: {{{props_str}}}")
    
    schema_parts.append("\n## Relationship Types:\n")
    # 실제 사용되는 관계 타입만 표시
    for rel_type in actual_rels:
        schema_parts.append(f"- {rel_type}")
    
    return "\n".join(schema_parts)

# 스키마 정보 확인
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    print(schema)
# Out:
# # Neo4j Graph Schema
#
#
# ## Node Labels:
#
# - Admin: {gu, sido, id, sigungu}
# - Shelter: {shelter_id, sido, shelter_type, area, sigungu, name, id, address, lat, lon}
# - Hazard: {(no properties)}
# - TemporaryHousing: {facility_id, sido, address, sigungu, id, area, name, lat, lon}
#
# ## Relationship Types:
#
# - IN

# %% [markdown]
# ## 3. Graph RAG 검색 함수

# %%
def generate_cypher_query(question: str, schema: str) -> str:
    """Ollama를 사용하여 자연어 질문을 Cypher 쿼리로 변환합니다."""
    
    prompt = f"""
당신은 Neo4j Cypher 쿼리 전문가입니다.
다음 그래프 스키마 정보를 참고하여, 사용자의 자연어 질문을 Cypher 쿼리로 변환하세요.

# Graph Schema:
{schema}

# 중요: 관계 타입은 'IN'만 사용하세요. 'LOCATED_IN'이나 'INTERSECTS'는 사용하지 마세요.
# 예시:
# - "몇 개" 질문: MATCH (s:Shelter)-[:IN]->(a:Admin {{gu: '강남구'}}) RETURN count(s)
# - "알려주세요" 질문: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10

# 사용자 질문:
{question}

지침:
1. 질문의 의도를 정확히 파악하여 적절한 Cypher 쿼리를 생성하세요.
2. 노드 라벨과 관계 타입을 정확히 사용하세요. 특히 관계는 'IN'만 사용해야 합니다.
3. **중요**: "알려주세요", "찾고 싶어요", "알려주세요" 같은 질문이면 반드시 실제 대피소 정보를 반환하도록 RETURN 절을 작성하세요.
   - 예: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
   - 또는: MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s.name, s.address, s.shelter_type LIMIT 10
   - COUNT()를 사용하지 마세요. 실제 노드 정보를 반환해야 합니다.
4. "몇 개" 또는 "개수" 질문이면 COUNT()를 사용하세요.
5. 쿼리만 반환하고 설명은 제외하세요.

Cypher 쿼리:
"""
    
    try:
        response = ollama_generate(prompt.strip())
        
        if not response:
            return None
        
        cypher_query = response.strip()
        # 코드 블록 제거 (```cypher 등)
        if cypher_query.startswith("```"):
            lines = cypher_query.split("\n")
            cypher_query = "\n".join(lines[1:-1]) if len(lines) > 2 else cypher_query
        
        return cypher_query
    except Exception as e:
        print(f"Cypher 쿼리 생성 오류: {e}")
        return None

# %%
def graph_rag_search(question: str, schema: str, session) -> Dict:
    """Graph RAG 검색: Neo4j에서 구조화된 정보를 검색합니다."""
    
    # 1. Cypher 쿼리 생성
    cypher_query = generate_cypher_query(question, schema)
    
    if not cypher_query:
        return {"query": None, "results": [], "count": 0, "error": "Cypher 쿼리 생성 실패"}
    
    print(f"\n[생성된 Cypher 쿼리]\n{cypher_query}\n")
    
    # 2. 쿼리 실행
    try:
        result = session.run(cypher_query)
        records = [dict(record) for record in result]
        
        # COUNT 등의 집계 함수 결과 처리
        # 집계 쿼리는 단일 레코드를 반환하므로, 결과 값 자체를 카운트로 사용
        actual_count = len(records)
        if actual_count == 1 and records:
            # COUNT 쿼리 결과 추출 시도
            for key, value in records[0].items():
                if 'count' in key.lower() or isinstance(value, (int, float)):
                    actual_count = int(value) if isinstance(value, (int, float)) else actual_count
        
        return {
            "query": cypher_query,
            "results": records,
            "count": actual_count
        }
    except Exception as e:
        print(f"  ⚠ Cypher 쿼리 실행 오류: {e}")
        return {
            "query": cypher_query,
            "results": [],
            "count": 0,
            "error": str(e)
        }

# %% [markdown]
# ## 4. Vector RAG 검색 함수

# %%
def vector_rag_search(question: str, collection, top_k: int = 5) -> Dict:
    """Vector RAG 검색: Chroma에서 관련 문서를 검색합니다."""
    
    if collection is None:
        return {"results": [], "error": "Chroma 컬렉션이 없습니다."}
    
    try:
        # 질문을 임베딩으로 변환하여 검색 (Chroma가 자동으로 처리)
        results = collection.query(
            query_texts=[question],
            n_results=top_k
        )
        
        documents = []
        for i in range(len(results["ids"][0])):
            doc_id = results["ids"][0][i]
            doc_text = results["documents"][0][i] if results["documents"] else ""
            distance = results["distances"][0][i] if results["distances"] else None
            
            documents.append({
                "id": doc_id,
                "text": doc_text,
                "distance": distance
            })
        
        return {
            "results": documents,
            "count": len(documents)
        }
    except Exception as e:
        return {
            "results": [],
            "error": str(e)
        }

# %% [markdown]
# ## 5. Hybrid RAG: Graph + Vector 병합

# %%
def format_graph_results(graph_results: Dict, max_length: int = 2000) -> str:
    """Graph RAG 결과를 텍스트로 포맷팅합니다."""
    
    if graph_results.get("error"):
        return f"오류: {graph_results['error']}"
    
    result_count = graph_results.get('count', 0)
    result_parts = ["# Graph RAG 검색 결과\n"]
    result_parts.append(f"Cypher 쿼리: {graph_results.get('query', 'N/A')}\n")
    result_parts.append(f"결과 개수: {result_count}\n")
    
    if not graph_results.get("results"):
        result_parts.append("\n검색 결과가 없습니다.")
    else:
        results = graph_results["results"]
        # 결과가 많으면 요약
        if len(results) > 20:
            result_parts.append(f"\n## 요약: 총 {len(results)}개 결과 중 처음 10개만 표시\n")
            results = results[:10]
        
        for i, record in enumerate(results, 1):
            result_parts.append(f"\n## 결과 {i}")
            for key, value in record.items():
                # 값이 너무 길면 자르기
                value_str = str(value)
                if len(value_str) > 200:
                    value_str = value_str[:200] + "..."
                result_parts.append(f"- {key}: {value_str}")
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략 - 결과가 너무 많습니다]"
    
    return text


def format_vector_results(vector_results: Dict, max_length: int = 3000) -> str:
    """Vector RAG 결과를 텍스트로 포맷팅합니다."""
    
    if vector_results.get("error"):
        return f"오류: {vector_results['error']}"
    
    if not vector_results.get("results"):
        return "검색 결과가 없습니다."
    
    result_parts = ["# Vector RAG 검색 결과\n"]
    result_parts.append(f"결과 개수: {vector_results.get('count', 0)}\n")
    
    for i, doc in enumerate(vector_results["results"], 1):
        result_parts.append(f"\n## 문서 {i} (거리: {doc.get('distance', 'N/A')})")
        doc_text = doc.get('text', '')
        # 문서가 너무 길면 자르기
        if len(doc_text) > 800:
            doc_text = doc_text[:800] + "..."
        result_parts.append(doc_text)
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략]"
    
    return text


def extract_shelter_info(graph_results: Dict, question: str = "") -> str:
    """Graph RAG 결과에서 대피소 정보를 추출하여 형식화된 답변을 생성합니다."""
    
    if not graph_results.get("results"):
        return None
    
    results = graph_results["results"]
    count = graph_results.get("count", 0)
    
    # Shelter 노드 정보 추출
    shelters = []
    
    for record in results:
        # record는 딕셔너리 형태: {'s': <Node ...>} 또는 {'name': '...', 'address': '...'} 등
        for key, value in record.items():
            # Neo4j Node 객체인 경우 (properties 속성이 있음)
            if hasattr(value, 'properties'):
                try:
                    props = value.properties
                    # Shelter 노드인지 확인 (labels 확인)
                    is_shelter = False
                    if hasattr(value, '_labels'):
                        labels = value._labels
                        is_shelter = 'Shelter' in labels or isinstance(labels, frozenset) and 'Shelter' in labels
                    elif hasattr(value, 'labels'):
                        labels = value.labels
                        is_shelter = 'Shelter' in labels
                    else:
                        # labels 속성이 없으면 문자열로 확인
                        value_str = str(value)
                        is_shelter = 'Shelter' in value_str or 'shelter' in key.lower()
                    
                    if is_shelter or 'name' in props or 'address' in props:  # Shelter 속성이 있으면 추가
                        shelter_name = props.get('name', '이름 없음')
                        shelter_address = props.get('address', '주소 없음')
                        shelter_type = props.get('shelter_type', '')
                        # 실제 값이 있는 경우만 추가
                        if shelter_name != '이름 없음' or shelter_address != '주소 없음':
                            shelters.append({
                                'name': shelter_name,
                                'address': shelter_address,
                                'type': shelter_type
                            })
                except Exception as e:
                    # properties 접근 실패 시 무시
                    pass
            # 딕셔너리인 경우 (직접 속성이 있는 경우 또는 dict(record)로 변환된 경우)
            elif isinstance(value, dict):
                if 'name' in value or 'address' in value or 'shelter_type' in value:
                    shelters.append({
                        'name': value.get('name', value.get('s.name', '이름 없음')),
                        'address': value.get('address', value.get('s.address', '주소 없음')),
                        'type': value.get('shelter_type', value.get('s.shelter_type', ''))
                    })
        # record 자체가 속성 딕셔너리인 경우 (RETURN s.name, s.address 같은 쿼리)
        # 모든 값을 확인했는데도 shelters에 추가되지 않은 경우
        if isinstance(record, dict):
            # record의 직접 속성 확인 (RETURN s.name 같은 경우)
            if 'name' in record or 'address' in record:
                record_name = record.get('name', record.get('s.name', ''))
                record_address = record.get('address', record.get('s.address', ''))
                if record_name or record_address:
                    # 중복 체크
                    is_duplicate = any(
                        s.get('name') == record_name and s.get('address') == record_address 
                        for s in shelters
                    )
                    if not is_duplicate:
                        shelters.append({
                            'name': record_name if record_name else '이름 없음',
                            'address': record_address if record_address else '주소 없음',
                            'type': record.get('shelter_type', record.get('s.shelter_type', ''))
                        })
    
    # Shelter 정보가 없으면 None 반환
    if not shelters:
        # 디버깅: 결과 구조 확인
        if results:
            print(f"  ⚠ 대피소 정보 추출 실패: 결과 {len(results)}개, 첫 번째 결과 타입: {type(results[0])}")
            if isinstance(results[0], dict):
                print(f"    첫 번째 결과 키: {list(results[0].keys())}")
                for key, value in list(results[0].items())[:3]:  # 처음 3개만
                    print(f"    - {key}: {type(value)}")
        return None
    
    # 중복 제거 (name과 address가 같은 경우)
    unique_shelters = []
    seen = set()
    for shelter in shelters:
        # '이름 없음'이나 '주소 없음'은 제외
        if shelter['name'] != '이름 없음' and shelter['address'] != '주소 없음':
            key = (shelter['name'], shelter['address'])
            if key not in seen:
                seen.add(key)
                unique_shelters.append(shelter)
    
    # 중복 제거 후에도 없으면 None
    if not unique_shelters:
        return None
    
    # 최대 10개만 표시
    display_shelters = unique_shelters[:10]
    remaining_count = len(unique_shelters) - len(display_shelters)
    
    # 질문에서 구 이름 추출
    import re
    gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
    gu_name = gu_match.group(1) if gu_match else ""
    
    # 답변 생성
    answer_parts = []
    
    if count > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {count}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {count}개의 대피소를 찾았습니다.\n")
    elif len(unique_shelters) > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
    
    if display_shelters:
        answer_parts.append("주요 대피소 목록:")
        for i, shelter in enumerate(display_shelters, 1):
            shelter_type = shelter['type'] if shelter['type'] else '대피소'
            answer_parts.append(f"{i}. {shelter['name']} ({shelter_type})")
            if shelter['address'] and shelter['address'] != '주소 없음':
                answer_parts.append(f"   주소: {shelter['address']}")
        
        if remaining_count > 0:
            answer_parts.append(f"\n이 외에 {remaining_count}개의 대피소가 더 있습니다.")
    
    return "\n".join(answer_parts) if answer_parts else None

# %%
def hybrid_rag(question: str, schema: str, neo4j_session, chroma_collection) -> Dict:
    """Hybrid RAG: Graph RAG와 Vector RAG를 결합하여 검색하고 답변을 생성합니다."""
    
    # 1. Graph RAG 검색
    print("=" * 60)
    print("[Graph RAG 검색 중...]")
    graph_results = graph_rag_search(question, schema, neo4j_session)
    
    # 2. Vector RAG 검색
    print("\n" + "=" * 60)
    print("[Vector RAG 검색 중...]")
    vector_results = vector_rag_search(question, chroma_collection)
    
    # 3. 결과 포맷팅 (길이 제한)
    graph_text = format_graph_results(graph_results, max_length=2000)
    vector_text = format_vector_results(vector_results, max_length=3000)
    
    # 4. Ollama를 사용하여 최종 답변 생성
    print("\n" + "=" * 60)
    print("[Ollama를 통한 최종 답변 생성 중...]")
    print("  프롬프트 길이:", len(f"{question}\n{graph_text}\n{vector_text}"), "자")
    
    # 간결한 프롬프트 생성
    # 질문 유형에 따라 다른 지침 제공
    if '알려주세요' in question or '찾고 싶어요' in question or '어디' in question:
        instructions = """- Graph RAG 결과에 실제 대피소 목록이 있으면 구체적인 이름과 주소를 제시하세요
- 대피소가 많으면 주요 대피소 몇 개를 예시로 제시하고, 총 개수를 알려주세요
- 간결하고 실행 가능한 답변 제공"""
    else:
        instructions = """- 구체적인 데이터(개수, 위치 등)를 명확히 제시
- 간결하고 실행 가능한 답변 제공
- 근거를 간단히 명시"""
    
    final_prompt = f"""재난대응 전문가로서 아래 질문에 답변하세요.

질문: {question}

[Graph RAG 결과]
{graph_text}

[Vector RAG 결과]  
{vector_text}

지침:
{instructions}

답변:"""
    
    try:
        # "알려주세요", "찾고 싶어요" 같은 질문에 대해 먼저 extract_shelter_info로 구체적인 답변 생성
        graph_count = graph_results.get('count', 0)
        is_list_question = '알려주세요' in question or '찾고 싶어요' in question or ('어디' in question and graph_count > 0)
        
        extracted_info = None
        if is_list_question and graph_count > 0:
            # Graph RAG 결과에서 대피소 정보 추출
            extracted_info = extract_shelter_info(graph_results, question)
            if extracted_info:
                print(f"  ✓ 대피소 정보 추출 완료: {len(extracted_info)}자")
        
        final_answer = ollama_generate(final_prompt.strip())
        
        # Ollama 응답 검증: 구체적인 대피소 정보가 포함되어 있는지 확인
        if final_answer and is_list_question and extracted_info:
            # Ollama 답변에 구체적인 대피소 이름이나 주소가 포함되어 있는지 확인
            has_specific_info = any(keyword in final_answer for keyword in ['주소:', '위치:', '명', '곳', '서울', '구'])
            # Ollama 답변이 일반적인 설명만 포함하고 있으면 추출된 정보 사용
            if not has_specific_info or len(final_answer) < 100:
                print(f"  ⚠ Ollama 답변이 일반적입니다. 추출된 정보를 사용합니다.")
                final_answer = extracted_info
        
        # Ollama 응답이 None이거나 비어있는 경우 fallback 답변 생성
        if not final_answer or (isinstance(final_answer, str) and final_answer.strip() == ""):
            print("  ⚠ Ollama 응답 생성 실패: 응답이 None이거나 비어있습니다.")
            # Fallback: 추출된 정보 또는 Graph RAG 결과 기반으로 답변 생성
            
            # 질문에서 구 이름 및 키워드 추출
            import re
            gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
            gu_name = gu_match.group(1) if gu_match else ""
            
            # 질문 유형에 따라 답변 생성
            if '몇 개' in question or '개수' in question or 'count' in question.lower():
                if graph_count > 0:
                    if gu_name:
                        final_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다."
                    else:
                        final_answer = f"검색 결과: {graph_count}개를 찾았습니다."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어디' in question or '위치' in question or '알려주세요' in question or '찾고 싶어요' in question:
                if extracted_info:
                    final_answer = extracted_info
                elif graph_count > 0:
                    final_answer = f"{gu_name if gu_name else '해당 지역'}에 있는 대피소는 총 {graph_count}개입니다. 상세 정보는 Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어떻게' in question or '행동' in question:
                # Vector RAG 결과를 활용한 답변
                vector_count = vector_results.get('count', 0)
                if vector_count > 0:
                    final_answer = "Vector RAG 검색 결과에 관련 행동 요령이 포함되어 있습니다. 문서를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            else:
                if graph_count > 0:
                    final_answer = f"검색 결과를 {graph_count}개 찾았습니다. Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            
            print(f"  ✓ Fallback 답변 생성: {final_answer[:50]}...")
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": final_answer
        }
    except Exception as e:
        print(f"  ⚠ 최종 답변 생성 오류: {e}")
        # Fallback 답변 생성
        graph_count = graph_results.get('count', 0)
        
        # 질문에서 구 이름 추출
        import re
        gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
        gu_name = gu_match.group(1) if gu_match else "해당 구"
        
        if '몇 개' in question or '개수' in question:
            if graph_count > 0:
                fallback_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        else:
            if graph_count > 0:
                fallback_answer = f"검색 결과를 {graph_count}개 찾았습니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": fallback_answer,
            "error": str(e)
        }

# %% [markdown]
# ## 6. 테스트 질의 실행

# %%
# Neo4j 스키마 가져오기
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    # 시민 시나리오 테스트 질의
    test_questions = [
        "강남구에 있는 대피소는 몇 개인가요?",
        "지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.",
        "임시주거시설은 어디에 있나요?",
        "지진 발생 시 어떻게 행동해야 하나요?",
        "공습경보가 발령되면 어떻게 해야 하나요?",
        "서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?"
    ]
    
    # 첫 번째 질의 테스트
    question = test_questions[0]
    print(f"\n{'='*60}")
    print(f"질문: {question}")
    print(f"{'='*60}\n")
    
    result = hybrid_rag(
        question=question,
        schema=schema,
        neo4j_session=session,
        chroma_collection=chroma_collection
    )
    
    print("\n" + "=" * 60)
    print("=" * 60)
    print(result.get("answer", "답변 생성 실패"))
# Out:
# ============================================================
# 질문: 강남구에 있는 대피소는 몇 개인가요?
# ============================================================
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sido = '서울특별시' AND s.sigungu = '강남구' RETURN count(s)
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sido = '서울특별시' AND s.sigungu = '강남구' RETURN count(s)
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3177 자
# ✓ Ollama 응답 생성: 강남구에 있는 대피소는 총 240개입니다. (출처: Graph RAG 검색 결과)
#
# ============================================================
# ============================================================
# 강남구에 있는 대피소는 총 240개입니다. (출처: Graph RAG 검색 결과)

# %%
# 여러 질의 일괄 실행
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    results = []
    for i, question in enumerate(test_questions, 1):
        print(f"\n\n{'#'*60}")
        print(f"질의 {i}/{len(test_questions)}: {question}")
        print(f"{'#'*60}\n")
        
        result = hybrid_rag(
            question=question,
            schema=schema,
            neo4j_session=session,
            chroma_collection=chroma_collection
        )
        
        results.append(result)
        
        print(f"\n{'='*60}")
        print("[최종 답변]")
        print(f"{'='*60}")
        print(result)
        print(result.get("answer", "답변 생성 실패"))
        print(f"\n{'='*60}\n")
# Out:
# ############################################################
# 질의 1/6: 강남구에 있는 대피소는 몇 개인가요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sido = '서울특별시' AND s.sigungu = '강남구' RETURN count(s)
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sido = '서울특별시' AND s.sigungu = '강남구' RETURN count(s)
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3177 자
# ✓ Ollama 응답 생성: 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 검색 결과: count(s): 240)
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '강남구에 있는 대피소는 몇 개인가요?', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.sido = '서울특별시' AND s.sigungu = '강남구' RETURN count(s)", 'results': [{'count(s)': 240}], 'count': 240}, 'vector_results': {'results': [{'id': '화재행동요령', 'text': '# 재난 행동요령: 화재\n\n## 평소 대비 요령\n\n### 1. 사전점검\n\n화재 예방을 위해 평소에 다음과 같이 확인합니다.\n\n#### 눈으로 확인\n- 사용하지 않는 전열기구 코드를 확인합니다.\n- 가스레인지 중간 벨브 잠금을 확인합니다.\n\n#### 귀로 확인\n- 평소에 나지 않던 이상한 소리를 확인합니다.\n\n#### 코로 확인\n- 타는 냄새가 나지 않는지 확인합니다.\n\n#### 손으로 확인\n- 만져보거나 두들겨 봅니다.\n\n#### 행동으로 확인\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n### 2. 대피훈련\n\n화재 상황에 대비한 훈련을 정기적으로 실시합니다.\n\n- 배워보자: 소화기 사용법, 표시해보자: 2곳 이상의 비상통로, 찾아보자: 대피장소, 막아보자: 문틈\n- 전화해보자: 우리 가족, 정해보자: 만날 장소, 어디있을까: 경량칸막이\n\n### 3. 비상용품 준비\n\n- 대피방법과 대피해서 만나는 장소를 사전에 약속합니다.\n- 대피할때 가져가야할 중요물건 목록을 작성하고 챙길 사람을 선정합니다.\n- 비상연락 전화번호 및 연락해야 할 대상을 선정합니다.\n- 문틈을 막아야할 경우 청테이프 또는 수건을 준비합니다.\n- 외부 대피 시 사용할 수건 등 대피에 사용할 물건을 준비합니다.\n- 긴급 대피한 경우 만날 장소와 비상연락망을 정해둡니다.\n\n---\n\n## 화재 발생 시 행동 요령\n\n### 화재경보가 울릴 때\n\n#### 1. 주변 사람에게 알립니다.\n\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려고 하기보다는 소리를 질러 주변 사람에게 알립니다.\n\n#### 2. 대피방법을 결정합니다.\n\n- 손등으로 출입문 손잡이를 만져보아 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져 보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n#### 3. 신속히 대피합니다.\n\n- 대피할 때는 엘리베이터를 절대 이용하지 않고 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n#### 4. 119로 신고합니다.\n\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n#### 5. 대피 후 인원을 확인합니다.\n\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n### 불을 발견했을 때\n\n#### 1. 연기가 발생하거나 불이 난 것을 보았을 때\n\n- 불이 난 것을 발견하면 "불이야!"라고 소리치거나 비상벨을 눌러 주변에 알리도록 합니다.\n\n#### 2. 불을 끌 것인지 대피할 것인지 판단합니다.\n\n- 불길이 천장까지 닿지 않은 작은 불이라면 소화기나 물양동이 등을 활용하여 신속히 끄도록 합니다.\n- 불길이 커져서 대피해야 할 경우 젖은 수건 또는 담요를 활용하여 계단을 통해 밖으로 대피합니다.\n- 세대 밖으로 대피가 어려운 경우 경량칸막이를 이용하여 이웃집으로 대피하거나 완강기를 이용하여 창문으로 나가는 방법, 실내대피 공간으로 대피하였다가 불이 꺼진 후 나오는 방법 등을 활용합니다.\n\n### 소화기 사용법\n\n#### 실내에서 사용할 때는 밖으로 대피할 때를 대비하여 문을 등지고\n\n1. 소화기를 가져와서 몸통을 단단히 잡고 안전핀을 뽑습니다.\n2. 노즐을 잡고 불쪽을 향해 가까이 이동합니다.\n3. 손잡이를 꽉 움켜쥡니다.\n4. 분말이 골고루 불을 덮을 수 있도록 쏩니다.\n\n### 완강기 사용법\n\n1. 지지대 고리에 완강기 고리를 걸고 잠근다.\n2. 지지대를 창밖으로 밀고 릴(줄)을 던진다.\n3. 완강기 벨트를 가슴 높이까지 걸고 조인다.\n4. 벽을 짚으며 안전하게 내려간다.\n\n### 옷에 불이 붙었을 때\n\n1. 옷에 불이 붙었을 때는 하던 일을 멈춥니다.\n2. 얼굴(눈, 코, 입)에 화상을 입지 않도록 두 손으로 감싼다.\n3. 바닥에 엎드린 후 몸을 뒹굴어서 불이 꺼지도록 합니다.\n\n---\n\n## 화재 대피 후 행동 요령\n\n### 1. 가족의 상황을 확인하고 부상자에 대한 응급처치를 실시합니다.\n\n- 대피 후 가족 모두의 안전 여부를 확인합니다.\n- 부상자가 있으면 응급처치를 실시하고 119에 신고하여 이송받습니다.\n\n### 2. 주변의 피해 상황을 파악합니다.\n\n- 대피 후 집으로 돌아온 경우 반드시 주택 등의 안전 여부를 확인하고 출입합니다.\n- 파손된 시설물(주택, 상하수도 등)은 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n\n### 3. 파손된 물품에 대한 기록을 남깁니다.\n\n- 파손된 사유시설을 보수 또는 복구할 때에는 반드시 사진을 찍어 둡니다.\n\n### 4. 올바른 정보를 확인합니다.\n\n- 근거 없는 유언비어에 유의하고, TV·라디오나 공공기관에서 제공하는 정보를 확인합니다.\n- 정부 안내방송을 계속 청취하고 이에 따라 행동합니다.\n\n### 5. 재난 상황에 따라 행동합니다.\n\n- 화재가 계속 진행 중이면 추가 대피 지시에 따릅니다.\n- 대피소에 도착한 후에는 도착사실을 알리고 통제에 따릅니다.\n- 구조 활동에 적극 협조합니다.\n', 'distance': 0.9835575819015503}, {'id': '지진행동요령', 'text': '# 재난 행동요령: 지진\n\n## 평소 대비 요령\n\n### 1. 집 안에서의 안전을 확보합니다.\n\n- 탁자 아래와 같이 집 안에서 대피할 수 있는 안전한 대피 공간을 미리 파악해 둡니다.\n- 유리창이나 넘어지기 쉬운 가구 주변 등 위험한 위치를 확인해 두고 지진 발생 시 가까이 가지 않도록 합니다.\n- 깨진 유리 등에 다치지 않도록 두꺼운 실내화를 준비해 둡니다.\n- 화재를 일으킬 수 있는 난로나 위험물은 주의하여 관리합니다.\n\n### 2. 집 안에서 떨어지기 쉬운 물건을 고정합니다.\n\n- 가구나 가전제품이 흔들릴 때 넘어지지 않도록 고정해 둡니다.\n- 텔레비전, 꽃병 등 떨어질 수 있는 물건은 높은 곳에 두지 않도록 합니다.\n- 그릇장 안의 물건들이 쏟아지지 않도록 문을 고정해 둡니다.\n- 창문 등의 유리 부분은 필름을 붙여 유리가 파손되지 않도록 합니다.\n\n### 3. 집을 안전하게 관리합니다.\n\n- 가스 및 전기를 미리 점검합니다.\n- 건물이나 담장은 수시로 점검하고, 위험한 부분은 안전하게 수리합니다.\n- 건물의 균열을 발견하면 전문가에게 문의하여 보수하고 보강합니다.\n\n### 4. 평상시 가족회의를 통하여 위급한 상황에 대비합니다.\n\n- 가스 및 전기를 차단하는 방법을 알아 둡니다.\n- 머물고 있는 곳 주위의 넓은 공간 등 대피할 수 있는 장소를 알아 둡니다.\n- 비상시 가족과 만날 곳과 연락할 방법을 정해 둡니다.\n- 응급처치하는 방법을 반복적으로 훈련하여 익혀 둡니다.\n\n### 5. 평소 비상용품을 잘 준비해 둡니다.\n\n- 지진에 대비하여 비상용품을 준비해 두고, 보관 장소와 사용방법을 알아 둡니다.\n- 지진 발생 시 화재가 발생할 수 있으니 소화기를 준비해 두고, 사용방법을 알아 둡니다.\n\n---\n\n## 지진 발생 시 행동 요령\n\n### 1. 지진으로 흔들릴 때는?\n\n- 지진으로 흔들리는 동안은 탁자 아 ...
# 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 검색 결과: count(s): 240)
#
# ============================================================
#
#
#
# ############################################################
# 질의 2/6: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 5080 자
#   ⚠ 대피소 정보 추출 실패: 결과 10개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['s']
#     - s: <class 'neo4j.graph.Node'>
# ✓ Ollama 응답 생성: 서초구에서 지진 발생 시 대피할 수 있는 옥외 대피소는 총 5곳입니다. Graph RAG 검색 결과에서 확인된 대피소 정보는 다음과 같습니다.
#
# *   **옥외대피소 1:** 서초구 반포대로 217(반포동)
# *   **옥외대피소 2:** 서초구 잠원동 160-3
# *   **옥외대피소 3:** 서초구 잠원동 162-1
# *   **옥외대피소 4:** 서초구 서...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s LIMIT 10", 'results': [{'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:13' labels=frozenset({'Shelter'}) properties={'area': 1184.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포대로 217(반포동)', 'sido': '서울특별시', 'name': '서울지방조달청 테니스장', 'lon': 127.002453, 'id': 'shelter_185', 'shelter_id': 185.0, 'lat': 37.499301}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:17' labels=frozenset({'Shelter'}) properties={'area': 1720.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 160-3', 'sido': '서울특별시', 'name': '누에소공원', 'lon': 127.008449, 'id': 'shelter_189', 'shelter_id': 189.0, 'lat': 37.50923}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:22' labels=frozenset({'Shelter'}) properties={'area': 2000.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 잠원동 162-1', 'sido': '서울특별시', 'name': '잠원흥동소공원', 'lon': 127.000426, 'id': 'shelter_194', 'shelter_id': 194.0, 'lat': 37.507746}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:23' labels=frozenset({'Shelter'}) properties={'area': 840.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초동 1686-10', 'sido': '서울특별시', 'name': '새싹어린이공원', 'lon': 127.018272, 'id': 'shelter_195', 'shelter_id': 195.0, 'lat': 37.497541}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:27' labels=frozenset({'Shelter'}) properties={'area': 1432.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 방배동 906-14', 'sido': '서울특별시', 'name': '효령어린이공원', 'lon': 126.997549, 'id': 'shelter_199', 'shelter_id': 199.0, 'lat': 37.483163}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:28' labels=frozenset({'Shelter'}) properties={'area': 21609.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 우면동 749', 'sido': '서울특별시', 'name': '우면수변공원', 'lon': 127.013599, 'id': 'shelter_200', 'shelter_id': 200.0, 'lat': 37.45584}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:38' labels=frozenset({'Shelter'}) properties={'area': 708.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포동 68-2', 'sido': '서울특별시', 'name': '파리15구공원', 'lon': 126.999165, 'id': 'shelter_210', 'shelter_id': 210.0, 'lat': 37.499517}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:219' labels=frozenset({'Shelter'}) properties={'area': 988.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포동 53-1', 'sido': '서울특별시', 'name': '미도어린이공원', 'lon': 127.010758, 'id': 'shelter_160', 'shelter_id': 160.0, 'lat': 37.501711}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:221' labels=frozenset({'Shelter'}) properties={'area': 2254.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초중앙로 96(서초동)', 'sido': '서울특별시', 'name': '서울교육대학교 부설초등학교 운동장', 'lon': 127.016948, 'id': 'shelter_162', 'shelter_id': 162.0, 'lat': 37.490249}>}, {'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:230' labels=frozenset({'Shelter'}) properties={'area': 2233.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 서초동 1301-25', 'sido': '서울특별시', 'name': '누리숲어린이공원', 'lon': 127.021195, 'id': 'shelter_171', 'shelter_id': 171.0, 'lat': 37.502051}>}], 'count': 10}, 'vector_results': {'results': [{'id': '공습행동요령', 'text': '# 재난 행동요령: 공습\n\n## 평소 대비 요령\n\n### 1. 기본 정보 숙지\n\n- 집 주변의 대피소(민방위 대피소, 지하철역, 지하 주차장 등)의 위치를 미리 확인합니다.\n- 비상 급수원(상수도 공급원, 우물 등)의 위치를 파악해 둡니다.\n- 경계경보, 공습경보, 화생방경보 등 각 경보의 신호 방법을 숙지합니다.\n\n### 2. 비상용품 준비\n\n- 평소에 생존배낭(비상용품 가방)을 준비하여 언제든 대피할 수 있도록 합니다.\n- 비상용품에는 다음과 같은 물건을 포함합니다:\n  - 식수, 간식, 비상약품\n  - 손전등, 배터리\n  - 담요, 옷\n  - 방독면 등 화생방 개인보호장비\n\n### 3. 화생방 공격 대비\n\n- 화생방 공격에 대비하여 방독면 등 개인보호장비를 점검하고 보관합니다.\n- 음식물과 우물 등은 오염 위험에 대비하여 뚜껑이나 비닐로 덮을 수 있도록 준비합니다.\n\n### 4. 가족 회의\n\n- 평소에 가족과 함께 비상시 행동 계획을 세웁니다.\n- 만날 장소와 연락 방법을 정해둡니다.\n- 어린이와 노 ...
# 서초구에서 지진 발생 시 대피할 수 있는 옥외 대피소는 총 5곳입니다. Graph RAG 검색 결과에서 확인된 대피소 정보는 다음과 같습니다.
#
# *   **옥외대피소 1:** 서초구 반포대로 217(반포동)
# *   **옥외대피소 2:** 서초구 잠원동 160-3
# *   **옥외대피소 3:** 서초구 잠원동 162-1
# *   **옥외대피소 4:** 서초구 서초동 1686-10
# *   **옥외대피소 5:** 서초구 방배동 906-14
#
# 이 외에도 더 많은 옥외 대피소가 있을 수 있으니, 실제 지진 발생 시 정부 또는 지자체의 안내에 따라 안전하게 대피하시기 바랍니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 3/6: 임시주거시설은 어디에 있나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (t:TemporaryHousing)
# RETURN t.name, t.address, t.shelter_type
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (t:TemporaryHousing)
# RETURN t.name, t.address, t.shelter_type
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 4005 자
#   ⚠ 대피소 정보 추출 실패: 결과 821개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['t.name', 't.address', 't.shelter_type']
#     - t.name: <class 'str'>
#     - t.address: <class 'str'>
#     - t.shelter_type: <class 'NoneType'>
# ✓ Ollama 응답 생성: 제공된 Graph RAG 결과에 따르면, 임시 주거 시설 정보는 다음과 같습니다.
#
# **현재까지 확인된 임시 주거 시설 목록:**
#
# *   증산동주민센터
# *   증산초등학교 체육관
# *   수색초등학교
# *   수색동 주민센터
# *   진관동 주민센터
# *   구산동주민센터
# *   역촌동 주민센터
# *   덕산중학교 체육관
# *   신사1동주민센터
# *   신사2동주민...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '임시주거시설은 어디에 있나요?', 'graph_results': {'query': 'MATCH (t:TemporaryHousing)\nRETURN t.name, t.address, t.shelter_type', 'results': [{'t.name': '증산동주민센터', 't.address': '서울특별시 은평구 증산동 187-19', 't.shelter_type': None}, {'t.name': '증산초등학교 체육관', 't.address': '서울특별시 은평구 증산동 212-0', 't.shelter_type': None}, {'t.name': '수색초등학교', 't.address': '서울특별시 은평구 수색동 129', 't.shelter_type': None}, {'t.name': '수색동 주민센터', 't.address': '서울특별시 은평구 수색동 363-11', 't.shelter_type': None}, {'t.name': '진관동 주민센터', 't.address': '서울특별시 은평구 진관동 78', 't.shelter_type': None}, {'t.name': '구산동주민센터', 't.address': '서울특별시 은평구 구산동 27-5', 't.shelter_type': None}, {'t.name': '역촌동 주민센터', 't.address': '서울특별시 은평구 역촌동 62-26', 't.shelter_type': None}, {'t.name': '덕산중학교 체육관', 't.address': '서울특별시 은평구 신사동 265-4', 't.shelter_type': None}, {'t.name': '신사1동주민센터', 't.address': '서울특별시 은평구 신사동 29-2', 't.shelter_type': None}, {'t.name': '신사2동주민센터', 't.address': '서울특별시 은평구 신사동 163-17', 't.shelter_type': None}, {'t.name': '서울서신초등학교', 't.address': '서울특별시 은평구 신사동 194-0', 't.shelter_type': None}, {'t.name': '증산중학교 다목적강당', 't.address': '서울특별시 은평구 증산동 산24-4', 't.shelter_type': None}, {'t.name': '염리생활체육관', 't.address': '서울특별시 마포구 염리동 174-3', 't.shelter_type': None}, {'t.name': '염리생활체육관', 't.address': '서울특별시 마포구 염리동 174-3', 't.shelter_type': None}, {'t.name': '용강초등학교', 't.address': '서울특별시 마포구 대흥동 35-1', 't.shelter_type': None}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.shelter_type': None}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.shelter_type': None}, {'t.name': '서문교회', 't.address': '서울특별시 은평구 응암동 577-57', 't.shelter_type': None}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.shelter_type': None}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.shelter_type': None}, {'t.name': '은평다목적체육관', 't.address': '서울특별시 은평구 진관동 362-0', 't.shelter_type': None}, {'t.name': '보훈회관', 't.address': '서울특별시 은평구 진관동 78-0', 't.shelter_type': None}, {'t.name': '용강동주민센터', 't.address': '서울특별시 마포구 용강동 505-0', 't.shelter_type': None}, {'t.name': '염리초등학교', 't.address': '서울특별시 마포구 염리동 173-4', 't.shelter_type': None}, {'t.name': '마포아트센터', 't.address': '서울특별시 마포구 대흥동 30-3', 't.shelter_type': None}, {'t.name': '원묵초등학교', 't.address': '서울특별시 중랑구 묵동 11', 't.shelter_type': None}, {'t.name': '원묵고등학교', 't.address': '서울특별시 중랑구 묵동 23', 't.shelter_type': None}, {'t.name': '양천구민체육센터', 't.address': '서울특별시 양천구 신정동 322-10', 't.shelter_type': None}, {'t.name': '신정초등학교', 't.address': '서울특별시 강서구 화곡동 869-42', 't.shelter_type': None}, {'t.name': '장안중학교', 't.address': '서울특별시 중랑구 중화동 288-26', 't.shelter_type': None}, {'t.name': '수산교회', 't.address': '서울특별시 중랑구 중화동 316-30', 't.shelter_type': None}, {'t.name': '구현고등학교', 't.address': '서울특별시 구로구 구로동 620-30', 't.shelter_type': None}, {'t.name': '화원종합사회복지관', 't.address': '서울특별시 구로구 구로동 476-134', 't.shelter_type': None}, {'t.name': '송화초등학교', 't.address': '서울특별시 강서구 방화동 217-35', 't.shelter_type': None}, {'t.name': '송정중학교', 't.address': '서울특별시 강서구 공항동 770-1', 't.shelter_type': None}, {'t.name': '서울과학고등학교', 't.address': '서울특별시 종로구 명륜1가 1-0', 't.shelter_type': None}, {'t.name': '이화동주민센터', 't.address': '서울특별시 종로구 이화동 27-4', 't.shelter_type': None}, {'t.name': '혜화동자치회관', 't.address': '서울특별시 종로구 혜화동 74-30', 't.shelter_type': None}, {'t.name': '독립문초등학교', 't.address': '서울특별시 종로구 무악동 46-82', 't.shelter_type': None}, {'t.name': '창신초등학교', 't.address': '서울특별시 종로구 창신동 128-32', 't.shelter_type': None}, {'t.name': '무악동주민센터', 't.address': '서울특별시 종로구 무악동 60-2', 't.shelter_type': None}, {'t.name': '교남동주민센터', 't.address': '서울특별시 종로구 행촌동 180-10', 't.shelter_type': None}, {'t.name': '재동초등학교', 't.address': '서울특별시 종로구 가회동 210', 't.shelter_type': None}, {'t.name': '은평중학교', 't.address': '서울특별시 은평구 구산동 182-44', 't.shelter_type': None}, {'t.name': '대은초등학교', 't.address': '서울특별시 은평구 대조동 82-5', 't.shelter_type': None}, {'t.name': '은명초등학교', 't.address': '서울특별시 은평구 응암동 114-12', 't.shelter_type': None}, {'t.name': '응암2동주민센터', 't.address': '서울특별시 은평구 응암동 229-13', 't ...
# 제공된 Graph RAG 결과에 따르면, 임시 주거 시설 정보는 다음과 같습니다.
#
# **현재까지 확인된 임시 주거 시설 목록:**
#
# *   증산동주민센터
# *   증산초등학교 체육관
# *   수색초등학교
# *   수색동 주민센터
# *   진관동 주민센터
# *   구산동주민센터
# *   역촌동 주민센터
# *   덕산중학교 체육관
# *   신사1동주민센터
# *   신사2동주민센터
#
# **총 개수:** 10개
#
# **추가 정보:**
#
# Graph RAG 결과는 현재까지 확인된 임시 주거 시설 목록만 제공합니다. 추가적으로, 제공된 Vector RAG 결과는 재난 행동 요령에 대한 정보만 제공하며, 해당 정보들을 기반으로 실제 임시 주거 시설의 위치 정보는 알 수 없습니다.
#
# **참고:**  위 목록은 현재까지 Graph RAG 결과에서 추출된 정보에 기반하며, 실제 임시 주거 시설의 위치 및 운영 상황은 변경될 수 있습니다.  정확한 정보는 해당 지역의 민방위 시스템 또는 관련 기관에 문의하여 확인하시는 것이 좋습니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 4/6: 지진 발생 시 어떻게 행동해야 하나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (h:Hazard)
# RETURN h
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (h:Hazard)
# RETURN h
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3112 자
# ✓ Ollama 응답 생성: 지진 발생 시 행동 요령은 다음과 같습니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 파악합니다.
# *   **가까운 곳으로 대피:** 탁자 아래나 가구 밑 등 좁고 튼튼한 곳에 몸을 숨기고 머리와 목을 보호합니다.  유리창, 책상, 찬장 등 무너지는 물체로부터 몸을 보호하는 것이 중요합니다.
# * ...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진 발생 시 어떻게 행동해야 하나요?', 'graph_results': {'query': 'MATCH (h:Hazard)\nRETURN h', 'results': [], 'count': 0}, 'vector_results': {'results': [{'id': '홍수행동요령', 'text': '# 재난 행동요령: 홍수\n\n## 평소 대비 요령\n\n### 1. 정보 수집 및 위험 요인 확인\n\n- 거주 또는 활동하는 지역의 홍수, 침수(저지대), 산사태, 해일 등 재해 위험 요인을 미리 확인합니다.\n- TV, 라디오, 인터넷, 스마트폰 앱 등을 통해 기상상황을 미리 파악합니다.\n\n### 2. 시설물 점검 및 정비\n\n- 가정의 하수구나 집 주변의 배수구를 미리 점검하고 막힌 곳은 뚫어둡니다.\n- 주변의 시설물(배수로, 빗물받이, 비탈면, 옹벽, 축대 등)을 미리 점검합니다.\n\n### 3. 차량 및 물자 보호\n\n- 하천이나 해변, 저지대에 주차된 차량은 안전한 곳으로 미리 이동합니다.\n- 침수가 예상되는 지역에는 모래 주머니, 물막이 판 등을 준비합니다.\n\n### 4. 비상용품 준비\n\n- 가족과 함께 비상용품을 준비하여 재난 발생에 대비합니다.\n- 상수도 공급이 중단될 수 있으므로, 욕조 등에 미리 물을 받아둡니다.\n- 재난정보 수신을 위해 스마트폰에 안전 앱이 설치되었는지 확인하고 긴급 연락망을 준비합니다.\n\n### 5. 대피 계획 수립\n\n- 홍수 우려 때 피난 가능한 장소와 길을 미리 알아둡니다.\n- 가족이나 이웃과 함께 대피계획을 세웁니다.\n\n---\n\n## 홍수 발생 시 행동 요령\n\n### 홍수 예·경보 시 대비요령\n\n- 홍수피해가 예상되는 지역의 주민은 라디오나 TV, 인터넷을 통해 기상변화를 알아 둡니다.\n- 홍수 우려 때 피난 가능한 장소와 길을 사전에 숙지합니다.\n- 산간·계곡, 하천, 방파제 등 위험지역에서는 야영이나 물놀이를 멈추고 안전한 곳으로 대피합니다.\n\n### 갑작스런 홍수 발생 시\n\n- 갑작스러운 홍수가 발생하면 높은 곳으로 빨리 대피합니다.\n- 비탈면이나 산사태가 일어날 수 있는 지역에 가까이 가지 않습니다.\n- 바위나 자갈 등이 흘러내리기 쉬운 비탈면 지역의 도로 통행을 삼가고, 도로를 지날 때는 주위를 잘 살핀 후 이동합니다.\n\n### 홍수 발생 시 금지 사항\n\n- 침수된 지역에서 자동차를 운전하지 않습니다.\n- 침수된 도로나 지하차도에는 진입하지 않습니다.\n- 농촌지역에서는 논둑이나 물꼬를 보러 나가지 않습니다.\n\n### 대피 조치\n\n- 홍수 예상 시 전기차단기를 내리고 가스 밸브를 잠굽니다.\n- 침수가 예상되는 저지대나 상습 침수지역, 산사태 위험지역에서는 안전한 곳으로 이동합니다.\n- 지정된 대피소에 도착하면 반드시 도착사실을 알리고, 통제에 따라 행동합니다.\n\n### 위험 상황에서의 행동\n\n- 고립된 지역에서는 무리하게 물을 건너지 말고, 119에 신고하거나 주변에 도움을 요청합니다.\n- 흙사태 경고 시 가까운 산림청에 신고합니다.\n\n---\n\n## 홍수 대피 후 행동 요령\n\n### 1. 침수 주택 재진입 시 주의사항\n\n- 침수된 주택은 가스누출, 감전 위험이 있으므로 바로 들어가지 마시고 환기를 시킵니다.\n- 가스·전기차단기가 OFF에 있는지 먼저 확인합니다.\n- 전문가의 안전점검을 받아 안전한 경우에만 사용합니다.\n\n### 2. 시설물 피해 확인 및 신고\n\n- 대피 후 집으로 돌아온 경우 반드시 주택 등의 안전 여부를 확인합니다.\n- 파손된 시설물(주택, 상하수도, 축대, 도로 등)을 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n- 파손된 사유시설을 보수할 때에는 반드시 사진을 찍어 둡니다.\n\n### 3. 위험 지역 접근 금지\n\n- 침수된 도로나 교량은 파손되었을 수 있으므로 건너지 않습니다.\n- 하천 제방은 무너질 수 있으니 가까이 가지 않습니다.\n\n### 4. 수질 및 식수 안전 확인\n\n- 수돗물이나 저장식수도 오염 여부를 반드시 조사 후에 사용합니다.\n\n### 5. 가족 및 이웃 안전 확인\n\n- 가족과 지인에게 연락하여 안전 여부를 확인합니다.\n- 연락이 되지 않고 실종이 의심될 경우에는 가까운 경찰서에 신고합니다.\n- 이웃의 노약자, 어린이 등 대피에 어려움이 있는 사람들의 안전 여부를 확인합니다.\n\n### 6. 2차 피해 방지\n\n- 주변과 함께 홍수로 인한 2차 피해를 방지하기 위한 조치를 실시합니다.\n- 정부 안내방송을 계속 청취하고 지시에 따릅니다.\n\n### 7. 심리 상담 및 지원\n\n- 필요시 재난피해자 심리 상담 등 정부 지원을 받습니다.\n', 'distance': 0.9369938969612122}, {'id': '화재행동요령', 'text': '# 재난 행동요령: 화재\n\n## 평소 대비 요령\n\n### 1. 사전점검\n\n화재 예방을 위해 평소에 다음과 같이 확인합니다.\n\n#### 눈으로 확인\n- 사용하지 않는 전열기구 코드를 확인합니다.\n- 가스레인지 중간 벨브 잠금을 확인합니다.\n\n#### 귀로 확인\n- 평소에 나지 않던 이상한 소리를 확인합니다.\n\n#### 코로 확인\n- 타는 냄새가 나지 않는지 확인합니다.\n\n#### 손으로 확인\n- 만져보거나 두들겨 봅니다.\n\n#### 행동으로 확인\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n### 2. 대피훈련\n\n화재 상황에 대비한 훈련을 정기적으로 실시합니다.\n\n- 배워보자: 소화기 사용법, 표시해보자: 2곳 이상의 비상통로, 찾아보자: 대피장소, 막아보자: 문틈\n- 전화해보자: 우리 가족, 정해보자: 만날 장소, 어디있을까: 경량칸막이\n\n### 3. 비상용품 준비\n\n- 대피방법과 대피해서 만나는 장소를 사전에 약속합니다.\n- 대피할때 가져가야할 중요물건 목록을 작성하고 챙길 사람을 선정합니다.\n- 비상연락 전화번호 및 연락해야 할 대상을 선정합니다.\n- 문틈을 막아야할 경우 청테이프 또는 수건을 준비합니다.\n- 외부 대피 시 사용할 수건 등 대피에 사용할 물건을 준비합니다.\n- 긴급 대피한 경우 만날 장소와 비상연락망을 정해둡니다.\n\n---\n\n## 화재 발생 시 행동 요령\n\n### 화재경보가 울릴 때\n\n#### 1. 주변 사람에게 알립니다.\n\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려고 하기보다는 소리를 질러 주변 사람에게 알립니다.\n\n#### 2. 대피방법을 결정합니다.\n\n- 손등으로 출입문 손잡이를 만져보아 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져 보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n#### 3. 신속히 대피합니다.\n\n- 대피할 때는 엘리베이터를 절대 이용하지 않고 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n#### 4. 119로 신고합니다.\n\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n#### 5. 대피 후 인원을 확인합니다.\n\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n### 불을 발견했을 때\n\n#### 1. 연기가 발생하거나 불이 난 것을 보았을 때\n\n- 불이 난 것을 발견하면 "불이야!"라고 소리치거나 비상벨을 눌러 주변에 알리도록 합니다.\n\n#### 2. 불을 끌 것인지 대피할 것인지 판단합니다.\n\n- 불길이 천장까지 닿지 않은 작은 불이라면 소화기나 물양동이 등을 활용하여 신속히 끄도록 합니다.\n- 불길이 커져서 대피해야 할 경우 젖은 수건 또는 담요를 활용하여 계단을 통해 ...
# 지진 발생 시 행동 요령은 다음과 같습니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 파악합니다.
# *   **가까운 곳으로 대피:** 탁자 아래나 가구 밑 등 좁고 튼튼한 곳에 몸을 숨기고 머리와 목을 보호합니다.  유리창, 책상, 찬장 등 무너지는 물체로부터 몸을 보호하는 것이 중요합니다.
# *   **떨어지는 물건 주의:** 주변에 떨어지거나 무너질 수 있는 물건이 있는지 확인하고, 가능하다면 가구를 이용하여 몸을 보호합니다.
#
# **2. 지진 진정 후:**
#
# *   **방송 청취:** 라디오나 TV, 스마트폰 앱 등을 통해 정부 발표 및 지진 관련 정보를 확인합니다. 안전한 대피 장소 및 경로를 확인합니다.
# *   **건물 밖 대피:** 건물 붕괴 위험이 있는 경우, 건물 밖으로 대피합니다.  가능하다면 2층 이상 높이로 대피하고, 건물 밖으로 나갈 때 넘어지지 않도록 주의합니다.
# *   **가스 차단:** 가스 누출 가능성에 대비하여 가스 밸브를 차단합니다.
# *   **구조 요청:** 부상자가 발생하면 응급처치를 실시하고, 구조를 요청합니다.
#
# **3. 추가적인 주의사항:**
#
# *   **대피 시 안전거리 확보:** 낙하물로부터 안전거리를 유지하며 대피합니다.
# *   **무리한 건물 진입 금지:** 구조 활동에 방해가 되지 않도록 무리하게 건물에 진입하지 않습니다.
#
# **참고:** 현재 검색 결과는 지진 대응에 대한 일반적인 정보를 제공하고 있습니다. 실제 지진 상황에서는 즉각적인 상황 판단과 대응이 필요합니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 5/6: 공습경보가 발령되면 어떻게 해야 하나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (h:Hazard)
# RETURN h
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (h:Hazard)
# RETURN h
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3113 자
# ✓ Ollama 응답 생성: 공습경보가 발령되면 다음과 같은 행동을 취해야 합니다.
#
# 1. **신속하게 대피소로 이동합니다.** 가장 가까운 민방위 대피소(지하철역, 지하 주차장 등)로 신속하게 이동합니다.
# 2. **안전한 장소로 대피합니다.** 대피소가 없는 경우, 건물 내 가장 안쪽의 실내 공간(방, 화장실 등)으로 이동하여 머신룸 등 더욱 안전한 곳을 찾습니다.
# 3. **머신룸이...
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '공습경보가 발령되면 어떻게 해야 하나요?', 'graph_results': {'query': 'MATCH (h:Hazard)\nRETURN h', 'results': [], 'count': 0}, 'vector_results': {'results': [{'id': '화재행동요령', 'text': '# 재난 행동요령: 화재\n\n## 평소 대비 요령\n\n### 1. 사전점검\n\n화재 예방을 위해 평소에 다음과 같이 확인합니다.\n\n#### 눈으로 확인\n- 사용하지 않는 전열기구 코드를 확인합니다.\n- 가스레인지 중간 벨브 잠금을 확인합니다.\n\n#### 귀로 확인\n- 평소에 나지 않던 이상한 소리를 확인합니다.\n\n#### 코로 확인\n- 타는 냄새가 나지 않는지 확인합니다.\n\n#### 손으로 확인\n- 만져보거나 두들겨 봅니다.\n\n#### 행동으로 확인\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n### 2. 대피훈련\n\n화재 상황에 대비한 훈련을 정기적으로 실시합니다.\n\n- 배워보자: 소화기 사용법, 표시해보자: 2곳 이상의 비상통로, 찾아보자: 대피장소, 막아보자: 문틈\n- 전화해보자: 우리 가족, 정해보자: 만날 장소, 어디있을까: 경량칸막이\n\n### 3. 비상용품 준비\n\n- 대피방법과 대피해서 만나는 장소를 사전에 약속합니다.\n- 대피할때 가져가야할 중요물건 목록을 작성하고 챙길 사람을 선정합니다.\n- 비상연락 전화번호 및 연락해야 할 대상을 선정합니다.\n- 문틈을 막아야할 경우 청테이프 또는 수건을 준비합니다.\n- 외부 대피 시 사용할 수건 등 대피에 사용할 물건을 준비합니다.\n- 긴급 대피한 경우 만날 장소와 비상연락망을 정해둡니다.\n\n---\n\n## 화재 발생 시 행동 요령\n\n### 화재경보가 울릴 때\n\n#### 1. 주변 사람에게 알립니다.\n\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려고 하기보다는 소리를 질러 주변 사람에게 알립니다.\n\n#### 2. 대피방법을 결정합니다.\n\n- 손등으로 출입문 손잡이를 만져보아 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져 보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n#### 3. 신속히 대피합니다.\n\n- 대피할 때는 엘리베이터를 절대 이용하지 않고 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n#### 4. 119로 신고합니다.\n\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n#### 5. 대피 후 인원을 확인합니다.\n\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n### 불을 발견했을 때\n\n#### 1. 연기가 발생하거나 불이 난 것을 보았을 때\n\n- 불이 난 것을 발견하면 "불이야!"라고 소리치거나 비상벨을 눌러 주변에 알리도록 합니다.\n\n#### 2. 불을 끌 것인지 대피할 것인지 판단합니다.\n\n- 불길이 천장까지 닿지 않은 작은 불이라면 소화기나 물양동이 등을 활용하여 신속히 끄도록 합니다.\n- 불길이 커져서 대피해야 할 경우 젖은 수건 또는 담요를 활용하여 계단을 통해 밖으로 대피합니다.\n- 세대 밖으로 대피가 어려운 경우 경량칸막이를 이용하여 이웃집으로 대피하거나 완강기를 이용하여 창문으로 나가는 방법, 실내대피 공간으로 대피하였다가 불이 꺼진 후 나오는 방법 등을 활용합니다.\n\n### 소화기 사용법\n\n#### 실내에서 사용할 때는 밖으로 대피할 때를 대비하여 문을 등지고\n\n1. 소화기를 가져와서 몸통을 단단히 잡고 안전핀을 뽑습니다.\n2. 노즐을 잡고 불쪽을 향해 가까이 이동합니다.\n3. 손잡이를 꽉 움켜쥡니다.\n4. 분말이 골고루 불을 덮을 수 있도록 쏩니다.\n\n### 완강기 사용법\n\n1. 지지대 고리에 완강기 고리를 걸고 잠근다.\n2. 지지대를 창밖으로 밀고 릴(줄)을 던진다.\n3. 완강기 벨트를 가슴 높이까지 걸고 조인다.\n4. 벽을 짚으며 안전하게 내려간다.\n\n### 옷에 불이 붙었을 때\n\n1. 옷에 불이 붙었을 때는 하던 일을 멈춥니다.\n2. 얼굴(눈, 코, 입)에 화상을 입지 않도록 두 손으로 감싼다.\n3. 바닥에 엎드린 후 몸을 뒹굴어서 불이 꺼지도록 합니다.\n\n---\n\n## 화재 대피 후 행동 요령\n\n### 1. 가족의 상황을 확인하고 부상자에 대한 응급처치를 실시합니다.\n\n- 대피 후 가족 모두의 안전 여부를 확인합니다.\n- 부상자가 있으면 응급처치를 실시하고 119에 신고하여 이송받습니다.\n\n### 2. 주변의 피해 상황을 파악합니다.\n\n- 대피 후 집으로 돌아온 경우 반드시 주택 등의 안전 여부를 확인하고 출입합니다.\n- 파손된 시설물(주택, 상하수도 등)은 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n\n### 3. 파손된 물품에 대한 기록을 남깁니다.\n\n- 파손된 사유시설을 보수 또는 복구할 때에는 반드시 사진을 찍어 둡니다.\n\n### 4. 올바른 정보를 확인합니다.\n\n- 근거 없는 유언비어에 유의하고, TV·라디오나 공공기관에서 제공하는 정보를 확인합니다.\n- 정부 안내방송을 계속 청취하고 이에 따라 행동합니다.\n\n### 5. 재난 상황에 따라 행동합니다.\n\n- 화재가 계속 진행 중이면 추가 대피 지시에 따릅니다.\n- 대피소에 도착한 후에는 도착사실을 알리고 통제에 따릅니다.\n- 구조 활동에 적극 협조합니다.\n', 'distance': 1.002604365348816}, {'id': '홍수행동요령', 'text': '# 재난 행동요령: 홍수\n\n## 평소 대비 요령\n\n### 1. 정보 수집 및 위험 요인 확인\n\n- 거주 또는 활동하는 지역의 홍수, 침수(저지대), 산사태, 해일 등 재해 위험 요인을 미리 확인합니다.\n- TV, 라디오, 인터넷, 스마트폰 앱 등을 통해 기상상황을 미리 파악합니다.\n\n### 2. 시설물 점검 및 정비\n\n- 가정의 하수구나 집 주변의 배수구를 미리 점검하고 막힌 곳은 뚫어둡니다.\n- 주변의 시설물(배수로, 빗물받이, 비탈면, 옹벽, 축대 등)을 미리 점검합니다.\n\n### 3. 차량 및 물자 보호\n\n- 하천이나 해변, 저지대에 주차된 차량은 안전한 곳으로 미리 이동합니다.\n- 침수가 예상되는 지역에는 모래 주머니, 물막이 판 등을 준비합니다.\n\n### 4. 비상용품 준비\n\n- 가족과 함께 비상용품을 준비하여 재난 발생에 대비합니다.\n- 상수도 공급이 중단될 수 있으므로, 욕조 등에 미리 물을 받아둡니다.\n- 재난정보 수신을 위해 스마트폰에 안전 앱이 설치되었는지 확인하고 긴급 연락망을 준비합니다.\n\n### 5. 대피 계획 수립\n\n- 홍수 우려 때 피난 가능한 장소와 길을 미리 알아둡니다.\n- 가족이나 이웃과 함께 대피계획을 세웁니다.\n\n---\n\n## 홍수 발생 시 행동 요령\n\n### 홍수 예·경보 시 대비요령\n\n- 홍수피해가 예상되는 지역의 주민은 라디오나 TV, 인터넷을 통해 기상변화를 알아 둡니다.\n- 홍수 우려 때 피난 가능한 장소와 길을 사전에 숙지합니다.\n- 산간·계곡, 하천, 방파제 등 위험지역에서는 야영이나 물놀이를 멈추고 안전한 곳으로 대피합니다.\n\n### 갑작스런 홍수 발생 시\n\n- 갑작스러운 홍수가 발생하면 높은 곳으로 빨리 대피합니다.\n- 비탈면이나 산사태가 일어날 수 있는 지역에 가까이 가지 않습니다.\n- 바위나 자갈 등이 흘러내리기 쉬운 비탈면 지역의 도로 통행을 삼가고, 도로를 지날 때는 주위를 잘 살핀 후 이동합니다.\n\n### 홍수 발생 시 금지 사항\n\n- 침수된 지역에서 자동차를 운전하지 ...
# 공습경보가 발령되면 다음과 같은 행동을 취해야 합니다.
#
# 1. **신속하게 대피소로 이동합니다.** 가장 가까운 민방위 대피소(지하철역, 지하 주차장 등)로 신속하게 이동합니다.
# 2. **안전한 장소로 대피합니다.** 대피소가 없는 경우, 건물 내 가장 안쪽의 실내 공간(방, 화장실 등)으로 이동하여 머신룸 등 더욱 안전한 곳을 찾습니다.
# 3. **머신룸이나 좁은 공간에 몸을 보호합니다.** 머신룸, 화장실, 창고 등 건물 내 좁은 공간은 낙하물로부터 보호받을 수 있습니다.
# 4. **외부와의 연락을 유지합니다.** 상황을 파악하고 가족 및 관계 기관과 연락을 유지합니다.
# 5. **침착하게 행동합니다.** 공습경보 발령 시 당황하지 않고 침착하게 행동하는 것이 중요합니다.
#
# **참고:** 평소에 가까운 대피소의 위치를 확인하고, 비상용품(손전등, 식수, 담요 등)을 미리 준비해 두는 것이 좋습니다.
#
# ============================================================
#
#
#
# ############################################################
# 질의 6/6: 서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# ✓ Ollama 응답 생성: ```cypher
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.facility_id DESC LIMIT 1
# ```
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.facility_id DESC LIMIT 1
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3384 자
#   ⚠ 대피소 정보 추출 실패: 결과 1개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['s']
#     - s: <class 'neo4j.graph.Node'>
# ✓ Ollama 응답 생성: 서초구 옥외대피소 중 가장 큰 시설은 다음과 같습니다.
#
# *   **반포대로 217 (반포동) 옥외대피소**: 면적 1184.0㎡ (이 문서에서 확인)
#
# 총 9개의 옥외대피소가 존재합니다. (이 문서에서 확인)
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?', 'graph_results': {'query': "MATCH (s:Shelter) WHERE s.sigungu = '서초구' RETURN s ORDER BY s.facility_id DESC LIMIT 1", 'results': [{'s': <Node element_id='4:591caba2-870f-4464-99ff-36305f481803:13' labels=frozenset({'Shelter'}) properties={'area': 1184.0, 'shelter_type': '옥외대피소', 'sigungu': '서초구', 'address': '서울특별시 서초구 반포대로 217(반포동)', 'sido': '서울특별시', 'name': '서울지방조달청 테니스장', 'lon': 127.002453, 'id': 'shelter_185', 'shelter_id': 185.0, 'lat': 37.499301}>}], 'count': 1}, 'vector_results': {'results': [{'id': '공습행동요령', 'text': '# 재난 행동요령: 공습\n\n## 평소 대비 요령\n\n### 1. 기본 정보 숙지\n\n- 집 주변의 대피소(민방위 대피소, 지하철역, 지하 주차장 등)의 위치를 미리 확인합니다.\n- 비상 급수원(상수도 공급원, 우물 등)의 위치를 파악해 둡니다.\n- 경계경보, 공습경보, 화생방경보 등 각 경보의 신호 방법을 숙지합니다.\n\n### 2. 비상용품 준비\n\n- 평소에 생존배낭(비상용품 가방)을 준비하여 언제든 대피할 수 있도록 합니다.\n- 비상용품에는 다음과 같은 물건을 포함합니다:\n  - 식수, 간식, 비상약품\n  - 손전등, 배터리\n  - 담요, 옷\n  - 방독면 등 화생방 개인보호장비\n\n### 3. 화생방 공격 대비\n\n- 화생방 공격에 대비하여 방독면 등 개인보호장비를 점검하고 보관합니다.\n- 음식물과 우물 등은 오염 위험에 대비하여 뚜껑이나 비닐로 덮을 수 있도록 준비합니다.\n\n### 4. 가족 회의\n\n- 평소에 가족과 함께 비상시 행동 계획을 세웁니다.\n- 만날 장소와 연락 방법을 정해둡니다.\n- 어린이와 노약자를 위한 대피 계획을 미리 수립합니다.\n\n### 5. 정부 방송 청취 준비\n\n- 라디오나 TV를 통해 정부 방송을 청취할 수 있도록 준비합니다.\n- 휴대폰 긴급재난문자 수신 설정을 확인합니다.\n\n---\n\n## 공습경보 발령 시 행동 요령\n\n### 경계경보 시 행동요령 (공격이 예상될 때)\n\n#### 경보 신호\n- 음성방송, 민방공 경보문자로 발령됨\n\n#### 행동 요령\n- 정부 안내 방송을 청취하며 정보를 파악합니다.\n- 어린이와 노약자를 미리 대피시키고 평소 준비해 둔 비상용품은 대피소로 옮깁니다.\n- 밤에는 불을 꺼야 하며 부득이한 경우에는 불빛이 밖으로 새어나가지 않도록 차단합니다.\n- 외부 가스밸브를 차단하고 전열기의 코드를 뽑습니다.\n- 화생방 공격에 대비하여 방독면 등 개인보호장비를 점검합니다.\n- 극장, 운동장, 백화점 등 사람이 많이 모이는 곳에서는 영업을 중단하고 손님들에게 경보 내용을 알립니다.\n\n### 공습경보 시 행동요령 (공격이 임박하거나 진행 중일 때)\n\n#### 경보 신호\n- 사이렌(1분, 5초 상승, 3초 하강 파상음)\n- 음성방송, 민방공 경보문자로 발령됨\n\n#### 행동 요령\n- 지하대피소나 지형지물을 이용하여 신속하고 질서 있게 대피합니다.\n- 가까운 민방위 대피소, 지하철역, 지하 주차장 등 지하시설 또는 콘크리트 건물 내 유리창이 없는 안전한 곳으로 대피합니다.\n- 고층건물에 있다면 계단을 이용하여 지하실 또는 아래층으로 대피합니다. (엘리베이터 이용 금지)\n- 방독면 등 화생방 개인보호장비와 생존배낭 등 비상용품을 가지고 대피합니다.\n- 운행 중인 차량은 가까운 빈터나 도로 오른쪽에 세우고 키는 차에 놓아둔 채로 모든 승객을 내려 대피시킵니다.\n- 화생방 공격에 대비하여 방독면을 착용합니다.\n\n### 화생방경보 시 행동요령\n\n#### 상황1: 화생방 작용제 탐지시, 오염 예상시 또는 공격 확인시\n- 방독면, 마스크, 수건 등으로 호흡기를 보호합니다.\n- 건물 내 높은 층의 실내공간 또는 바람 반대 방향으로 대피합니다.\n- 음식물과 물을 섭취하지 않도록 주의합니다.\n\n#### 상황2: 화생방 공격 종료시\n- 정부의 안내를 받을 때까지 실외활동을 자제합니다.\n- 오염 지역 시설이나 물자에는 접근하거나 만지지 않습니다.\n- 정부에서 하는 오염지역 제독작업에 적극 협조합니다.\n\n---\n\n## 공습경보 발령 후 행동 요령\n\n### 1. 대피소에서의 생활 규칙\n\n- 대피소에 도착한 후 질서를 지키고 계속 정부 방송을 청취합니다.\n- 행정안전부(옛 소방방재청)의 지시에 따라 행동합니다.\n- 공동대피공간일 경우 대표자를 선정하고 공동생활 규칙을 정합니다.\n\n### 2. 공포와 불안 관리\n\n- 대피하여 모여 있는 사람들은 공포, 공황 상태 및 불안에 노출되어 있을 수 있습니다.\n- 차분함을 유지하고 서로 배려하는 자세를 갖습니다.\n- 필요시 심리 상담을 받습니다.\n\n### 3. 정보 확인\n\n- SNS 등에 유포되는 유언비어에 현혹되지 않습니다.\n- 공식 정부 방송만 청취하고 신뢰합니다.\n\n### 4. 경보해제 후 행동\n\n- 경보해제 신호가 발령되면 정부의 안내에 따릅니다.\n- 부상자 구조에 동참합니다.\n- 추가 공습에 대비합니다.\n\n### 5. 복귀 전 조치\n\n- 복귀 전 정부의 안전 확인 지시를 받아야 합니다.\n- 오염 확대 가능성이 있으므로 지정지역 외 접근을 금지합니다.\n- 환경감시 등 조사활동이 끝날 때까지 정부 및 방재유도 요원의 안내에 따릅니다.\n\n### 6. 장기 대피 시 준비\n\n- 2주 이상의 대피가 필요할 수 있으므로 충분한 식수와 식량을 준비합니다.\n- 의약품과 의료용품을 충분히 준비합니다.\n- 방사선 낙진 등 오염된 외부공기가 내부로 유입되지 않도록 조치합니다.\n\n### 7. 집으로 복귀 시\n\n- 집으로 복귀한 후 가스누출, 누전 등의 위험을 점검합니다.\n- 가스·전기를 점검하고 필요시 전문가의 안전조사를 받습니다.\n- 오염 가능성이 있으므로 샤워를 하고 옷을 갈아입습니다.\n\n### 8. 피해 상황 신고\n\n- 파손된 시설물을 발견한 경우 가까운 시·군·구청이나 행정복지센터에 신고합니다.\n- 필요시 피해 사진을 촬영하여 보관합니다.\n', 'distance': 0.8463894128799438}, {'id': '홍수행동요령', 'text': '# 재난 행동요령: 홍수\n\n## 평소 대비 요령\n\n### 1. 정보 수집 및 위험 요인 확인\n\n- 거주 또는 활동하는 지역의 홍수, 침수(저지대), 산사태, 해일 등 재해 위험 요인을 미리 확인합니다.\n- TV, 라디오, 인터넷, 스마트폰 앱 등을 통해 기상상황을 미리 파악합니다.\n\n### 2. 시설물 점검 및 정비\n\n- 가정의 하수구나 집 주변의 배수구를 미리 점검하고 막힌 곳은 뚫어둡니다.\n- 주변의 시설물(배수로, 빗물받이, 비탈면, 옹벽, 축대 등)을 미리 점검합니다.\n\n### 3. 차량 및 물자 보호\n\n- 하천이나 해변, 저지대에 주차된 차량은 안전한 곳으로 미리 이동합니다.\n- 침수가 예상되는 지역에는 모래 주머니, 물막이 판 등을 준비합니다.\n\n### 4. 비상용품 준비\n\n- 가족과 함께 비상용품을 준비하여 재난 발생에 대비합니다.\n- 상수도 공급이 중단될 수 있으므로, 욕조 등에 미리 물을 받아둡니다.\n- 재난정보 수신을 위해 스마트폰에 안전 앱이 설치되었는지 확인하고 긴급 연락망을 준비합니다.\n\n### 5. 대피 계획 수립\n\n- 홍수 우려 때 피난 가능한 장소와 길을 미리 알아둡니다.\n- 가족이나 이웃과 함께 대피계획을 세웁니다.\n\n---\n\n## 홍수 발생 시 행동 요령\n\n### 홍수 예·경보 시 대비요령\n\n- 홍수피해가 예상되는 지 ...
# 서초구 옥외대피소 중 가장 큰 시설은 다음과 같습니다.
#
# *   **반포대로 217 (반포동) 옥외대피소**: 면적 1184.0㎡ (이 문서에서 확인)
#
# 총 9개의 옥외대피소가 존재합니다. (이 문서에서 확인)
#
# ============================================================

# %% [markdown]
# ## 7. 결과 분석

# %%
# 결과 요약
print("\n" + "="*60)
print("# Hybrid RAG 검색 결과 요약")
print("="*60 + "\n")

for i, result in enumerate(results, 1):
    question = result.get("question", "N/A")
    graph_count = result.get("graph_results", {}).get("count", 0)
    vector_count = result.get("vector_results", {}).get("count", 0)
    has_answer = result.get("answer") is not None
    
    print(f"질의 {i}: {question}")
    print(f"  - Graph RAG: {graph_count}개 결과")
    print(f"  - Vector RAG: {vector_count}개 결과")
    print(f"  - 최종 답변: {'✓ 생성됨' if has_answer else '✗ 생성 실패'}")
    print(result.get("answer", "답변 생성 실패"))
    print()
# Out:
# ============================================================
# # Hybrid RAG 검색 결과 요약
# ============================================================
#
# 질의 1: 강남구에 있는 대피소는 몇 개인가요?
#   - Graph RAG: 240개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 강남구에 있는 대피소는 총 240개입니다. (Graph RAG 검색 결과: count(s): 240)
#
# 질의 2: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
#   - Graph RAG: 10개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 서초구에서 지진 발생 시 대피할 수 있는 옥외 대피소는 총 5곳입니다. Graph RAG 검색 결과에서 확인된 대피소 정보는 다음과 같습니다.
#
# *   **옥외대피소 1:** 서초구 반포대로 217(반포동)
# *   **옥외대피소 2:** 서초구 잠원동 160-3
# *   **옥외대피소 3:** 서초구 잠원동 162-1
# *   **옥외대피소 4:** 서초구 서초동 1686-10
# *   **옥외대피소 5:** 서초구 방배동 906-14
#
# 이 외에도 더 많은 옥외 대피소가 있을 수 있으니, 실제 지진 발생 시 정부 또는 지자체의 안내에 따라 안전하게 대피하시기 바랍니다.
#
# 질의 3: 임시주거시설은 어디에 있나요?
#   - Graph RAG: 821개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 제공된 Graph RAG 결과에 따르면, 임시 주거 시설 정보는 다음과 같습니다.
#
# **현재까지 확인된 임시 주거 시설 목록:**
#
# *   증산동주민센터
# *   증산초등학교 체육관
# *   수색초등학교
# *   수색동 주민센터
# *   진관동 주민센터
# *   구산동주민센터
# *   역촌동 주민센터
# *   덕산중학교 체육관
# *   신사1동주민센터
# *   신사2동주민센터
#
# **총 개수:** 10개
#
# **추가 정보:**
#
# Graph RAG 결과는 현재까지 확인된 임시 주거 시설 목록만 제공합니다. 추가적으로, 제공된 Vector RAG 결과는 재난 행동 요령에 대한 정보만 제공하며, 해당 정보들을 기반으로 실제 임시 주거 시설의 위치 정보는 알 수 없습니다.
#
# **참고:**  위 목록은 현재까지 Graph RAG 결과에서 추출된 정보에 기반하며, 실제 임시 주거 시설의 위치 및 운영 상황은 변경될 수 있습니다.  정확한 정보는 해당 지역의 민방위 시스템 또는 관련 기관에 문의하여 확인하시는 것이 좋습니다.
#
# 질의 4: 지진 발생 시 어떻게 행동해야 하나요?
#   - Graph RAG: 0개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 지진 발생 시 행동 요령은 다음과 같습니다.
#
# **1. 지진 발생 직후:**
#
# *   **침착하게 행동:** 공포에 휩싸이지 않고 침착하게 상황을 파악합니다.
# *   **가까운 곳으로 대피:** 탁자 아래나 가구 밑 등 좁고 튼튼한 곳에 몸을 숨기고 머리와 목을 보호합니다.  유리창, 책상, 찬장 등 무너지는 물체로부터 몸을 보호하는 것이 중요합니다.
# *   **떨어지는 물건 주의:** 주변에 떨어지거나 무너질 수 있는 물건이 있는지 확인하고, 가능하다면 가구를 이용하여 몸을 보호합니다.
#
# **2. 지진 진정 후:**
#
# *   **방송 청취:** 라디오나 TV, 스마트폰 앱 등을 통해 정부 발표 및 지진 관련 정보를 확인합니다. 안전한 대피 장소 및 경로를 확인합니다.
# *   **건물 밖 대피:** 건물 붕괴 위험이 있는 경우, 건물 밖으로 대피합니다.  가능하다면 2층 이상 높이로 대피하고, 건물 밖으로 나갈 때 넘어지지 않도록 주의합니다.
# *   **가스 차단:** 가스 누출 가능성에 대비하여 가스 밸브를 차단합니다.
# *   **구조 요청:** 부상자가 발생하면 응급처치를 실시하고, 구조를 요청합니다.
#
# **3. 추가적인 주의사항:**
#
# *   **대피 시 안전거리 확보:** 낙하물로부터 안전거리를 유지하며 대피합니다.
# *   **무리한 건물 진입 금지:** 구조 활동에 방해가 되지 않도록 무리하게 건물에 진입하지 않습니다.
#
# **참고:** 현재 검색 결과는 지진 대응에 대한 일반적인 정보를 제공하고 있습니다. 실제 지진 상황에서는 즉각적인 상황 판단과 대응이 필요합니다.
#
# 질의 5: 공습경보가 발령되면 어떻게 해야 하나요?
#   - Graph RAG: 0개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 공습경보가 발령되면 다음과 같은 행동을 취해야 합니다.
#
# 1. **신속하게 대피소로 이동합니다.** 가장 가까운 민방위 대피소(지하철역, 지하 주차장 등)로 신속하게 이동합니다.
# 2. **안전한 장소로 대피합니다.** 대피소가 없는 경우, 건물 내 가장 안쪽의 실내 공간(방, 화장실 등)으로 이동하여 머신룸 등 더욱 안전한 곳을 찾습니다.
# 3. **머신룸이나 좁은 공간에 몸을 보호합니다.** 머신룸, 화장실, 창고 등 건물 내 좁은 공간은 낙하물로부터 보호받을 수 있습니다.
# 4. **외부와의 연락을 유지합니다.** 상황을 파악하고 가족 및 관계 기관과 연락을 유지합니다.
# 5. **침착하게 행동합니다.** 공습경보 발령 시 당황하지 않고 침착하게 행동하는 것이 중요합니다.
#
# **참고:** 평소에 가까운 대피소의 위치를 확인하고, 비상용품(손전등, 식수, 담요 등)을 미리 준비해 두는 것이 좋습니다.
#
# 질의 6: 서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?
#   - Graph RAG: 1개 결과
#   - Vector RAG: 4개 결과
#   - 최종 답변: ✓ 생성됨
# 서초구 옥외대피소 중 가장 큰 시설은 다음과 같습니다.
#
# *   **반포대로 217 (반포동) 옥외대피소**: 면적 1184.0㎡ (이 문서에서 확인)
#
# 총 9개의 옥외대피소가 존재합니다. (이 문서에서 확인)

# %%
# Neo4j 연결 종료
neo4j_driver.close()
print("✓ Neo4j 연결 종료")
# Out:
# ✓ Neo4j 연결 종료

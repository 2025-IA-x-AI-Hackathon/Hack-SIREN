# %% [markdown]
# # 6-3. Hybrid RAG (Advanced) - 재난대응 시스템
#
# Graph RAG와 Vector RAG를 결합한 하이브리드 검색 시스템입니다.
# - **Graph RAG**: Neo4j 그래프 데이터베이스에서 구조화된 정보 검색
# - **Vector RAG**: Chroma 벡터 DB에서 문서 검색
# - **Gemini API**: Google Gemini를 사용한 자연어 생성

# %%
# 필요한 라이브러리 import
import os
from typing import List, Dict, Optional
from dotenv import load_dotenv
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Neo4j
from neo4j import GraphDatabase

# Chroma
import chromadb
from chromadb.config import Settings

# Gemini API
from google import genai
from google.genai import types

load_dotenv()
print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %% [markdown]
# ## 1. 데이터베이스 연결 설정

# %%
# Neo4j 연결 설정
NEO4J_URI = os.getenv("NEO4J_URI", "bolt://localhost:7687")
NEO4J_USER = os.getenv("NEO4J_USER", "neo4j")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "password")

neo4j_driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

def get_neo4j_session():
    return neo4j_driver.session()

# Neo4j 연결 확인
try:
    with get_neo4j_session() as session:
        result = session.run("RETURN 1 as test")
        print(f"✓ Neo4j 연결 성공: {NEO4J_URI}")
except Exception as e:
    print(f"✗ Neo4j 연결 실패: {e}")
# Out:
# ✓ Neo4j 연결 성공: bolt://localhost:7687

# %%
# Chroma 벡터 DB 연결 (Gemini 임베딩 사용)
CHROMA_PERSIST_DIR = "data/chroma"
DOCS_DIR = "docs"

chroma_client = chromadb.PersistentClient(
    path=CHROMA_PERSIST_DIR,
    settings=Settings(anonymized_telemetry=False)
)

# Gemini 임베딩 함수는 Cell 7에서 초기화 후 사용
# 임시로 None으로 설정 (Cell 7 실행 후 업데이트 필요)
gemini_embedding_fn = None

# 컬렉션 가져오기 또는 생성
try:
    chroma_collection = chroma_client.get_collection("disaster_docs")
    print(f"✓ Chroma 컬렉션 로드 성공: {chroma_collection.count()} 문서")
except Exception as e:
    print(f"✗ Chroma 컬렉션 로드 실패: {e}")
    print("새 컬렉션 생성 및 문서 적재 중...")
    
    # Gemini 임베딩 함수가 아직 초기화되지 않았으면 임시 생성
    if gemini_embedding_fn is None:
        print("⚠ Gemini 임베딩 함수가 아직 초기화되지 않았습니다.")
        print("   Cell 7을 먼저 실행하거나, 아래 코드로 임시 초기화합니다...")
        # 임시 초기화
        GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
        if GOOGLE_API_KEY:
            temp_client = genai.Client(api_key=GOOGLE_API_KEY)
            class GeminiEmbeddingFunction:
                def __init__(self, client, model="gemini-embedding-001"):
                    self.client = client
                    self.model = model
                def __call__(self, input_texts):
                    result = self.client.models.embed_content(
                        model=self.model,
                        contents=input_texts,
                        config=types.EmbedContentConfig(
                            output_dimensionality=384  # 기존 컬렉션과 호환되도록 384차원 사용
                        )
                    )
                    embeddings = []
                    for embedding in result.embeddings:
                        if hasattr(embedding, 'values'):
                            embeddings.append(list(embedding.values))
                        elif isinstance(embedding, list):
                            embeddings.append(embedding)
                        elif hasattr(embedding, '__iter__') and not isinstance(embedding, str):
                            embeddings.append(list(embedding))
                        else:
                            embeddings.append([float(embedding)])
                    return embeddings
            gemini_embedding_fn = GeminiEmbeddingFunction(temp_client)
            print("  ✓ 임시 Gemini 임베딩 함수 초기화 완료")
    
    # 새 컬렉션 생성 (Gemini 임베딩 함수 사용)
    chroma_collection = chroma_client.create_collection(
        name="disaster_docs",
        embedding_function=gemini_embedding_fn,
        metadata={"description": "재난 행동요령 문서 (Gemini 임베딩 사용)"}
    )
    
    # docs 폴더의 마크다운 파일 읽기 및 적재
    import glob
    
    doc_files = glob.glob(f"{DOCS_DIR}/*.md")
    print(f"\n찾은 문서 파일: {len(doc_files)}개")
    
    documents = []
    ids = []
    metadatas = []
    
    for doc_file in doc_files:
        try:
            with open(doc_file, 'r', encoding='utf-8') as f:
                content = f.read()
            
            filename = os.path.basename(doc_file)
            doc_id = filename.replace('.md', '')
            
            documents.append(content)
            ids.append(doc_id)
            metadatas.append({"source": filename, "type": "disaster_guide"})
            
            print(f"  ✓ {filename} 적재 완료 ({len(content)}자)")
        except Exception as e:
            print(f"  ✗ {doc_file} 적재 실패: {e}")
    
    # Chroma에 문서 추가 (Gemini 임베딩 자동 생성)
    if documents:
        chroma_collection.add(
            documents=documents,
            ids=ids,
            metadatas=metadatas
        )
        print(f"\n✓ 총 {len(documents)}개 문서를 Chroma에 적재했습니다 (Gemini 임베딩 사용).")
    else:
        print("\n✗ 적재할 문서가 없습니다.")
# Out:
# ✓ Chroma 컬렉션 로드 성공: 16 문서

# %% [markdown]
# ## 1-1. Neo4j 데이터 적재 (필요시)

# %%
# Neo4j 데이터 적재 함수 (배치 처리로 성능 향상)
def load_neo4j_data(nodes_csv: str, relationships_csv: str, session):
    """CSV 파일에서 Neo4j로 데이터를 적재합니다."""
    
    # 기존 데이터 삭제
    session.run("MATCH (n) DETACH DELETE n")
    print("✓ 기존 데이터 삭제 완료")
    
    # 노드 CSV 읽기
    nodes_df = pd.read_csv(nodes_csv, encoding='utf-8-sig')
    print(f"\n노드 CSV 로드: {len(nodes_df)}개")
    
    # 노드 타입별로 배치 적재
    node_types = nodes_df['type'].unique()
    
    for node_type in node_types:
        type_nodes = nodes_df[nodes_df['type'] == node_type]
        print(f"\n{node_type} 노드 적재 중... ({len(type_nodes)}개)")
        
        # 배치 크기 설정
        batch_size = 100
        
        for batch_start in range(0, len(type_nodes), batch_size):
            batch_end = min(batch_start + batch_size, len(type_nodes))
            batch = type_nodes.iloc[batch_start:batch_end]
            
            # 배치별 쿼리 생성
            queries = []
            for _, row in batch.iterrows():
                props = {}
                for col in type_nodes.columns:
                    if col not in ['id', 'type'] and pd.notna(row[col]):
                        value = row[col]
                        # 숫자 변환 시도
                        try:
                            if isinstance(value, (int, float)) or (isinstance(value, str) and value.replace('.', '').replace('-', '').isdigit()):
                                value = float(value) if '.' in str(value) else int(float(value))
                        except:
                            pass
                        props[col] = value
                
                # CREATE 쿼리 작성
                prop_strs = [f"{k}: ${k}" for k in props.keys()]
                create_props = ", ".join(["id: $id"] + prop_strs)
                query = f"CREATE (n:{node_type} {{{create_props}}})"
                params = {"id": row['id'], **props}
                queries.append((query, params))
            
            # 배치 실행
            for query, params in queries:
                try:
                    session.run(query, **params)
                except Exception as e:
                    print(f"  ⚠ 오류: {params.get('id')} - {e}")
            
            if (batch_start // batch_size + 1) % 10 == 0:
                print(f"  진행 중: {batch_end}/{len(type_nodes)} ({batch_end*100//len(type_nodes)}%)")
        
        print(f"  ✓ {node_type} 노드 적재 완료")
    
    # 관계 CSV 읽기 및 배치 적재
    relationships_df = pd.read_csv(relationships_csv, encoding='utf-8-sig')
    print(f"\n관계 CSV 로드: {len(relationships_df)}개")
    
    batch_size = 500
    for batch_start in range(0, len(relationships_df), batch_size):
        batch_end = min(batch_start + batch_size, len(relationships_df))
        batch = relationships_df.iloc[batch_start:batch_end]
        
        for _, rel in batch.iterrows():
            query = f"""
            MATCH (from:{rel['from_type']} {{id: $from_id}})
            MATCH (to:{rel['to_type']} {{id: $to_id}})
            MERGE (from)-[:{rel['relationship_type']}]->(to)
            """
            try:
                session.run(query, from_id=rel['from_id'], to_id=rel['to_id'])
            except Exception as e:
                print(f"  ⚠ 관계 오류: {rel['from_id']} -> {rel['to_id']} - {e}")
        
        if (batch_start // batch_size + 1) % 5 == 0:
            print(f"  진행 중: {batch_end}/{len(relationships_df)} ({batch_end*100//len(relationships_df)}%)")
    
    print(f"  ✓ 관계 적재 완료: {len(relationships_df)}개")
    
    # 최종 통계
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    print(f"\n✓ Neo4j 데이터 적재 완료: 노드 {node_count}개, 관계 {rel_count}개")

# 데이터 상태 확인 및 적재
with get_neo4j_session() as session:
    # 현재 상태 확인
    node_count = session.run("MATCH (n) RETURN count(n) as count").single()["count"]
    rel_count = session.run("MATCH ()-[r]->() RETURN count(r) as count").single()["count"]
    
    # 예상 데이터 개수 (CSV 확인) - preprocessing02.ipynb 결과 사용
    # preprocessing02.ipynb에서 생성한 완전한 그래프 스키마 사용
    NODES_CSV = "data/processed/neo4j_nodes_complete.csv"
    REL_CSV = "data/processed/neo4j_relationships_complete.csv"
    
    expected_nodes = 0
    expected_rels = 0
    
    if os.path.exists(NODES_CSV):
        nodes_df = pd.read_csv(NODES_CSV, encoding='utf-8-sig')
        expected_nodes = len(nodes_df)
    
    if os.path.exists(REL_CSV):
        rels_df = pd.read_csv(REL_CSV, encoding='utf-8-sig')
        expected_rels = len(rels_df)
    
    print(f"\n{'='*60}")
    print("Neo4j 데이터 상태 확인")
    print(f"{'='*60}")
    print(f"현재 노드: {node_count}개 (예상: {expected_nodes}개)")
    print(f"현재 관계: {rel_count}개 (예상: {expected_rels}개)")
    
    # 데이터가 없거나 불완전한 경우 적재
    if node_count == 0 or node_count < expected_nodes * 0.9:  # 90% 미만이면 재적재
        if node_count > 0:
            print(f"\n⚠ 데이터가 불완전합니다. 재적재를 진행합니다...")
        else:
            print(f"\n데이터 적재 시작...")
        
        if os.path.exists(NODES_CSV) and os.path.exists(REL_CSV):
            load_neo4j_data(NODES_CSV, REL_CSV, session)
        else:
            print(f"\n✗ CSV 파일을 찾을 수 없습니다:")
            print(f"  - {NODES_CSV}")
            print(f"  - {REL_CSV}")
            print("  먼저 preprocessing02.ipynb를 실행하여 데이터를 생성하세요.")
    else:
        print(f"\n✓ Neo4j 데이터가 정상적으로 적재되어 있습니다.")
        
        # 노드 타입별 통계
        print("\n노드 타입별 통계:")
        for label in session.run("CALL db.labels()").values():
            label_name = label[0]
            count = session.run(f"MATCH (n:{label_name}) RETURN count(n) as count").single()["count"]
            print(f"  - {label_name}: {count}개")
        
        # 관계 통계 확인
        print("\n관계 통계:")
        rel_stats = session.run("""
        MATCH ()-[r]->()
        RETURN type(r) as rel_type, count(r) as count
        ORDER BY count DESC
        """).data()
        for stat in rel_stats:
            print(f"  - {stat['rel_type']}: {stat['count']}개")
        
        # 예시: 강남구 관계 확인 (IN 관계)
        print("\n강남구 관계 확인 (예시):")
        gangnam_test = session.run("""
        MATCH (s:Shelter)-[r:IN]->(a:Admin {gu: '강남구'})
        RETURN count(s) as shelter_count
        """).single()
        if gangnam_test:
            print(f"  - 강남구 Shelter 노드 수 (IN 관계): {gangnam_test['shelter_count']}개")
        else:
            print("  - 강남구 관계를 찾을 수 없습니다.")
# Out:
# ============================================================
# Neo4j 데이터 상태 확인
# ============================================================
# 현재 노드: 4061개 (예상: 4061개)
# 현재 관계: 7095개 (예상: 4255개)
#
# ✓ Neo4j 데이터가 정상적으로 적재되어 있습니다.
#
# 노드 타입별 통계:
#   - Hazard: 4개
#   - Shelter: 3136개
#   - TemporaryHousing: 821개
#   - Admin: 25개
#   - Policy: 73개
#   - Event: 2개
#
# 관계 통계:
#   - IN: 6797개
#   - GUIDES: 292개
#   - TRIGGERS: 2개
#   - CAUSES: 2개
#   - INCREASES_RISK_OF: 1개
#   - UPDATES: 1개
#
# 강남구 관계 확인 (예시):
#   - 강남구 Shelter 노드 수 (IN 관계): 449개

# %%
# Gemini API 클라이언트 설정
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not GOOGLE_API_KEY:
    raise ValueError("GOOGLE_API_KEY 환경변수를 설정해주세요.")

gemini_client = genai.Client(api_key=GOOGLE_API_KEY)
print("✓ Gemini API 클라이언트 초기화 완료")

# Gemini 임베딩 함수 정의
class GeminiEmbeddingFunction:
    """Chroma용 Gemini 임베딩 함수"""
    
    def __init__(self, client: genai.Client, model: str = "gemini-embedding-001"):
        self.client = client
        self.model = model
    
    def __call__(self, input_texts: List[str]) -> List[List[float]]:
        """텍스트 리스트를 임베딩으로 변환"""
        try:
            # 기존 Chroma 컬렉션이 384차원을 기대하므로 명시적으로 지정
            result = self.client.models.embed_content(
                model=self.model,
                contents=input_texts,
                config=types.EmbedContentConfig(
                    output_dimensionality=384  # 기존 컬렉션과 호환되도록 384차원 사용
                )
            )
            # embeddings 리스트 반환
            # result.embeddings는 임베딩 객체 리스트
            embeddings = []
            for embedding in result.embeddings:
                # 임베딩 객체에서 벡터 값 추출
                if hasattr(embedding, 'values'):
                    # Embedding 객체인 경우
                    embeddings.append(list(embedding.values))
                elif isinstance(embedding, list):
                    # 이미 리스트인 경우
                    embeddings.append(embedding)
                elif hasattr(embedding, '__iter__') and not isinstance(embedding, str):
                    # 반복 가능한 객체인 경우
                    embeddings.append(list(embedding))
                else:
                    # 기타 경우 (단일 값 등)
                    embeddings.append([float(embedding)])
            return embeddings
        except Exception as e:
            print(f"임베딩 생성 오류: {e}")
            raise

# Gemini 임베딩 함수 인스턴스 생성
gemini_embedding_fn = GeminiEmbeddingFunction(gemini_client)
print("✓ Gemini 임베딩 함수 초기화 완료")
# Out:
# ✓ Gemini API 클라이언트 초기화 완료
# ✓ Gemini 임베딩 함수 초기화 완료

# %% [markdown]
# ## 2. Neo4j 스키마 정보 가져오기

# %%
def get_neo4j_schema(session) -> str:
    """Neo4j 그래프 스키마 정보를 가져옵니다 (preprocessing02.ipynb의 완전한 스키마 포함)."""
    
    # 노드 라벨 조회
    node_labels_query = "CALL db.labels()"
    node_labels = [record["label"] for record in session.run(node_labels_query)]
    
    # 관계 타입 조회
    rel_types_query = "CALL db.relationshipTypes()"
    rel_types = [record["relationshipType"] for record in session.run(rel_types_query)]
    
    # 실제로 사용되는 관계 타입만 필터링
    # preprocessing02.ipynb에서 생성한 관계 타입들: IN, GUIDES, TRIGGERS, CAUSES, INCREASES_RISK_OF, UPDATES 등
    actual_rels = []
    rel_counts = {}
    for rel_type in rel_types:
        count = session.run(f"MATCH ()-[r:{rel_type}]->() RETURN count(r) as count").single()["count"]
        if count > 0:  # 실제로 데이터가 있는 관계만 포함
            actual_rels.append(rel_type)
            rel_counts[rel_type] = count
    
    # 노드별 속성 정보 조회
    node_properties = {}
    for label in node_labels:
        props_query = f"""
        MATCH (n:{label})
        RETURN keys(n) as props
        LIMIT 1
        """
        result = session.run(props_query)
        record = result.single()
        if record:
            node_properties[label] = record["props"]
    
    # 스키마 문자열 생성
    schema_parts = ["# Neo4j Graph Schema (Complete from preprocessing02.ipynb)\n\n"]
    
    schema_parts.append("## Node Labels:\n")
    for label in sorted(node_labels):
        props = node_properties.get(label, [])
        # 주요 속성만 표시 (너무 길지 않도록)
        key_props = [p for p in props if p not in ['id', 'type']][:10]
        props_str = ", ".join(key_props) if key_props else "id, type"
        schema_parts.append(f"- {label}: {{id, type, {props_str}...}}")
    
    schema_parts.append("\n## Relationship Types:\n")
    # preprocessing02.ipynb에서 생성한 관계 타입들을 포함하여 표시
    # 중요 관계 타입 우선 표시
    important_rels = ['GUIDES', 'TRIGGERS', 'CAUSES', 'INCREASES_RISK_OF', 'UPDATES', 'IN']
    for rel_type in important_rels:
        if rel_type in actual_rels:
            schema_parts.append(f"- {rel_type} ({rel_counts[rel_type]}개)")
    
    # 나머지 관계 타입
    for rel_type in sorted(actual_rels):
        if rel_type not in important_rels:
            schema_parts.append(f"- {rel_type} ({rel_counts[rel_type]}개)")
    
    return "\n".join(schema_parts)

# 스키마 정보 확인
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    print(schema)
# Out:
# # Neo4j Graph Schema (Complete from preprocessing02.ipynb)
#
#
# ## Node Labels:
#
# - Admin: {id, type, gu, sido, sigungu...}
# - Event: {id, type, name, description, magnitude, pga, date, event_type...}
# - Hazard: {id, type, description, name, hazard_type, severity, hazard_code...}
# - Policy: {id, type, name, source, policy_id, content_length, disaster_type...}
# - Shelter: {id, type, lat, lon, shelter_id, sido, shelter_type, area, sigungu, name, address...}
# - TemporaryHousing: {id, type, facility_id, lon, lat, sido, address, sigungu, area, name...}
#
# ## Relationship Types:
#
# - GUIDES (292개)
# - TRIGGERS (2개)
# - CAUSES (2개)
# - INCREASES_RISK_OF (1개)
# - UPDATES (1개)
# - IN (6797개)

# %% [markdown]
# ## 3. Graph RAG 검색 함수

# %%
def generate_cypher_query(question: str, schema: str) -> str:
    """Ollama를 사용하여 자연어 질문을 Cypher 쿼리로 변환합니다 (preprocessing02.ipynb의 완전한 스키마 지원)."""
    
    prompt = f"""
당신은 Neo4j Cypher 쿼리 전문가입니다.
다음 그래프 스키마 정보를 참고하여, 사용자의 자연어 질문을 Cypher 쿼리로 변환하세요.

# Graph Schema:
{schema}

# 사용 가능한 노드 타입:
- Shelter, TemporaryHousing: 대피소 및 임시주거시설
- Admin: 행정구역 (gu, sigungu 속성)
- Hazard: 재난 유형 (지진, 산사태, 붕괴, 노화)
- Policy: 행동요령 정책
- Event: 재난 이벤트

# 사용 가능한 관계 타입:
- IN: Shelter/TemporaryHousing → Admin (위치 관계)
- GUIDES: Policy → Hazard (행동요령이 재난을 안내)
- TRIGGERS: Hazard → Hazard 또는 Event → Hazard (유발 관계)
- CAUSES: Hazard → Hazard (원인 관계)
- INCREASES_RISK_OF: Hazard → Hazard (위험 증가 관계)
- UPDATES: Event → Hazard (이벤트가 재난 정보 업데이트)

# 예시:
# - "몇 개" 질문: MATCH (s:Shelter)-[:IN]->(a:Admin {{gu: '강남구'}}) RETURN count(s)
# - "알려주세요" 질문: MATCH (s:Shelter)-[:IN]->(a:Admin {{gu: '서초구'}}) RETURN s.name, s.address LIMIT 10
# - "행동요령" 질문: MATCH (p:Policy)-[:GUIDES]->(h:Hazard {{hazard_type: '지진'}}) RETURN p.name, p.content LIMIT 5
# - "재난 관계" 질문: MATCH (h1:Hazard)-[:TRIGGERS]->(h2:Hazard) RETURN h1.name, h2.name

# 사용자 질문:
{question}

지침:
1. 질문의 의도를 정확히 파악하여 적절한 Cypher 쿼리를 생성하세요.
2. 노드 라벨과 관계 타입을 정확히 사용하세요. 위에 나열된 관계 타입을 활용하세요.
3. **중요**: "알려주세요", "찾고 싶어요", "어디" 같은 질문이면 반드시 실제 정보를 반환하도록 RETURN 절을 작성하세요.
   - 대피소: MATCH (s:Shelter)-[:IN]->(a:Admin {{gu: '서초구'}}) RETURN s.name, s.address, s.shelter_type LIMIT 10
   - 행동요령: MATCH (p:Policy)-[:GUIDES]->(h:Hazard) RETURN p.name, p.content LIMIT 5
   - COUNT()를 사용하지 마세요. 실제 노드 정보를 반환해야 합니다.
4. "몇 개" 또는 "개수" 질문이면 COUNT()를 사용하세요.
5. 재난 관련 질문은 Hazard, Policy, Event 노드를 활용하세요.
6. 쿼리만 반환하고 설명은 제외하세요.

Cypher 쿼리:
"""
    
    try:
        response = gemini_client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt.strip()
        )
        
        cypher_query = response.text.strip()
        # 코드 블록 제거 (```cypher 등)
        if cypher_query.startswith("```"):
            lines = cypher_query.split("\n")
            cypher_query = "\n".join(lines[1:-1]) if len(lines) > 2 else cypher_query
        
        return cypher_query
    except Exception as e:
        print(f"Cypher 쿼리 생성 오류: {e}")
        return None

# %%
def graph_rag_search(question: str, schema: str, session) -> Dict:
    """Graph RAG 검색: Neo4j에서 구조화된 정보를 검색합니다."""
    
    # 1. Cypher 쿼리 생성
    cypher_query = generate_cypher_query(question, schema)
    
    if not cypher_query:
        return {"query": None, "results": [], "count": 0, "error": "Cypher 쿼리 생성 실패"}
    
    print(f"\n[생성된 Cypher 쿼리]\n{cypher_query}\n")
    
    # 2. 쿼리 실행
    try:
        result = session.run(cypher_query)
        records = [dict(record) for record in result]
        
        # COUNT 등의 집계 함수 결과 처리
        # 집계 쿼리는 단일 레코드를 반환하므로, 결과 값 자체를 카운트로 사용
        actual_count = len(records)
        if actual_count == 1 and records:
            # COUNT 쿼리 결과 추출 시도
            for key, value in records[0].items():
                if 'count' in key.lower() or isinstance(value, (int, float)):
                    actual_count = int(value) if isinstance(value, (int, float)) else actual_count
        
        return {
            "query": cypher_query,
            "results": records,
            "count": actual_count
        }
    except Exception as e:
        print(f"  ⚠ Cypher 쿼리 실행 오류: {e}")
        return {
            "query": cypher_query,
            "results": [],
            "count": 0,
            "error": str(e)
        }

# %% [markdown]
# ## 4. Vector RAG 검색 함수

# %%
def vector_rag_search(question: str, collection, client: genai.Client, top_k: int = 5) -> Dict:
    """Vector RAG 검색: Chroma에서 관련 문서를 검색합니다 (Gemini 임베딩 사용)."""
    
    if collection is None:
        return {"results": [], "error": "Chroma 컬렉션이 없습니다."}
    
    try:
        # Gemini를 사용하여 질문을 임베딩으로 변환
        try:
            embedding_result = client.models.embed_content(
                model="gemini-embedding-001",
                contents=[question],
                config=types.EmbedContentConfig(
                    output_dimensionality=384  # 기존 컬렉션과 호환되도록 384차원 사용
                )
            )
            
            # 임베딩 벡터 추출 (예제 코드 참고)
            query_embedding = None
            if embedding_result.embeddings:
                embedding = embedding_result.embeddings[0]
                # 임베딩 객체에서 벡터 값 추출
                if hasattr(embedding, 'values'):
                    query_embedding = list(embedding.values)
                elif isinstance(embedding, list):
                    query_embedding = embedding
                elif hasattr(embedding, '__iter__') and not isinstance(embedding, str):
                    query_embedding = list(embedding)
                else:
                    query_embedding = [float(embedding)]
            
            if query_embedding is None:
                raise ValueError("임베딩 추출 실패")
            
            # Chroma에서 임베딩 기반 검색
            results = collection.query(
                query_embeddings=[query_embedding],
                n_results=top_k
            )
        except Exception as embed_error:
            # Gemini 임베딩 실패 시, Chroma의 기본 임베딩 함수 사용 (텍스트 기반)
            print(f"  ⚠ Gemini 임베딩 실패, 텍스트 기반 검색으로 전환: {embed_error}")
            results = collection.query(
                query_texts=[question],
                n_results=top_k
            )
        
        documents = []
        for i in range(len(results["ids"][0])):
            doc_id = results["ids"][0][i]
            doc_text = results["documents"][0][i] if results["documents"] else ""
            distance = results["distances"][0][i] if results["distances"] else None
            
            documents.append({
                "id": doc_id,
                "text": doc_text,
                "distance": distance
            })
        
        return {
            "results": documents,
            "count": len(documents)
        }
    except Exception as e:
        return {
            "results": [],
            "error": str(e)
        }

# %% [markdown]
# ## 5. Hybrid RAG: Graph + Vector 병합

# %%
def format_graph_results(graph_results: Dict, max_length: int = 2000) -> str:
    """Graph RAG 결과를 텍스트로 포맷팅합니다."""
    
    if graph_results.get("error"):
        return f"오류: {graph_results['error']}"
    
    result_count = graph_results.get('count', 0)
    result_parts = ["# Graph RAG 검색 결과\n"]
    result_parts.append(f"Cypher 쿼리: {graph_results.get('query', 'N/A')}\n")
    result_parts.append(f"결과 개수: {result_count}\n")
    
    if not graph_results.get("results"):
        result_parts.append("\n검색 결과가 없습니다.")
    else:
        results = graph_results["results"]
        # 결과가 많으면 요약
        if len(results) > 20:
            result_parts.append(f"\n## 요약: 총 {len(results)}개 결과 중 처음 10개만 표시\n")
            results = results[:10]
        
        for i, record in enumerate(results, 1):
            result_parts.append(f"\n## 결과 {i}")
            for key, value in record.items():
                # 값이 너무 길면 자르기
                value_str = str(value)
                if len(value_str) > 200:
                    value_str = value_str[:200] + "..."
                result_parts.append(f"- {key}: {value_str}")
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략 - 결과가 너무 많습니다]"
    
    return text


def format_vector_results(vector_results: Dict, max_length: int = 3000) -> str:
    """Vector RAG 결과를 텍스트로 포맷팅합니다."""
    
    if vector_results.get("error"):
        return f"오류: {vector_results['error']}"
    
    if not vector_results.get("results"):
        return "검색 결과가 없습니다."
    
    result_parts = ["# Vector RAG 검색 결과\n"]
    result_parts.append(f"결과 개수: {vector_results.get('count', 0)}\n")
    
    for i, doc in enumerate(vector_results["results"], 1):
        result_parts.append(f"\n## 문서 {i} (거리: {doc.get('distance', 'N/A')})")
        doc_text = doc.get('text', '')
        # 문서가 너무 길면 자르기
        if len(doc_text) > 800:
            doc_text = doc_text[:800] + "..."
        result_parts.append(doc_text)
    
    text = "\n".join(result_parts)
    # 전체 길이 제한
    if len(text) > max_length:
        text = text[:max_length] + "\n\n[이하 생략]"
    
    return text


def extract_shelter_info(graph_results: Dict, question: str = "") -> str:
    """Graph RAG 결과에서 대피소 정보를 추출하여 형식화된 답변을 생성합니다."""
    
    if not graph_results.get("results"):
        return None
    
    results = graph_results["results"]
    count = graph_results.get("count", 0)
    
    # Shelter 노드 정보 추출
    shelters = []
    
    for record in results:
        # record는 딕셔너리 형태: {'s': <Node ...>} 또는 {'name': '...', 'address': '...'} 등
        for key, value in record.items():
            # Neo4j Node 객체인 경우 (properties 속성이 있음)
            if hasattr(value, 'properties'):
                try:
                    props = value.properties
                    # Shelter 노드인지 확인 (labels 확인)
                    is_shelter = False
                    if hasattr(value, '_labels'):
                        labels = value._labels
                        is_shelter = 'Shelter' in labels or isinstance(labels, frozenset) and 'Shelter' in labels
                    elif hasattr(value, 'labels'):
                        labels = value.labels
                        is_shelter = 'Shelter' in labels
                    else:
                        # labels 속성이 없으면 문자열로 확인
                        value_str = str(value)
                        is_shelter = 'Shelter' in value_str or 'shelter' in key.lower()
                    
                    if is_shelter or 'name' in props or 'address' in props:  # Shelter 속성이 있으면 추가
                        shelter_name = props.get('name', '이름 없음')
                        shelter_address = props.get('address', '주소 없음')
                        shelter_type = props.get('shelter_type', '')
                        # 실제 값이 있는 경우만 추가
                        if shelter_name != '이름 없음' or shelter_address != '주소 없음':
                            shelters.append({
                                'name': shelter_name,
                                'address': shelter_address,
                                'type': shelter_type
                            })
                except Exception as e:
                    # properties 접근 실패 시 무시
                    pass
            # 딕셔너리인 경우 (직접 속성이 있는 경우 또는 dict(record)로 변환된 경우)
            elif isinstance(value, dict):
                if 'name' in value or 'address' in value or 'shelter_type' in value:
                    shelters.append({
                        'name': value.get('name', value.get('s.name', '이름 없음')),
                        'address': value.get('address', value.get('s.address', '주소 없음')),
                        'type': value.get('shelter_type', value.get('s.shelter_type', ''))
                    })
        # record 자체가 속성 딕셔너리인 경우 (RETURN s.name, s.address 같은 쿼리)
        # 모든 값을 확인했는데도 shelters에 추가되지 않은 경우
        if isinstance(record, dict):
            # record의 직접 속성 확인 (RETURN s.name 같은 경우)
            if 'name' in record or 'address' in record:
                record_name = record.get('name', record.get('s.name', ''))
                record_address = record.get('address', record.get('s.address', ''))
                if record_name or record_address:
                    # 중복 체크
                    is_duplicate = any(
                        s.get('name') == record_name and s.get('address') == record_address 
                        for s in shelters
                    )
                    if not is_duplicate:
                        shelters.append({
                            'name': record_name if record_name else '이름 없음',
                            'address': record_address if record_address else '주소 없음',
                            'type': record.get('shelter_type', record.get('s.shelter_type', ''))
                        })
    
    # Shelter 정보가 없으면 None 반환
    if not shelters:
        # 디버깅: 결과 구조 확인
        if results:
            print(f"  ⚠ 대피소 정보 추출 실패: 결과 {len(results)}개, 첫 번째 결과 타입: {type(results[0])}")
            if isinstance(results[0], dict):
                print(f"    첫 번째 결과 키: {list(results[0].keys())}")
                for key, value in list(results[0].items())[:3]:  # 처음 3개만
                    print(f"    - {key}: {type(value)}")
        return None
    
    # 중복 제거 (name과 address가 같은 경우)
    unique_shelters = []
    seen = set()
    for shelter in shelters:
        # '이름 없음'이나 '주소 없음'은 제외
        if shelter['name'] != '이름 없음' and shelter['address'] != '주소 없음':
            key = (shelter['name'], shelter['address'])
            if key not in seen:
                seen.add(key)
                unique_shelters.append(shelter)
    
    # 중복 제거 후에도 없으면 None
    if not unique_shelters:
        return None
    
    # 최대 10개만 표시
    display_shelters = unique_shelters[:10]
    remaining_count = len(unique_shelters) - len(display_shelters)
    
    # 질문에서 구 이름 추출
    import re
    gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
    gu_name = gu_match.group(1) if gu_match else ""
    
    # 답변 생성
    answer_parts = []
    
    if count > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {count}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {count}개의 대피소를 찾았습니다.\n")
    elif len(unique_shelters) > 0:
        if gu_name:
            answer_parts.append(f"{gu_name}에 총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
        else:
            answer_parts.append(f"총 {len(unique_shelters)}개의 대피소를 찾았습니다.\n")
    
    if display_shelters:
        answer_parts.append("주요 대피소 목록:")
        for i, shelter in enumerate(display_shelters, 1):
            shelter_type = shelter['type'] if shelter['type'] else '대피소'
            answer_parts.append(f"{i}. {shelter['name']} ({shelter_type})")
            if shelter['address'] and shelter['address'] != '주소 없음':
                answer_parts.append(f"   주소: {shelter['address']}")
        
        if remaining_count > 0:
            answer_parts.append(f"\n이 외에 {remaining_count}개의 대피소가 더 있습니다.")
    
    return "\n".join(answer_parts) if answer_parts else None

# %%
def hybrid_rag(question: str, schema: str, neo4j_session, chroma_collection) -> Dict:
    """Hybrid RAG: Graph RAG와 Vector RAG를 결합하여 검색하고 답변을 생성합니다."""
    
    # 1. Graph RAG 검색
    print("=" * 60)
    print("[Graph RAG 검색 중...]")
    graph_results = graph_rag_search(question, schema, neo4j_session)
    
    # 2. Vector RAG 검색
    print("\n" + "=" * 60)
    print("[Vector RAG 검색 중...]")
    vector_results = vector_rag_search(question, chroma_collection, gemini_client)
    
    # 3. 결과 포맷팅 (길이 제한)
    graph_text = format_graph_results(graph_results, max_length=2000)
    vector_text = format_vector_results(vector_results, max_length=3000)
    
    # 4. Ollama를 사용하여 최종 답변 생성
    print("\n" + "=" * 60)
    print("[Ollama를 통한 최종 답변 생성 중...]")
    print("  프롬프트 길이:", len(f"{question}\n{graph_text}\n{vector_text}"), "자")
    
    # 간결한 프롬프트 생성
    # 질문 유형에 따라 다른 지침 제공 (preprocessing02.ipynb의 완전한 스키마 활용)
    if '알려주세요' in question or '찾고 싶어요' in question or '어디' in question:
        instructions = """- Graph RAG 결과에 실제 대피소/시설 목록이 있으면 구체적인 이름과 주소를 제시하세요
- 대피소가 많으면 주요 대피소 몇 개를 예시로 제시하고, 총 개수를 알려주세요
- 간결하고 실행 가능한 답변 제공"""
    elif '행동' in question or '어떻게' in question or '요령' in question:
        instructions = """- Graph RAG 결과에 Policy(행동요령) 정보가 있으면 구체적으로 제시하세요
- Vector RAG 결과의 행동요령 문서를 참고하여 구체적인 행동 지침을 제공하세요
- 간결하고 실행 가능한 답변 제공"""
    elif '재난' in question or '위험' in question or 'Hazard' in question or '지진' in question or '산사태' in question:
        instructions = """- Graph RAG 결과에서 Hazard 노드와 관련 관계(TRIGGERS, CAUSES, INCREASES_RISK_OF)를 활용하세요
- 재난 간의 연쇄 관계를 명확히 설명하세요
- 구체적인 데이터와 근거를 제시하세요"""
    else:
        instructions = """- 구체적인 데이터(개수, 위치 등)를 명확히 제시
- Graph RAG와 Vector RAG 결과를 모두 활용하세요
- 간결하고 실행 가능한 답변 제공
- 근거를 간단히 명시"""
    
    final_prompt = f"""재난대응 전문가로서 아래 질문에 답변하세요.

질문: {question}

[Graph RAG 결과]
{graph_text}

[Vector RAG 결과]  
{vector_text}

지침:
{instructions}

답변:"""
    
    try:
        # "알려주세요", "찾고 싶어요" 같은 질문에 대해 먼저 extract_shelter_info로 구체적인 답변 생성
        graph_count = graph_results.get('count', 0)
        is_list_question = '알려주세요' in question or '찾고 싶어요' in question or ('어디' in question and graph_count > 0)
        
        extracted_info = None
        if is_list_question and graph_count > 0:
            # Graph RAG 결과에서 대피소 정보 추출
            extracted_info = extract_shelter_info(graph_results, question)
            if extracted_info:
                print(f"  ✓ 대피소 정보 추출 완료: {len(extracted_info)}자")
        
        final_answer = gemini_client.models.generate_content(
            model='gemini-2.5-flash',
            contents=final_prompt.strip()
        )
        
        # Ollama 응답 검증: 구체적인 대피소 정보가 포함되어 있는지 확인
        if final_answer and is_list_question and extracted_info:
            # Ollama 답변에 구체적인 대피소 이름이나 주소가 포함되어 있는지 확인
            has_specific_info = any(keyword in final_answer for keyword in ['주소:', '위치:', '명', '곳', '서울', '구'])
            # Ollama 답변이 일반적인 설명만 포함하고 있으면 추출된 정보 사용
            if not has_specific_info or len(final_answer) < 100:
                print(f"  ⚠ Ollama 답변이 일반적입니다. 추출된 정보를 사용합니다.")
                final_answer = extracted_info
        
        # Ollama 응답이 None이거나 비어있는 경우 fallback 답변 생성
        if not final_answer or (isinstance(final_answer, str) and final_answer.strip() == ""):
            print("  ⚠ Ollama 응답 생성 실패: 응답이 None이거나 비어있습니다.")
            # Fallback: 추출된 정보 또는 Graph RAG 결과 기반으로 답변 생성
            
            # 질문에서 구 이름 및 키워드 추출
            import re
            gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
            gu_name = gu_match.group(1) if gu_match else ""
            
            # 질문 유형에 따라 답변 생성
            if '몇 개' in question or '개수' in question or 'count' in question.lower():
                if graph_count > 0:
                    if gu_name:
                        final_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다."
                    else:
                        final_answer = f"검색 결과: {graph_count}개를 찾았습니다."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어디' in question or '위치' in question or '알려주세요' in question or '찾고 싶어요' in question:
                if extracted_info:
                    final_answer = extracted_info
                elif graph_count > 0:
                    final_answer = f"{gu_name if gu_name else '해당 지역'}에 있는 대피소는 총 {graph_count}개입니다. 상세 정보는 Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            elif '어떻게' in question or '행동' in question:
                # Vector RAG 결과를 활용한 답변
                vector_count = vector_results.get('count', 0)
                if vector_count > 0:
                    final_answer = "Vector RAG 검색 결과에 관련 행동 요령이 포함되어 있습니다. 문서를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            else:
                if graph_count > 0:
                    final_answer = f"검색 결과를 {graph_count}개 찾았습니다. Graph RAG 결과를 참고하세요."
                else:
                    final_answer = "검색 결과를 찾을 수 없습니다."
            
            print(f"  ✓ Fallback 답변 생성: {final_answer[:50]}...")
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": final_answer
        }
    except Exception as e:
        print(f"  ⚠ 최종 답변 생성 오류: {e}")
        # Fallback 답변 생성
        graph_count = graph_results.get('count', 0)
        
        # 질문에서 구 이름 추출
        import re
        gu_match = re.search(r'(강남구|서초구|송파구|강동구|광진구|성동구|중랑구|동대문구|성북구|강북구|노원구|도봉구|은평구|서대문구|마포구|용산구|종로구|중구|영등포구|양천구|강서구|구로구|금천구|관악구)', question)
        gu_name = gu_match.group(1) if gu_match else "해당 구"
        
        if '몇 개' in question or '개수' in question:
            if graph_count > 0:
                fallback_answer = f"{gu_name}에 있는 대피소는 {graph_count}개입니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        else:
            if graph_count > 0:
                fallback_answer = f"검색 결과를 {graph_count}개 찾았습니다. (오류 발생으로 간단 답변)"
            else:
                fallback_answer = f"오류 발생: {str(e)}. Graph RAG 결과: {graph_count}개"
        
        return {
            "question": question,
            "graph_results": graph_results,
            "vector_results": vector_results,
            "answer": fallback_answer,
            "error": str(e)
        }

# %%
# 필요한 라이브러리 import
import os
import json
from typing import List, Dict, Any, Optional
from dotenv import load_dotenv

# Neo4j
from neo4j import GraphDatabase

# ChromaDB
import chromadb
from chromadb.config import Settings

# Gemini API
from google import genai

# 기타
import pandas as pd

# 환경 변수 로드
load_dotenv()

print("라이브러리 로드 완료")
# Out:
# 라이브러리 로드 완료

# %% [markdown]
# ## 6. 테스트 질의 실행

# %%
# Neo4j 스키마 가져오기
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    # 시민 시나리오 테스트 질의 (preprocessing02.ipynb의 완전한 스키마를 활용)
    test_questions = [
        "강남구에 있는 대피소는 몇 개인가요?",
        "지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.",
        "임시주거시설은 어디에 있나요?",
        "지진 발생 시 어떻게 행동해야 하나요?",
        "공습경보가 발령되면 어떻게 해야 하나요?",
        "서초구의 옥외대피소 중 가장 큰 시설은 어디인가요?",
        "지진이 다른 재난을 유발할 수 있나요?",
        "산사태 위험 지역 근처에 대피소가 있나요?",
        "노후 시설물이 붕괴 위험을 증가시킬 수 있나요?"
    ]
    
    # 첫 번째 질의 테스트
    question = test_questions[0]
    print(f"\n{'='*60}")
    print(f"질문: {question}")
    print(f"{'='*60}\n")
    
    result = hybrid_rag(
        question=question,
        schema=schema,
        neo4j_session=session,
        chroma_collection=chroma_collection
    )
    
    print("\n" + "=" * 60)
    print("=" * 60)
    print(result.get("answer", "답변 생성 실패"))
# Out:
# ============================================================
# 질문: 강남구에 있는 대피소는 몇 개인가요?
# ============================================================
#
# ============================================================
# [Graph RAG 검색 중...]
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter)-[:IN]->(a:Admin {gu: '강남구'}) RETURN count(s)
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3161 자
#
# ============================================================
# ============================================================
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""강남구에는 총 **449개**의 대피소가 있습니다.
#
# **근거:** Graph RAG 검색 결과 (강남구 내 대피소 수 쿼리 결과)"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='DJIGafrWMMep1e8PgraEcA' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=41,
#   prompt_token_count=2048,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2048
#     ),
#   ],
#   thoughts_token_count=281,
#   total_token_count=2370
# ) automatic_function_calling_history=[] parsed=None

# %%
# Neo4j 스키마 가져오기
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    # 시민 시나리오 테스트 질의 (preprocessing02.ipynb의 완전한 스키마를 활용)
    test_questions = [
        "2025-11-02 15:00 서울특별시 동남쪽 2km 지역 M6.3 지진 / 낙하물, 여진주의  국민재난안전포털 참고 대응",
        "지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.",
        "지진 발생 시 어떻게 행동해야 하나요?",
        "노후 시설물이 붕괴 위험을 증가시킬 수 있나요?"
    ]
    
    # 첫 번째 질의 테스트
    question = test_questions[0]
    print(f"\n{'='*60}")
    print(f"질문: {question}")
    print(f"{'='*60}\n")
    
    result = hybrid_rag(
        question=question,
        schema=schema,
        neo4j_session=session,
        chroma_collection=chroma_collection
    )
    
    print("\n" + "=" * 60)
    print("=" * 60)
    print(result.get("answer", "답변 생성 실패"))
# Out:
# ============================================================
# 질문: 2025-11-02 15:00 서울특별시 동남쪽 2km 지역 M6.3 지진 / 낙하물, 여진주의  국민재난안전포털 참고 대응
# ============================================================
#
# ============================================================
# [Graph RAG 검색 중...]
# Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `content` does not exist. Verify that the spelling is correct.', position=<SummaryInputPosition line=3, column=18, offset=118>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 118, 'line': 3, 'column': 18}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "MATCH (p:Policy)-[:GUIDES]->(h:Hazard)\nWHERE h.hazard_type = '지진' OR h.name = '낙하물' OR h.name = '여진'\nRETURN p.name, p.content\nLIMIT 5"
# [생성된 Cypher 쿼리]
# MATCH (p:Policy)-[:GUIDES]->(h:Hazard)
# WHERE h.hazard_type = '지진' OR h.name = '낙하물' OR h.name = '여진'
# RETURN p.name, p.content
# LIMIT 5
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3474 자
#
# ============================================================
# ============================================================
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""네, 재난대응 전문가로서 2025년 11월 2일 15시 서울특별시 동남쪽 2km 지역에서 발생한 규모 6.3 지진 상황과 관련하여 국민 행동 요령 및 연쇄 재난 위험성에 대해 답변드리겠습니다. 낙하물 및 여진에 대한 주의는 필수적이며, 국민재난안전포털의 정보를 바탕으로 대응 방안을 설명하겠습니다.
#
# **1. 재난 상황 개요 및 즉각적인 대응**
#
# 서울 동남쪽 2km 지역에서 발생한 M6.3 지진은 수도권에 심각한 피해를 유발할 수 있는 중대 재난 상황입니다. 도심 지역의 특성상 고층 건물의 붕괴 위험, 낙하물 발생, 대규모 정전, 화재 발생 등 복합적인 재난으로 이어질 가능성이 매우 높습니다.
#
# **즉각적인 행동 요령:**
#
# *   **실내:** 테이블 밑이나 튼튼한 가구 아래로 몸을 숨기고, 머리와 목을 보호합니다. 진동이 멈춘 후 가스, 전기 등을 차단하고 비상구로 대피합니다.
# *   **실외:** 건물 외벽, 담벼락, 전신주 등 낙하 위험이 있는 곳에서 멀리 떨어져 넓은 공간으로 대피합니다.
# *   **이동 중 (차량, 대중교통):** 흔들림이 느껴지면 즉시 안전하게 정차하고, 대중교통 이용 시 승무원의 안내에 따릅니다.
#
# **2. 지진으로 인한 연쇄 재난(Cascading Disaster) 위험성 및 대응 방안**
#
# 제공된 Graph RAG 결과는 현재 공백으로, 특정 정책 노드와 재난 간의 직접적인 관계를 파악하기 어렵습니다. 그러나 Vector RAG 검색 결과를 통해 지진 발생 시 예상되는 다양한 2차 재난 및 이에 대한 국민행동요령을 유추할 수 있으며, 이는 재난 간의 연쇄 관계를 명확히 보여줍니다.
#
# **가. 낙하물 및 건물 붕괴 위험 증가 (지진 → 건물 손상 → 낙하물, 추가 붕괴 위험)**
#
# *   M6.3 지진은 건물 구조물에 심각한 손상을 입혀 **낙하물 발생** 위험을 극대화합니다. 이는 간판, 유리창, 외벽 마감재 등뿐만 아니라 실내의 가구, 전등 등에서도 발생할 수 있습니다.
# *   **여진**은 이미 손상된 건물에 추가적인 충격을 주어 **건물 붕괴 위험**을 증가시킵니다.
# *   **대응:**
#     *   건물 밖으로 대피 시에는 건물과 간판, 전선 등이 없는 넓은 공간을 찾아 이동합니다.
#     *   여진 발생 시에는 즉시 안전한 곳으로 몸을 피하고, 이미 손상된 건물 주변에는 접근하지 않습니다.
#
# **나. 화재 및 폭발 사고 (지진 → 가스/전기 시설 손상 → 화재/폭발)**
#
# Vector RAG **문서 2 (폭발사고 국민행동요령)**에 따르면, 폭발사고는 "매우 광범위한 피해를 유발하며, 인명피해뿐만 아니라 건물 붕괴, 대규모 화재 등 연쇄 재난으로 이어질 수 있습니다." 지진으로 인한 가스 배관 파손, 전기 합선 등은 대규모 화재와 폭발로 이어질 가능성이 매우 높습니다. 특히 "가스 누출 시 즉시 조치: 환기, 전기스위치 사용 금지, 화기 사용 절대 금지"는 지진 후의 핵심 행동입니다.
#
# *   **연쇄 관계:** 지진 발생 → 도시 가스관 손상 및 전력선 단선 → 가스 누출 및 전기 스파크 → 대규모 화재 및 폭발 발생 (특히 밀집된 주거 지역, 공장 지역에서 위험)
# *   **대응:**
#     *   지진 진동이 멈추면 즉시 가스 밸브를 잠그고 전기 차단기를 내립니다.
#     *   가스 냄새가 나면 창문을 열어 환기하고, 스위치를 켜거나 끄지 않으며, 성냥이나 라이터를 사용하지 않습니다. 즉시 대피 후 119에 신고합니다.
#
# **다. 정전 및 전력 부족 (지진 → 전력 시설 손상 → 정전)**
#
# Vector RAG **문서 4 (정전 및 전력부족 국민행동요령)**에서 언급된 바와 같이, "전력수급 부족으로 인한 정전은 일상생활, 산업, 의료 등 사회 전반에 심각한 영향을 미칩니다." M6.3 지진은 전력망 및 발전 시설에 광범위한 손상을 입혀 대규모 정전을 유발할 것입니다.
#
# *   **연쇄 관계:** 지진 발생 → 변전소, 송전탑, 배전망 등 전력 시설 파손 → 광범위한 정전 → 통신 마비, 교통 신호 마비, 의료 기기 작동 중단, 난방/냉방 문제 등 생활 기반 마비
# *   **대응:**
#     *   비상 랜턴, 라디오, 보조 배터리 등을 미리 준비합니다.
#     *   엘리베이터 이용 중 정전 시, 침착하게 비상 호출 버튼을 누르고 구조를 기다립니다.
#     *   비상 상황 시에는 휴대전화 사용을 최소화하여 배터리를 보존하고, 가족 및 지인과 연락 방법을 미리 정해둡니다.
#
# **라. 교통 시설 마비 및 사고 (지진 → 철도/지하철, 도로 터널 손상 → 대규모 교통 마비)**
#
# Vector RAG **문서 1 (철도·지하철 사고 국민행동요령)**과 **문서 3 (도로 터널사고 국민행동요령)**은 폐쇄된 공간에서의 대피 및 대응의 중요성을 강조합니다. 지진으로 인해 철도/지하철의 탈선, 터널 붕괴, 도로 파손 및 교량 손상 등이 발생하여 대규모 교통 마비와 인명 피해로 이어질 수 있습니다.
#
# *   **연쇄 관계:** 지진 발생 → 철도/지하철 선로 변형, 터널 구조물 손상, 도로 파손, 교량 붕괴 → 열차 탈선 및 정지, 터널 내 차량 고립 및 충돌, 도로 통행 불능 → 긴급 구호 인력 및 장비 접근 지연
# *   **대응:**
#     *   지하철 이용 중 지진 발생 시 승무원의 지시에 따라 침착하게 행동하며, 비상버튼을 통해 승무원과 연락합니다.
#     *   터널 이용 중 지진 발생 시 차량을 안전하게 정차하고 엔진을 끈 후 신속하게 차에서 내려 터널 내 비상구를 통해 대피합니다.
#
# **3. 재난 전문가로서의 종합 의견 및 권고**
#
# 이번 M6.3 지진 시나리오는 서울과 같은 고밀도 도시에서 복합적인 재난이 동시다발적으로 발생할 수 있음을 시사합니다.
#
# *   **국민 개개인의 대비:** 평소 비상용품(생수, 비상식량, 구급약품, 손전등, 라디오, 보조배터리 등)을 준비하고, 가족 비상계획(모임 장소, 연락 방법)을 세워야 합니다.
# *   **재난 정보 확인:** 지진 발생 후에는 정부 및 지자체의 공식 채널(국민재난안전포털, TV, 라디오, 재난문자 등)을 통해 최신 정보를 확인하고, 신뢰할 수 없는 정보에 현혹되지 않아야 합니다.
# *   **안전 취약 계층 배려:** 어린이, 노약자, 장애인 등 안전 취약 계층의 대피 및 구조에 각별한 주의와 협력이 필요합니다.
# *   **침착한 행동:** 패닉은 더 큰 혼란과 피해를 유발합니다. 위에서 언급된 국민행동요령을 숙지하고 침착하게 대응하는 것이 중요합니다.
#
# 재난은 언제든 발생할 수 있습니다. 철저한 사전 대비와 국민들의 적극적인 협조가 인명 및 재산 피해를 최소화하는 데 결정적인 역할을 할 것입니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='LpIGaavWM8ezvr0PwM7loA0' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=1855,
#   prompt_token_count=2238,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2238
#     ),
#   ],
#   thoughts_token_count=1906,
#   total_token_count=5999
# ) automatic_function_calling_history=[] parsed=None

# %%
# 여러 질의 일괄 실행
with get_neo4j_session() as session:
    schema = get_neo4j_schema(session)
    
    results = []
    for i, question in enumerate(test_questions, 1):
        print(f"\n\n{'#'*60}")
        print(f"질의 {i}/{len(test_questions)}: {question}")
        print(f"{'#'*60}\n")
        
        result = hybrid_rag(
            question=question,
            schema=schema,
            neo4j_session=session,
            chroma_collection=chroma_collection
        )
        
        results.append(result)
        
        print(f"\n{'='*60}")
        print("[최종 답변]")
        print(f"{'='*60}")
        print(result)
        print(result.get("answer", "답변 생성 실패"))
        print(f"\n{'='*60}\n")
# Out:
# ############################################################
# 질의 1/4: 2025-11-02 15:00 서울특별시 동남쪽 2km 지역 M6.3 지진 / 낙하물, 여진주의  국민재난안전포털 참고 대응
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `content` does not exist. Verify that the spelling is correct.', position=<SummaryInputPosition line=3, column=18, offset=132>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 132, 'line': 3, 'column': 18}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "MATCH (p:Policy)-[:GUIDES]->(h:Hazard)\nWHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'\nRETURN p.name, p.content\nLIMIT 5"
# [생성된 Cypher 쿼리]
# MATCH (p:Policy)-[:GUIDES]->(h:Hazard)
# WHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'
# RETURN p.name, p.content
# LIMIT 5
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3488 자
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '2025-11-02 15:00 서울특별시 동남쪽 2km 지역 M6.3 지진 / 낙하물, 여진주의  국민재난안전포털 참고 대응', 'graph_results': {'query': "MATCH (p:Policy)-[:GUIDES]->(h:Hazard)\nWHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'\nRETURN p.name, p.content\nLIMIT 5", 'results': [{'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}], 'count': 5}, 'vector_results': {'results': [{'id': '철도·지하철 사고 국민행동요령', 'text': '# 국민재난안전포털 철도·지하철 사고 국민행동요령 (2025)\n\n**국토교통부 & 행정안전부 발행**\n\n---\n\n## 철도·지하철 사고 개요\n\n### 사고의 위험성\n\n철도·지하철 사고는 **폐쇄된 공간에서 다수 인원이 탑승**하고 있어 **신속한 대피와 침착한 대응**이 매우 중요합니다. 화재, 충돌, 테러 등 다양한 상황에 대비해야 합니다.\n\n### 대피의 기본 원칙\n\n- **승무원 및 안내방송 따르기**\n- **질서 있는 행동**\n- **안전취약계층 먼저 대피**\n- **선로 진입 주의**\n\n---\n\n## 지하철 화재 발생 시\n\n### 1단계: 승무원 연락\n\n**비상버튼 이용:**\n- **노약자·장애인석 옆에 있는 비상버튼을 눌러 승무원과 연락**\n- 위치 정확히 알리기\n- 상황 설명\n\n**인터폰 이용:**\n- 객실 양 끝에 있는 인터폰 이용\n- 승무원에게 즉시 알리기\n\n### 2단계: 초기 소화\n\n**소화기 이용:**\n- 여유가 있다면 **객차마다 2개씩 비치된 소화기를 이용하여 불을 끝**\n- 소화기 위치 파악\n- 불의 하단부 겨냥\n\n**소화 불가 시:**\n- 무리하게 소화 시도 금지\n- 즉시 대피 전환\n\n### 3단계: 호흡기 보호\n\n**코와 입 가리기:**\n- **코와 입을 수건, 티슈, 옷소매 등으로 막기**\n- 젖은 천 사용 (가능할 경우)\n- 연기 흡입 최소화\n\n**호흡 관리:**\n- 천천히, 얕게 호흡\n- 신선한 공기 지역으로 이동\n\n### 4단계: 다른 객차로 이동\n\n**화재 미발생 객차로:**\n- **화재가 발생하지 않은 다른 객실로 이동**\n- 객차 연결부를 통해 이동\n- 신속하지만 질서 있게\n\n### 5단계: 출입문 개방\n\n**자동 개방:**\n- 열차 정지 후 자동으로 개방 대기\n\n**수동 개방:**\n- **출입문이 자동으로 열리지 않으면 수동으로 문을 열기**\n- 수동 손잡이 사용\n\n**비상용 망치:**\n- **여의치 않으면 비상용 망치를 이용하여 유리창을 깨기**\n- 유리 깨기 후 안전하게 탈출\n\n**소화기로 유리 깨기:**\n- **망치가 없으면 소화기로 유리창을 깨기**\n\n### 6단계: 스크린도어(PSD) 개방\n\n**빨간색 바 이용:**\n- **스크린도어(PSD)가 열리지 않을 경우 스크린도어에 설치된 빨간색 바를 밀고 나가기**\n- 위치 사전 파악\n- 신속히 나가기\n\n### 7단계: 비상구로 대피\n\n**조명 확인:**\n- 대피유도 등 확인\n- 비상구 위치 파악\n\n**정전 시:**\n- **정전 시에는 대피유도 등을 따라 출구로 나가기**\n- **유도등이 보이지 않을 때는 벽을 짚으면서 나가기**\n- **시각장애인 안내용 보도블록을 따라 나가기**\n\n**신속 대피:**\n- **비상구로 신속히 대피합시다**\n- 침착하고 질서 있게\n\n### 8단계: 지상 대피\n\n**지상으로 대피:**\n- 가능한 한 지상으로 대피\n\n**터널 대피:**\n- **지상으로 대피가 여의치 않을 때는 전동차 진행방향 터널로 대피**\n- 선로 진입 주의\n- 반대편 열차 주의\n\n---\n\n## 지하철 출입문 개방 방법\n\n### 수동으로 문 열기\n\n**수동 손잡이 위치:**\n- 출입문 양쪽에 위치\n- 사전 확인 필수\n\n**개방 방법:**\n1. 수동 손잡이를 찾기\n2. 손잡이를 잡고 끌어당기거나 밀기\n3. 문이 열려 신속히 탈출\n\n**비상 상황:**\n- 열차 정지 후 시도\n- 무리하게 힘 쓰지 말기\n- 다른 방법 시도\n\n### 비상용 망치 이용\n\n**망치 위치:**\n- 출입문 근처에 설치\n- 빨간색 케이스 안\n- 사전 위치 파악\n\n**유리 깨기 방법:**\n1. 망치를 잡기\n2. 유리 가장자리 또는 중앙을 강하게 치기\n3. 깨진 유리 피해 탈출\n\n**안전 주의:**\n- 깨진 유리 파편 주의\n- 손 보호\n- 천천히 조심히 탈출\n\n### 스크린도어(PSD) 개방\n\n**손잡이 이용:**\n- 양쪽 손잡이를 밀거나 당기기\n\n**빨간색 바:**\n- 스크린도어에 설치된 빨간색 바 확인\n- 빨간색 바를 밀어 개방\n- 신속히 탈출\n\n---\n\n## 지하철 스크린도어(PSD) 개방\n\n### 정상 개방\n\n**자동 개방:**\n- 열차 정지 시 자동으로 스크린도어 개방\n- 대기\n\n### 수동 개방\n\n**손잡이 조작:**\n1. **스크린도어 양쪽 손잡이를 양쪽으로 밀기**\n2. 또는 당기기\n3. 신속히 탈출\n\n**빨간색 바 조작:**\n1. **스크린도어에 설치된 빨간색 바 찾기**\n2. **빨간색 바를 밀고 탈출**\n3. 신속히 나가기\n\n---\n\n## 지하철 일반 사고 대응\n\n### 기본 행동요령\n\n**승무원 연락:**\n- **객실 양 끝에 있는 인터폰으로 승무원에게 알립니다**\n- 상황 설명\n- 지시 받기\n\n**화재 신고:**\n- **화재 발생 시 119에 신고**\n- 위치 정확히\n- 동시에 승무원에게도 알리기\n\n**초기 소화:**\n- **여유가 있다면 객실 양 끝에 비치된 소화기로 불을 끝**\n- 무리하지 말기\n\n**호흡기 보호:**\n- **입과 코를 젖은 천으로 막고 화재가 발생하지 않은 다른 객실로 이동**\n- 신속하게 이동\n- 연기 회피\n\n### 대피 원칙\n\n**안내방송 준수:**\n- **안내방송과 승무원의 안내에 따라 질서있게 대피합시다**\n- 공식 지시 따르기\n\n**약자 배려:**\n- **부상자, 노약자, 임산부가 먼저 대피할 수 있도록 배려하고 돕습니다**\n- 함께 대피\n- 도움 제공\n\n**출입문 개방:**\n- **문이 열리지 않으면 열차가 멈춘 후에 안내방송에 따라 비상핸들이나 비상콕크를 돌려 문을 열고 탈출합니다**\n- 승무원 지시 대기\n\n**스크린도어:**\n- **스크린도어는 손잡이를 양쪽으로 밀거나 빨간색 바를 밀고 탈출**\n- 신속히\n\n### 선로 대피 시 주의\n\n**감전 위험:**\n- **선로로 대피할 때에는, 감전위험이 있으므로 반드시 대피안내에 따라 반대편 선로의 열차 진입에 유의하며 대피합니다**\n- 제3 레일 주의 (전기 위험)\n- 반대편 열차 주시\n\n**선로 위 이동:**\n- 최소한의 선로 접촉\n- 승무원 지시 따르기\n- 신속하고 신중하게\n\n### 비상구 대피\n\n**유도등 따르기:**\n- **대피할 때에는 대피 유도등을 따라 침착하게 비상구로 대피합니다**\n- 조명 확인\n- 방향 감각 유지\n\n**정전 시:**\n- 벽을 짚으며 이동\n- 시각장애인용 보도블록 활용\n- 다른 승객과 함께\n\n---\n\n## 고속철도 탈선·충돌사고\n\n### 기본 행동요령\n\n**승무원 지시:**\n- **기관사 및 승무원의 안내방송에 따라 대피합니다**\n- 공식 지시 준수\n\n**질서 있는 대피:**\n- **승무원 ...
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""재난대응 전문가로서 2025년 11월 2일 15시 서울특별시 동남쪽 2km 지역에서 발생한 규모 6.3 지진 발생 상황에 대해 다음과 같이 대응 방안을 제시합니다. 낙하물 및 여진에 대한 특별한 주의가 필요하며, 국민재난안전포털의 정보를 기반으로 대응하겠습니다.
#
# ---
#
# ### **[Graph RAG 결과 분석 및 활용]**
#
# 제공된 Graph RAG 검색 결과는 `p.name`과 `p.content` 모두 비어 있는(None) 상태로, 특정 지진, 낙하물, 여진 관련 정책 콘텐츠를 직접적으로 반환하지 않았습니다. 이는 현재 Graph RAG 데이터베이스 내에 해당 조건에 부합하는 정책 노드와 콘텐츠가 직접적으로 연결되어 있지 않거나, 검색 결과가 비어 있음을 의미합니다.
#
# 그러나 Cypher 쿼리(`MATCH (p:Policy)-[:GUIDES]->(h:Hazard) WHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'`)는 **지진(Hazard), 낙하물(Hazard), 여진(Hazard)**이라는 재난 유형 간의 연관성과, 이에 대한 정책(Policy)이 존재할 것이라는 구조적 가정을 보여줍니다. 따라서 Graph RAG 결과가 비어 있음에도 불구하고, 지진으로 인한 주요 2차 피해 및 연쇄 효과를 분석하고 이에 대한 대응 원칙을 수립하는 데 있어 Hazard 노드 및 관계의 개념을 활용할 것입니다.
#
# ---
#
# ### **[M6.3 지진 발생 시 재난 간 연쇄 관계 및 대응 방안]**
#
# 규모 6.3의 지진은 서울과 같은 인구 밀집 지역에서 발생할 경우, 광범위한 직접적인 피해와 더불어 다양한 연쇄 재난을 유발할 수 있습니다. 국민재난안전포털의 일반적인 지침과 제공된 Vector RAG 결과를 바탕으로 주요 연쇄 관계 및 대응 방안을 설명합니다.
#
# **1. 지진 → 낙하물 발생 및 건물 붕괴 위험 (직접적 연쇄)**
# *   **관계:** 지진은 건물 및 구조물의 흔들림을 유발하여 **낙하물**(`TRIGGERS` Hazard) 발생의 직접적인 원인이 되며, 심각할 경우 건물 붕괴(`CAUSES` Hazard)로 이어집니다.
# *   **대응:**
#     *   **지진 발생 즉시:** "DROP, COVER, HOLD ON" 원칙에 따라 몸을 낮추고, 튼튼한 탁자 아래 등으로 숨어 머리와 목을 보호하며, 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡습니다. 유리창, 가구 등 낙하물이 떨어질 수 있는 곳에서 멀리 떨어집니다.
#     *   **흔들림이 멈춘 후:** 주변을 살피고 안전이 확보된 후 대피합니다. 건물 밖으로 대피 시에는 떨어지는 간판, 유리창, 외벽 등에 특히 주의하며, 열린 공간으로 이동합니다.
#
# **2. 지진 → 여진 발생 (지속적 연쇄)**
# *   **관계:** 본 지진(`CAUSES` Hazard) 발생 후에는 크고 작은 **여진**(`TRIGGERS` Hazard)이 수일, 수주간 지속될 수 있으며, 이는 이미 약화된 구조물에 추가적인 피해를 주거나 심리적 불안감을 조성합니다.
# *   **대응:**
#     *   **대피 후:** 안전한 장소로 대피하더라도 여진에 대비하여 항상 주변 상황을 주시하고, 추가적인 흔들림 발생 시 즉각적으로 다시 "DROP, COVER, HOLD ON" 자세를 취할 준비를 합니다.
#     *   **피해 점검:** 거주지나 근무지로 돌아갈 때에는 전문가의 안전 점검 후 진입하며, 여진으로 인한 추가적인 피해 가능성을 염두에 둡니다.
#
# **3. 지진 → 정전 및 전력 부족 (2차 연쇄)**
# *   **관계:** 지진으로 인해 전력선, 변압기 등 전력 공급 시설이 파손되어 광범위한 **정전**(`TRIGGERS` Hazard)이 발생할 수 있습니다. 이는 통신 두절, 교통 마비, 냉난방 불가 등 추가적인 피해를 유발합니다.
# *   **근거:** **Vector RAG 문서 4 ("국민재난안전포털 정전 및 전력부족 국민행동요령 (2025)")**는 정전 발생 시의 대응 요령을 제시합니다.
# *   **대응:**
#     *   **정전 발생 시:** 침착하게 행동하며, 비상 랜턴이나 휴대용 손전등을 사용하여 어둠에 적응합니다. 휴대폰 충전량을 아껴두고, 필요한 경우 비상 발전기를 가동합니다. 엘리베이터 내부에 갇히지 않도록 주의하고, 만약 갇혔다면 비상벨을 누릅니다.
#     *   **비상 대비:** 평소 비상용품(손전등, 라디오, 건전지, 응급약품, 식수 등)을 미리 준비하여 정전 상황에 대비합니다.
#
# **4. 지진 → 가스 누출 및 폭발 사고 (2차 연쇄)**
# *   **관계:** 지진으로 인해 가스 배관이 파손될 경우 **가스 누출**(`CAUSES` Hazard)이 발생하고, 이는 작은 불씨나 스파크에도 **폭발 사고**(`TRIGGERS` Hazard)로 이어질 수 있어 매우 위험합니다.
# *   **근거:** **Vector RAG 문서 2 ("국민재난안전포털 폭발사고 국민행동요령 (2025)")**는 가스 누출 시 즉시 환기, 전기 스위치 사용 금지, 화기 사용 절대 금지 등의 조치를 강조합니다. 통계적으로 공동주택 및 단독주택에서의 폭발사고가 37%를 차지합니다.
# *   **대응:**
#     *   **가스 냄새 감지 시:** 즉시 창문과 출입문을 활짝 열어 환기시키고, 도시가스 밸브를 잠급니다. 절대 전기 스위치를 조작하거나 성냥, 라이터 등 화기를 사용해서는 안 됩니다.
#     *   **신고:** 안전한 곳으로 대피한 후 관리사무소 또는 가스회사에 신고합니다.
#
# **5. 지진 → 철도/지하철 및 도로 터널 사고 (교통 인프라 연쇄)**
# *   **관계:** 지진은 철도 선로, 지하철 터널, 도로 및 터널 구조물에 손상을 주어 **철도·지하철 사고**(`INCREASES_RISK_OF` Hazard)나 **도로 터널 사고**(`INCREASES_RISK_OF` Hazard) 발생 위험을 증가시키고, 대피를 어렵게 만들 수 있습니다.
# *   **근거:** **Vector RAG 문서 1 ("국민재난안전포털 철도·지하철 사고 국민행동요령 (2025)")**과 **Vector RAG 문서 3 ("국민재난안전포털 도로 터널사고 국민행동요령 (2025)")**은 폐쇄된 공간에서의 신속한 대피와 침착한 대응의 중요성을 강조합니다.
# *   **대응:**
#     *   **지하철/열차 내:** 승무원 및 안내방송에 따라 침착하게 행동하며, 비상 버튼이나 인터폰으로 상황을 알립니다. 화재 발생 시 소화기를 사용하고, 연기 흡입 방지를 위해 코와 입을 가립니다. 승무원의 지시에 따라 질서 있게 대피합니다.
#     *   **도로 터널 내:** 차량을 갓길이나 비상주차대에 정차하고 엔진을 끈 후 키를 꽂아둔 채 하차합니다. 휴대전화 또는 터널 내 긴급전화로 신고하고, 터널 입구 방향이나 비상구, 피난연결통로를 통해 안전한 곳으로 대피합니다.
#
# ### **[종합적인 대응 원칙]**
#
# 1.  **초기 행동:** 지진 발생 시 "DROP, COVER, HOLD ON" 원칙을 준수하고, 낙하물로부터 몸을 보호합니다.
# 2.  **안전 확보 및 대피:** 흔들림이 멈추면 여진에 대비하며 안전한 장소로 대피합니다. 대피 시에는 떨어지는 물건에 주의하고, 개방된 공간으로 이동합니다.
# 3.  **2차 재난 대비:** 정전, 가스 누출, 교통 인프라 마비 등 2차 재난에 대한 정보를 습득하고 각 상황에 맞는 국민행동요령에 따라 침착하게 대응합니다. 특히 가스 누출 시 환기 및 화기 사용 금지를 철저히 지킵니다.
# 4.  **정보 확인:** 국민재난안전포털(또는 기타 공신력 있는 매체)을 통해 재난 상황과 정부의 안내를 지속적으로 확인하고 따릅니다.
# 5.  **비상용품 준비:** 평소 비상식량, 식수, 응급약품, 손전등, 라디오 등을 포함한 비상 배낭을 준비하여 예기치 않은 상황에 대비합니다.
# 6.  **가족 및 이웃 확인:** 안전한 장소로 대피 후 가족 구성원의 안전을 확인하고, 주변의 도움이 필요한 이웃을 살핍니다.
#
# 이러한 지침은 M6.3 지진 발생 시 국민의 생명과 재산을 보호하고, 연쇄 재난으로부터 피해를 최소화하는 데 중요한 역할을 할 것입니다."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='UJIGaeC8POvE1e8PyJOpyQk',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=2165,
#     prompt_token_count=2240,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=2240
#       ),
#     ],
#     thoughts_token_count=1688,
#     total_token_count=6093
#   )
# )}
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""재난대응 전문가로서 2025년 11월 2일 15시 서울특별시 동남쪽 2km 지역에서 발생한 규모 6.3 지진 발생 상황에 대해 다음과 같이 대응 방안을 제시합니다. 낙하물 및 여진에 대한 특별한 주의가 필요하며, 국민재난안전포털의 정보를 기반으로 대응하겠습니다.
#
# ---
#
# ### **[Graph RAG 결과 분석 및 활용]**
#
# 제공된 Graph RAG 검색 결과는 `p.name`과 `p.content` 모두 비어 있는(None) 상태로, 특정 지진, 낙하물, 여진 관련 정책 콘텐츠를 직접적으로 반환하지 않았습니다. 이는 현재 Graph RAG 데이터베이스 내에 해당 조건에 부합하는 정책 노드와 콘텐츠가 직접적으로 연결되어 있지 않거나, 검색 결과가 비어 있음을 의미합니다.
#
# 그러나 Cypher 쿼리(`MATCH (p:Policy)-[:GUIDES]->(h:Hazard) WHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'`)는 **지진(Hazard), 낙하물(Hazard), 여진(Hazard)**이라는 재난 유형 간의 연관성과, 이에 대한 정책(Policy)이 존재할 것이라는 구조적 가정을 보여줍니다. 따라서 Graph RAG 결과가 비어 있음에도 불구하고, 지진으로 인한 주요 2차 피해 및 연쇄 효과를 분석하고 이에 대한 대응 원칙을 수립하는 데 있어 Hazard 노드 및 관계의 개념을 활용할 것입니다.
#
# ---
#
# ### **[M6.3 지진 발생 시 재난 간 연쇄 관계 및 대응 방안]**
#
# 규모 6.3의 지진은 서울과 같은 인구 밀집 지역에서 발생할 경우, 광범위한 직접적인 피해와 더불어 다양한 연쇄 재난을 유발할 수 있습니다. 국민재난안전포털의 일반적인 지침과 제공된 Vector RAG 결과를 바탕으로 주요 연쇄 관계 및 대응 방안을 설명합니다.
#
# **1. 지진 → 낙하물 발생 및 건물 붕괴 위험 (직접적 연쇄)**
# *   **관계:** 지진은 건물 및 구조물의 흔들림을 유발하여 **낙하물**(`TRIGGERS` Hazard) 발생의 직접적인 원인이 되며, 심각할 경우 건물 붕괴(`CAUSES` Hazard)로 이어집니다.
# *   **대응:**
#     *   **지진 발생 즉시:** "DROP, COVER, HOLD ON" 원칙에 따라 몸을 낮추고, 튼튼한 탁자 아래 등으로 숨어 머리와 목을 보호하며, 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡습니다. 유리창, 가구 등 낙하물이 떨어질 수 있는 곳에서 멀리 떨어집니다.
#     *   **흔들림이 멈춘 후:** 주변을 살피고 안전이 확보된 후 대피합니다. 건물 밖으로 대피 시에는 떨어지는 간판, 유리창, 외벽 등에 특히 주의하며, 열린 공간으로 이동합니다.
#
# **2. 지진 → 여진 발생 (지속적 연쇄)**
# *   **관계:** 본 지진(`CAUSES` Hazard) 발생 후에는 크고 작은 **여진**(`TRIGGERS` Hazard)이 수일, 수주간 지속될 수 있으며, 이는 이미 약화된 구조물에 추가적인 피해를 주거나 심리적 불안감을 조성합니다.
# *   **대응:**
#     *   **대피 후:** 안전한 장소로 대피하더라도 여진에 대비하여 항상 주변 상황을 주시하고, 추가적인 흔들림 발생 시 즉각적으로 다시 "DROP, COVER, HOLD ON" 자세를 취할 준비를 합니다.
#     *   **피해 점검:** 거주지나 근무지로 돌아갈 때에는 전문가의 안전 점검 후 진입하며, 여진으로 인한 추가적인 피해 가능성을 염두에 둡니다.
#
# **3. 지진 → 정전 및 전력 부족 (2차 연쇄)**
# *   **관계:** 지진으로 인해 전력선, 변압기 등 전력 공급 시설이 파손되어 광범위한 **정전**(`TRIGGERS` Hazard)이 발생할 수 있습니다. 이는 통신 두절, 교통 마비, 냉난방 불가 등 추가적인 피해를 유발합니다.
# *   **근거:** **Vector RAG 문서 4 ("국민재난안전포털 정전 및 전력부족 국민행동요령 (2025)")**는 정전 발생 시의 대응 요령을 제시합니다.
# *   **대응:**
#     *   **정전 발생 시:** 침착하게 행동하며, 비상 랜턴이나 휴대용 손전등을 사용하여 어둠에 적응합니다. 휴대폰 충전량을 아껴두고, 필요한 경우 비상 발전기를 가동합니다. 엘리베이터 내부에 갇히지 않도록 주의하고, 만약 갇혔다면 비상벨을 누릅니다.
#     *   **비상 대비:** 평소 비상용품(손전등, 라디오, 건전지, 응급약품, 식수 등)을 미리 준비하여 정전 상황에 대비합니다.
#
# **4. 지진 → 가스 누출 및 폭발 사고 (2차 연쇄)**
# *   **관계:** 지진으로 인해 가스 배관이 파손될 경우 **가스 누출**(`CAUSES` Hazard)이 발생하고, 이는 작은 불씨나 스파크에도 **폭발 사고**(`TRIGGERS` Hazard)로 이어질 수 있어 매우 위험합니다.
# *   **근거:** **Vector RAG 문서 2 ("국민재난안전포털 폭발사고 국민행동요령 (2025)")**는 가스 누출 시 즉시 환기, 전기 스위치 사용 금지, 화기 사용 절대 금지 등의 조치를 강조합니다. 통계적으로 공동주택 및 단독주택에서의 폭발사고가 37%를 차지합니다.
# *   **대응:**
#     *   **가스 냄새 감지 시:** 즉시 창문과 출입문을 활짝 열어 환기시키고, 도시가스 밸브를 잠급니다. 절대 전기 스위치를 조작하거나 성냥, 라이터 등 화기를 사용해서는 안 됩니다.
#     *   **신고:** 안전한 곳으로 대피한 후 관리사무소 또는 가스회사에 신고합니다.
#
# **5. 지진 → 철도/지하철 및 도로 터널 사고 (교통 인프라 연쇄)**
# *   **관계:** 지진은 철도 선로, 지하철 터널, 도로 및 터널 구조물에 손상을 주어 **철도·지하철 사고**(`INCREASES_RISK_OF` Hazard)나 **도로 터널 사고**(`INCREASES_RISK_OF` Hazard) 발생 위험을 증가시키고, 대피를 어렵게 만들 수 있습니다.
# *   **근거:** **Vector RAG 문서 1 ("국민재난안전포털 철도·지하철 사고 국민행동요령 (2025)")**과 **Vector RAG 문서 3 ("국민재난안전포털 도로 터널사고 국민행동요령 (2025)")**은 폐쇄된 공간에서의 신속한 대피와 침착한 대응의 중요성을 강조합니다.
# *   **대응:**
#     *   **지하철/열차 내:** 승무원 및 안내방송에 따라 침착하게 행동하며, 비상 버튼이나 인터폰으로 상황을 알립니다. 화재 발생 시 소화기를 사용하고, 연기 흡입 방지를 위해 코와 입을 가립니다. 승무원의 지시에 따라 질서 있게 대피합니다.
#     *   **도로 터널 내:** 차량을 갓길이나 비상주차대에 정차하고 엔진을 끈 후 키를 꽂아둔 채 하차합니다. 휴대전화 또는 터널 내 긴급전화로 신고하고, 터널 입구 방향이나 비상구, 피난연결통로를 통해 안전한 곳으로 대피합니다.
#
# ### **[종합적인 대응 원칙]**
#
# 1.  **초기 행동:** 지진 발생 시 "DROP, COVER, HOLD ON" 원칙을 준수하고, 낙하물로부터 몸을 보호합니다.
# 2.  **안전 확보 및 대피:** 흔들림이 멈추면 여진에 대비하며 안전한 장소로 대피합니다. 대피 시에는 떨어지는 물건에 주의하고, 개방된 공간으로 이동합니다.
# 3.  **2차 재난 대비:** 정전, 가스 누출, 교통 인프라 마비 등 2차 재난에 대한 정보를 습득하고 각 상황에 맞는 국민행동요령에 따라 침착하게 대응합니다. 특히 가스 누출 시 환기 및 화기 사용 금지를 철저히 지킵니다.
# 4.  **정보 확인:** 국민재난안전포털(또는 기타 공신력 있는 매체)을 통해 재난 상황과 정부의 안내를 지속적으로 확인하고 따릅니다.
# 5.  **비상용품 준비:** 평소 비상식량, 식수, 응급약품, 손전등, 라디오 등을 포함한 비상 배낭을 준비하여 예기치 않은 상황에 대비합니다.
# 6.  **가족 및 이웃 확인:** 안전한 장소로 대피 후 가족 구성원의 안전을 확인하고, 주변의 도움이 필요한 이웃을 살핍니다.
#
# 이러한 지침은 M6.3 지진 발생 시 국민의 생명과 재산을 보호하고, 연쇄 재난으로부터 피해를 최소화하는 데 중요한 역할을 할 것입니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='UJIGaeC8POvE1e8PyJOpyQk' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2165,
#   prompt_token_count=2240,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2240
#     ),
#   ],
#   thoughts_token_count=1688,
#   total_token_count=6093
# ) automatic_function_calling_history=[] parsed=None
#
# ============================================================
#
#
#
# ############################################################
# 질의 2/4: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
#
# [생성된 Cypher 쿼리]
# MATCH (s:Shelter)-[:IN]->(a:Admin {gu: '서초구'}) RETURN s.name, s.address, s.shelter_type LIMIT 10
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 4095 자
#   ⚠ 대피소 정보 추출 실패: 결과 10개, 첫 번째 결과 타입: <class 'dict'>
#     첫 번째 결과 키: ['s.name', 's.address', 's.shelter_type']
#     - s.name: <class 'str'>
#     - s.address: <class 'str'>
#     - s.shelter_type: <class 'str'>
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.', 'graph_results': {'query': "MATCH (s:Shelter)-[:IN]->(a:Admin {gu: '서초구'}) RETURN s.name, s.address, s.shelter_type LIMIT 10", 'results': [{'s.name': '반포고등학교 운동장', 's.address': '서울특별시 서초구 고무래로 71(반포동)', 's.shelter_type': '옥외대피소'}, {'s.name': '본마을공원', 's.address': '서울특별시 서초구 신원동 445', 's.shelter_type': '실내대피소'}, {'s.name': '개포은행나무공원', 's.address': '서울특별시 강남구 개포로20길 48(개포동)', 's.shelter_type': '옥외대피소'}, {'s.name': '기와터공원', 's.address': '서울특별시 용산구 한강로3가 63-388', 's.shelter_type': '옥외대피소'}, {'s.name': '원명초등학교 운동장', 's.address': '서울특별시 서초구 고무래로 90-6 (서초동)', 's.shelter_type': '실내대피소'}, {'s.name': '상신초등학교 운동장 ', 's.address': '서울특별시 은평구 가좌로 361(신사동)', 's.shelter_type': '옥외대피소'}, {'s.name': '서초초등학교 운동장', 's.address': '서울특별시 서초구 서운로 178(서초동)', 's.shelter_type': '실내대피소'}, {'s.name': '은행나무어린이공원', 's.address': '서울특별시 마포구 성미산로29길 17-9 (연남동)', 's.shelter_type': '옥외대피소'}, {'s.name': '서초중학교 운동장', 's.address': '서울특별시 서초구 반포대로13길 48(서초동)', 's.shelter_type': '실내대피소'}, {'s.name': '서초고등학교 운동장', 's.address': '서울특별시 서초구 반포대로27길 29(서초동)', 's.shelter_type': '실내대피소'}], 'count': 10}, 'vector_results': {'results': [{'id': '사회재난 행동요령 통합 가이드', 'text': '# 사회재난 행동요령 통합 가이드\n\n> **사회재난에 대한 완벽한 대비와 대응을 위한 통합 행동요령 매뉴얼**\n> \n> 본 문서는 대한민국 행정안전부 국민재난안전포털(safekorea.go.kr)의 공식 지침을 기반으로 작성되었습니다.\n\n---\n\n## 1. 화재\n\n### 평소 대비 요령\n\n#### 사전점검 (눈, 귀, 코, 손, 행동)\n\n**눈으로 확인**\n- 사용하지 않는 전열기구 코드\n- 가스레인지 중간 밸브 잠금\n\n**귀로 확인**\n- 평소에 나지 않던 이상한 소리\n\n**코로 확인**\n- 타는 냄새\n\n**손으로 확인**\n- 만져보거나 두들겨 보기\n\n**행동으로 확인**\n- 조리 중에는 자리를 비우지 않습니다.\n- 난방기구 등 전열기구 사용 시 주변에 탈 수 있는 물건을 두지 않습니다.\n\n#### 대피훈련\n\n**배워두세요**\n- 소화기 사용법\n- 비상통로 위치 (2곳 이상)\n- 대피 장소\n- 문틈 차단 방법\n\n**정해두세요**\n- 대피방법과 대피 후 만나는 장소\n- 대피할 때 가져갈 중요물건 목록\n- 비상연락 전화번호 및 연락할 대상\n\n**준비해두세요**\n- 문틈을 막을 청테이프 또는 수건\n- 외부 대피 시 사용할 수건 등 대피용품\n- 긴급 대피 시 만날 장소와 비상연락망\n\n#### 119 신고 방법\n\n**일반전화**\n1. 수화기를 들어 발신 확인\n2. 119 누르기\n3. 소방대원의 질문에 답하기\n\n**휴대전화**\n1. 119 누르기\n2. 소방대원의 질문에 답하기\n\n**인터넷**\n1. www.119.go.kr 접속\n2. 신고하기 버튼 누르기\n3. 성명 등 필수인적사항 기록\n4. 사고개요 정확히 기록\n5. 등록여부 확인\n\n**공중전화**\n1. 수화기 들기\n2. 긴급버튼(적색) 누르기\n3. 119 누르기\n4. 소방대원의 질문에 답하기\n\n### 화재 발생 시 행동 요령\n\n#### 화재경보가 울렸을 때\n\n**1. 주변 사람에게 알립니다**\n- 자고 있을 때 화재경보가 울리면 불이 났는지 확인하려 하기 보다는 큰소리를 질러 주변 사람에게 알립니다.\n\n**2. 대피방법을 결정합니다**\n- 손등으로 출입문 손잡이를 만져봅니다.\n- 손잡이가 따뜻하거나 뜨거우면 문 반대쪽에 불이 난 것이므로 문을 열지 않습니다.\n- 연기 들어오는 방향과 출입문 손잡이를 만져보아 계단으로 나갈지 창문으로 구조를 요청할지 결정합니다.\n\n**3. 신속히 대피합니다**\n- 대피할 때는 **엘리베이터를 절대 이용하지 않고** 계단을 통하여 지상으로 안전하게 대피합니다.\n- 대피가 어려운 경우에는 창문으로 구조요청을 하거나 대피공간 또는 경량칸막이를 이용하여 대피합니다.\n\n**4. 119로 신고합니다**\n- 안전하게 대피한 후 119에 신고합니다.\n- 휴대폰이 있어서 신고가 가능하다면 속히 해주시고, 신고하느라 대피시간을 놓치지 않도록 합니다.\n\n**5. 대피 후 인원을 확인합니다**\n- 놀이터 등 사전에 약속한 안전한 곳으로 대피한 후 인원을 확인합니다.\n- 주변에 보이지 않는 사람이 있다면 출동한 소방관에게 알려줍니다.\n\n#### 불을 발견했을 때\n\n**1. 연기가 발생하거나 불이 난 것을 보았을 때**\n- 불이 난 것을 발견하면 **"불이야!"**라고 큰소리로 외치거나 비상벨을 눌러 주변에 알립니다.\n\n**2. 불을 끌 것인지 대피할 것인지 판단합니다**\n- **불길이 천장까지 닿지 않은 작은 불인 경우**: 소화기나 물양동이 등을 활용하여 신속히 끕니다.\n- **불길이 커진 경우**: 젖은 수건 또는 담요를 활용하여 계단을 통해 밖으로 대피합니다.\n- **세대 밖으로 대피가 어려운 경우**: \n  - 경량칸막이를 이용하여 이웃집으로 대피\n  - 완강기를 이용하여 창문으로 나가기\n  - 실내대피공간으로 대피하였다가 불이 꺼진 후 나오기\n\n#### 화재진압: 소화기 사용법\n\n**기본 사용 절차**\n1. 안전핀을 뽑습니다.\n2. 노즐을 잡고 불쪽을 향합니다.\n3. 손잡이를 움켜쥡니다.\n4. 분말이 골고루 불을 덮을 수 있도록 뿝니다.\n\n**실내에서 사용할 때 주의사항**\n- 밖으로 대피할 때를 대비하여 문을 등지고 사용합니다.\n\n#### 화재진압: 소화전 사용법\n\n**기본 사용 절차**\n1. 문을 엽니다.\n2. 호스를 빼고 노즐을 잡습니다.\n3. 밸브를 돕니다.\n4. 불을 향해 뿝니다.\n\n**2인 1조로 사용할 경우**\n1. 1명이 먼저 소화전함의 문을 열고 호스와 노즐이 연결되어 있는지 확인합니다.\n2. 호스를 밖으로 꼬이지 않도록 불이 난 곳까지 길게 늘어뜨린 후 노즐을 잡고 방수자세를 취합니다.\n3. 다른 한 사람이 밸브를 돌려 물이 나오는 것을 확인한 후 뛰어가서 호스를 잡는 것을 도와줍니다.\n4. 노즐의 끝을 돌려 물의 양을 조절해가며 불을 끕니다.\n\n#### 옷에 불이 붙었을 때\n\n**대처 절차 (멈춘다 → 보호한다 → 엎드린다 → 뒹군다)**\n1. 하던 일을 멈춥니다.\n2. 얼굴(눈, 코, 입)에 화상을 입지 않도록 두 손으로 감쌉니다.\n3. 바닥에 엎드립니다.\n4. 몸을 뒹굴어서 불이 꺼지도록 합니다.\n\n#### 연기를 피해 대피하는 자세\n\n*대류현상에 따라 뜨거운 연기는 천장으로 올라가고 차가운 공기는 아래로 내려옵니다.*\n\n1. 손수건, 옷 등을 이용하여 호흡기(코와 입)를 보호합니다.\n2. 자세를 낮춥니다.\n3. 다른 손으로는 벽을 짚습니다.\n4. 한 방향으로 신속하게 밖으로 대피합니다.\n\n#### 심폐소생술 (4분의 기적)\n\n**4단계 절차**\n1. 반응  ...
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""지진 발생 시 서초구 인근 대피소를 찾고 계시는군요. 가까운 대피소 정보를 안내해 드리겠습니다.
#
# Graph RAG 검색 결과에 따르면 서초구 내에는 다음과 같은 주요 대피소들이 있습니다.
#
# **서초구 주요 대피소:**
#
# *   **반포고등학교 운동장** (옥외대피소)
#     *   주소: 서울특별시 서초구 고무래로 71(반포동)
# *   **본마을공원** (실내대피소)
#     *   주소: 서울특별시 서초구 신원동 445
# *   **원명초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 고무래로 90-6 (서초동)
# *   **서초초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 서운로 178(서초동)
# *   **서초중학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로13길 48(서초동)
# *   **서초고등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로27길 29(서초동)
#
# 제공된 검색 결과에서는 서초구 내 총 6개의 대피소를 확인할 수 있었습니다. 지진 발생 시에는 주변 안전을 확보한 후 가장 가까운 대피소로 이동하시는 것이 중요합니다. 실제 대피소의 위치는 '국민재난안전포털' 앱이나 웹사이트에서 실시간으로 확인할 수 있으니, 평소에 미리 확인해 두시는 것을 권장합니다."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='WpIGabPaDJqV1e8P9P-T2A0',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=402,
#     prompt_token_count=2638,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=2638
#       ),
#     ],
#     thoughts_token_count=586,
#     total_token_count=3626
#   )
# )}
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""지진 발생 시 서초구 인근 대피소를 찾고 계시는군요. 가까운 대피소 정보를 안내해 드리겠습니다.
#
# Graph RAG 검색 결과에 따르면 서초구 내에는 다음과 같은 주요 대피소들이 있습니다.
#
# **서초구 주요 대피소:**
#
# *   **반포고등학교 운동장** (옥외대피소)
#     *   주소: 서울특별시 서초구 고무래로 71(반포동)
# *   **본마을공원** (실내대피소)
#     *   주소: 서울특별시 서초구 신원동 445
# *   **원명초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 고무래로 90-6 (서초동)
# *   **서초초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 서운로 178(서초동)
# *   **서초중학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로13길 48(서초동)
# *   **서초고등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로27길 29(서초동)
#
# 제공된 검색 결과에서는 서초구 내 총 6개의 대피소를 확인할 수 있었습니다. 지진 발생 시에는 주변 안전을 확보한 후 가장 가까운 대피소로 이동하시는 것이 중요합니다. 실제 대피소의 위치는 '국민재난안전포털' 앱이나 웹사이트에서 실시간으로 확인할 수 있으니, 평소에 미리 확인해 두시는 것을 권장합니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='WpIGabPaDJqV1e8P9P-T2A0' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=402,
#   prompt_token_count=2638,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2638
#     ),
#   ],
#   thoughts_token_count=586,
#   total_token_count=3626
# ) automatic_function_calling_history=[] parsed=None
#
# ============================================================
#
#
#
# ############################################################
# 질의 3/4: 지진 발생 시 어떻게 행동해야 하나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
# Received notification from DBMS server: <GqlStatusObject gql_status='01N52', status_description='warn: property key does not exist. The property `content` does not exist. Verify that the spelling is correct.', position=<SummaryInputPosition line=1, column=77, offset=76>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 76, 'line': 1, 'column': 77}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: "MATCH (p:Policy)-[:GUIDES]->(h:Hazard {hazard_type: '지진'}) RETURN p.name, p.content LIMIT 5"
# [생성된 Cypher 쿼리]
# MATCH (p:Policy)-[:GUIDES]->(h:Hazard {hazard_type: '지진'}) RETURN p.name, p.content LIMIT 5
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3384 자
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '지진 발생 시 어떻게 행동해야 하나요?', 'graph_results': {'query': "MATCH (p:Policy)-[:GUIDES]->(h:Hazard {hazard_type: '지진'}) RETURN p.name, p.content LIMIT 5", 'results': [{'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}, {'p.name': ' >  > ', 'p.content': None}], 'count': 5}, 'vector_results': {'results': [{'id': '철도·지하철 사고 국민행동요령', 'text': '# 국민재난안전포털 철도·지하철 사고 국민행동요령 (2025)\n\n**국토교통부 & 행정안전부 발행**\n\n---\n\n## 철도·지하철 사고 개요\n\n### 사고의 위험성\n\n철도·지하철 사고는 **폐쇄된 공간에서 다수 인원이 탑승**하고 있어 **신속한 대피와 침착한 대응**이 매우 중요합니다. 화재, 충돌, 테러 등 다양한 상황에 대비해야 합니다.\n\n### 대피의 기본 원칙\n\n- **승무원 및 안내방송 따르기**\n- **질서 있는 행동**\n- **안전취약계층 먼저 대피**\n- **선로 진입 주의**\n\n---\n\n## 지하철 화재 발생 시\n\n### 1단계: 승무원 연락\n\n**비상버튼 이용:**\n- **노약자·장애인석 옆에 있는 비상버튼을 눌러 승무원과 연락**\n- 위치 정확히 알리기\n- 상황 설명\n\n**인터폰 이용:**\n- 객실 양 끝에 있는 인터폰 이용\n- 승무원에게 즉시 알리기\n\n### 2단계: 초기 소화\n\n**소화기 이용:**\n- 여유가 있다면 **객차마다 2개씩 비치된 소화기를 이용하여 불을 끝**\n- 소화기 위치 파악\n- 불의 하단부 겨냥\n\n**소화 불가 시:**\n- 무리하게 소화 시도 금지\n- 즉시 대피 전환\n\n### 3단계: 호흡기 보호\n\n**코와 입 가리기:**\n- **코와 입을 수건, 티슈, 옷소매 등으로 막기**\n- 젖은 천 사용 (가능할 경우)\n- 연기 흡입 최소화\n\n**호흡 관리:**\n- 천천히, 얕게 호흡\n- 신선한 공기 지역으로 이동\n\n### 4단계: 다른 객차로 이동\n\n**화재 미발생 객차로:**\n- **화재가 발생하지 않은 다른 객실로 이동**\n- 객차 연결부를 통해 이동\n- 신속하지만 질서 있게\n\n### 5단계: 출입문 개방\n\n**자동 개방:**\n- 열차 정지 후 자동으로 개방 대기\n\n**수동 개방:**\n- **출입문이 자동으로 열리지 않으면 수동으로 문을 열기**\n- 수동 손잡이 사용\n\n**비상용 망치:**\n- **여의치 않으면 비상용 망치를 이용하여 유리창을 깨기**\n- 유리 깨기 후 안전하게 탈출\n\n**소화기로 유리 깨기:**\n- **망치가 없으면 소화기로 유리창을 깨기**\n\n### 6단계: 스크린도어(PSD) 개방\n\n**빨간색 바 이용:**\n- **스크린도어(PSD)가 열리지 않을 경우 스크린도어에 설치된 빨간색 바를 밀고 나가기**\n- 위치 사전 파악\n- 신속히 나가기\n\n### 7단계: 비상구로 대피\n\n**조명 확인:**\n- 대피유도 등 확인\n- 비상구 위치 파악\n\n**정전 시:**\n- **정전 시에는 대피유도 등을 따라 출구로 나가기**\n- **유도등이 보이지 않을 때는 벽을 짚으면서 나가기**\n- **시각장애인 안내용 보도블록을 따라 나가기**\n\n**신속 대피:**\n- **비상구로 신속히 대피합시다**\n- 침착하고 질서 있게\n\n### 8단계: 지상 대피\n\n**지상으로 대피:**\n- 가능한 한 지상으로 대피\n\n**터널 대피:**\n- **지상으로 대피가 여의치 않을 때는 전동차 진행방향 터널로 대피**\n- 선로 진입 주의\n- 반대편 열차 주의\n\n---\n\n## 지하철 출입문 개방 방법\n\n### 수동으로 문 열기\n\n**수동 손잡이 위치:**\n- 출입문 양쪽에 위치\n- 사전 확인 필수\n\n**개방 방법:**\n1. 수동 손잡이를 찾기\n2. 손잡이를 잡고 끌어당기거나 밀기\n3. 문이 열려 신속히 탈출\n\n**비상 상황:**\n- 열차 정지 후 시도\n- 무리하게 힘 쓰지 말기\n- 다른 방법 시도\n\n### 비상용 망치 이용\n\n**망치 위치:**\n- 출입문 근처에 설치\n- 빨간색 케이스 안\n- 사전 위치 파악\n\n**유리 깨기 방법:**\n1. 망치를 잡기\n2. 유리 가장자리 또는 중앙을 강하게 치기\n3. 깨진 유리 피해 탈출\n\n**안전 주의:**\n- 깨진 유리 파편 주의\n- 손 보호\n- 천천히 조심히 탈출\n\n### 스크린도어(PSD) 개방\n\n**손잡이 이용:**\n- 양쪽 손잡이를 밀거나 당기기\n\n**빨간색 바:**\n- 스크린도어에 설치된 빨간색 바 확인\n- 빨간색 바를 밀어 개방\n- 신속히 탈출\n\n---\n\n## 지하철 스크린도어(PSD) 개방\n\n### 정상 개방\n\n**자동 개방:**\n- 열차 정지 시 자동으로 스크린도어 개방\n- 대기\n\n### 수동 개방\n\n**손잡이 조작:**\n1. **스크린도어 양쪽 손잡이를 양쪽으로 밀기**\n2. 또는 당기기\n3. 신속히 탈출\n\n**빨간색 바 조작:**\n1. **스크린도어에 설치된 빨간색 바 찾기**\n2. **빨간색 바를 밀고 탈출**\n3. 신속히 나가기\n\n---\n\n## 지하철 일반 사고 대응\n\n### 기본 행동요령\n\n**승무원 연락:**\n- **객실 양 끝에 있는 인터폰으로 승무원에게 알립니다**\n- 상황 설명\n- 지시 받기\n\n**화재 신고:**\n- **화재 발생 시 119에 신고**\n- 위치 정확히\n- 동시에 승무원에게도 알리기\n\n**초기 소화:**\n- **여유가 있다면 객실 양 끝에 비치된 소화기로 불을 끝**\n- 무리하지 말기\n\n**호흡기 보호:**\n- **입과 코를 젖은 천으로 막고 화재가 발생하지 않은 다른 객실로 이동**\n- 신속하게 이동\n- 연기 회피\n\n### 대피 원칙\n\n**안내방송 준수:**\n- **안내방송과 승무원의 안내에 따라 질서있게 대피합시다**\n- 공식 지시 따르기\n\n**약자 배려:**\n- **부상자, 노약자, 임산부가 먼저 대피할 수 있도록 배려하고 돕습니다**\n- 함께 대피\n- 도움 제공\n\n**출입문 개방:**\n- **문이 열리지 않으면 열차가 멈춘 후에 안내방송에 따라 비상핸들이나 비상콕크를 돌려 문을 열고 탈출합니다**\n- 승무원 지시 대기\n\n**스크린도어:**\n- **스크린도어는 손잡이를 양쪽으로 밀거나 빨간색 바를 밀고 탈출**\n- 신속히\n\n### 선로 대피 시 주의\n\n**감전 위험:**\n- **선로로 대피할 때에는, 감전위험이 있으므로 반드시 대피안내에 따라 반대편 선로의 열차 진입에 유의하며 대피합니다**\n- 제3 레일 주의 (전기 위험)\n- 반대편 열차 주시\n\n**선로 위 이동:**\n- 최소한의 선로 접촉\n- 승무원 지시 따르기\n- 신속하고 신중하게\n\n### 비상구 대피\n\n**유도등 따르기:**\n- **대피할 때에는 대피 유도등을 따라 침착하게 비상구로 대피합니다**\n- 조명 확인\n- 방향 감각 유지\n\n**정전 시:**\n- 벽을 짚으며 이동\n- 시각장애인용 보도블록 활용\n- 다른 승객과 함께\n\n---\n\n## 고속철도 탈선·충돌사고\n\n### 기본 행동요령\n\n**승무원 지시:**\n- **기관사 및 승무원의 안내방송에 따라 대피합니다**\n- 공식 지시 준수\n\n**질서 있는 대피:**\n- **승무원이 승강문을 개방하면 질서 있게 대피합시다**\n- 순서 지키기\n- **(필요시, 비상사다리 설치)**\n\n**약자 먼저:**\n- **부상자, 노약자, 임산부가 먼저 대피할 수 있도록 배 ...
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""재난대응 전문가로서 지진 발생 시 행동 요령에 대해 말씀드리겠습니다.
#
# 제공된 Graph RAG 및 Vector RAG 검색 결과에서는 지진 발생 시의 구체적인 행동 지침이 직접적으로 확인되지 않았습니다. 다만, 재난대응 전문가의 관점에서 국민들이 반드시 알아야 할 지진 발생 시 행동 요령은 다음과 같습니다.
#
# ---
#
# **지진 발생 시 행동 요령**
#
# 지진 발생 시에는 침착하게 다음 3단계 원칙에 따라 행동하는 것이 중요합니다.
#
# 1.  **"DROP, COVER, HOLD ON" (몸을 낮추고, 숨고, 잡기)**
#     *   **몸을 낮추기 (DROP):** 지진을 느끼면 즉시 바닥에 엎드려 몸의 중심을 낮춥니다.
#     *   **숨기 (COVER):** 탁자나 책상 등 견고한 가구 아래로 들어가 머리와 목을 보호합니다. 주변에 숨을 곳이 없다면 방석 등으로 머리를 가리고 벽 모서리나 기둥 옆에 웅크립니다.
#     *   **꽉 잡기 (HOLD ON):** 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡고 몸을 보호합니다.
#
# 2.  **안전 확보 및 대피 준비**
#     *   **실내인 경우:** 창문, 거울, 높은 가구 등 떨어지거나 넘어질 수 있는 물건에서 멀리 떨어집니다. 흔들림이 멈추면 가스 밸브와 전기 스위치를 잠그고 출구를 확보한 후 안전하게 대피할 준비를 합니다. 신발은 반드시 착용하여 발을 보호합니다.
#     *   **실외인 경우:** 건물, 담벼락, 전신주, 가로등 등 낙하 또는 붕괴 위험이 있는 곳에서 멀리 떨어진 넓은 공간으로 이동합니다.
#     *   **차량 운전 중인 경우:** 서서히 속도를 줄여 도로 우측에 차를 세우고 비상등을 켭니다. 라디오를 통해 재난 방송을 청취하고, 차 안에 머무르거나 주변이 안전하다고 판단되면 차 키를 꽂아둔 채 대피합니다.
#
# 3.  **지진 후 행동**
#     *   **안전한 곳으로 대피:** 흔들림이 멈춘 후, 엘리베이터는 절대 사용하지 않고 계단을 이용하여 외부의 안전한 넓은 공간(운동장, 공원 등)으로 대피합니다.
#     *   **정보 확인 및 구조 요청:** 스마트폰, 라디오 등으로 재난 방송을 청취하여 상황을 파악하고, 부상자가 있거나 위험 상황 발생 시 119 또는 112에 신고합니다.
#     *   **여진 대비:** 여진이 발생할 수 있으므로, 재난 방송 및 관계 기관의 안내에 따라 행동하며 안전에 유의합니다.
#
# 가장 중요한 것은 당황하지 않고 침착하게 위의 행동 요령을 따르는 것입니다. 평소 가족 및 직장 동료와 비상연락망 및 대피 계획을 세워두는 것도 큰 도움이 됩니다."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='aZIGaZWgBMnE1e8Pyb7E2Q4',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=691,
#     prompt_token_count=2151,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=2151
#       ),
#     ],
#     thoughts_token_count=1127,
#     total_token_count=3969
#   )
# )}
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""재난대응 전문가로서 지진 발생 시 행동 요령에 대해 말씀드리겠습니다.
#
# 제공된 Graph RAG 및 Vector RAG 검색 결과에서는 지진 발생 시의 구체적인 행동 지침이 직접적으로 확인되지 않았습니다. 다만, 재난대응 전문가의 관점에서 국민들이 반드시 알아야 할 지진 발생 시 행동 요령은 다음과 같습니다.
#
# ---
#
# **지진 발생 시 행동 요령**
#
# 지진 발생 시에는 침착하게 다음 3단계 원칙에 따라 행동하는 것이 중요합니다.
#
# 1.  **"DROP, COVER, HOLD ON" (몸을 낮추고, 숨고, 잡기)**
#     *   **몸을 낮추기 (DROP):** 지진을 느끼면 즉시 바닥에 엎드려 몸의 중심을 낮춥니다.
#     *   **숨기 (COVER):** 탁자나 책상 등 견고한 가구 아래로 들어가 머리와 목을 보호합니다. 주변에 숨을 곳이 없다면 방석 등으로 머리를 가리고 벽 모서리나 기둥 옆에 웅크립니다.
#     *   **꽉 잡기 (HOLD ON):** 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡고 몸을 보호합니다.
#
# 2.  **안전 확보 및 대피 준비**
#     *   **실내인 경우:** 창문, 거울, 높은 가구 등 떨어지거나 넘어질 수 있는 물건에서 멀리 떨어집니다. 흔들림이 멈추면 가스 밸브와 전기 스위치를 잠그고 출구를 확보한 후 안전하게 대피할 준비를 합니다. 신발은 반드시 착용하여 발을 보호합니다.
#     *   **실외인 경우:** 건물, 담벼락, 전신주, 가로등 등 낙하 또는 붕괴 위험이 있는 곳에서 멀리 떨어진 넓은 공간으로 이동합니다.
#     *   **차량 운전 중인 경우:** 서서히 속도를 줄여 도로 우측에 차를 세우고 비상등을 켭니다. 라디오를 통해 재난 방송을 청취하고, 차 안에 머무르거나 주변이 안전하다고 판단되면 차 키를 꽂아둔 채 대피합니다.
#
# 3.  **지진 후 행동**
#     *   **안전한 곳으로 대피:** 흔들림이 멈춘 후, 엘리베이터는 절대 사용하지 않고 계단을 이용하여 외부의 안전한 넓은 공간(운동장, 공원 등)으로 대피합니다.
#     *   **정보 확인 및 구조 요청:** 스마트폰, 라디오 등으로 재난 방송을 청취하여 상황을 파악하고, 부상자가 있거나 위험 상황 발생 시 119 또는 112에 신고합니다.
#     *   **여진 대비:** 여진이 발생할 수 있으므로, 재난 방송 및 관계 기관의 안내에 따라 행동하며 안전에 유의합니다.
#
# 가장 중요한 것은 당황하지 않고 침착하게 위의 행동 요령을 따르는 것입니다. 평소 가족 및 직장 동료와 비상연락망 및 대피 계획을 세워두는 것도 큰 도움이 됩니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='aZIGaZWgBMnE1e8Pyb7E2Q4' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=691,
#   prompt_token_count=2151,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2151
#     ),
#   ],
#   thoughts_token_count=1127,
#   total_token_count=3969
# ) automatic_function_calling_history=[] parsed=None
#
# ============================================================
#
#
#
# ############################################################
# 질의 4/4: 노후 시설물이 붕괴 위험을 증가시킬 수 있나요?
# ############################################################
#
# ============================================================
# [Graph RAG 검색 중...]
#
# [생성된 Cypher 쿼리]
# MATCH (h1:Hazard {hazard_type: '노화'})-[:INCREASES_RISK_OF]->(h2:Hazard {hazard_type: '붕괴'}) RETURN h1.name AS 노후시설물재난유형, h2.name AS 붕괴재난유형
#
#
# ============================================================
# [Vector RAG 검색 중...]
#
# ============================================================
# [Ollama를 통한 최종 답변 생성 중...]
#   프롬프트 길이: 3254 자
#
# ============================================================
# [최종 답변]
# ============================================================
# {'question': '노후 시설물이 붕괴 위험을 증가시킬 수 있나요?', 'graph_results': {'query': "MATCH (h1:Hazard {hazard_type: '노화'})-[:INCREASES_RISK_OF]->(h2:Hazard {hazard_type: '붕괴'}) RETURN h1.name AS 노후시설물재난유형, h2.name AS 붕괴재난유형", 'results': [{'노후시설물재난유형': '노화', '붕괴재난유형': '붕괴'}], 'count': 1}, 'vector_results': {'results': [{'id': '비상시 국민행동요령', 'text': '# 2025 비상시 국민행동요령\n\n**행정안전부 발행**\n\n---\n\n## 비상사태란?\n\n**비상사태**란 전쟁 또는 이에 준하는 비상시 상황을 말합니다.\n\n비상사태가 발생하면 정부의 대응뿐만 아니라 **국민의 자발적인 협조와 대비가 중요**합니다.\n\n방법을 알아야 대비도 가능합니다!\n\n---\n\n## 비상시 안전을 위해 꼭 기억해야 할 4가지\n\n### 1️⃣ **일상생활 중 꼼꼼히 준비**\n- 대피장소 사전에 파악하기\n- 비상 생존배낭 준비하기\n- 전시 대비 물품 구비하기\n\n### 2️⃣ **공습 경보가 울리거나 포탄이 떨어질 때 안전하게 대피**\n- 신속하게 대피 후 신체 보호하기\n- 노약자, 어린이, 임산부, 장애인 등 대피 취약자를 도와 함께 대피하기\n\n### 3️⃣ **대피소 대피 중에 귀 기울여 정부 안내방송 잘 듣기**\n- 정부의 안내에 따라 행동\n- 유언비어에 현혹되지 않기\n\n### 4️⃣ **질서유지 및 상호 배려하기**\n- 대피소에서 질서를 잘 유지하며 서로 배려하는 자세 갖기\n\n---\n\n## 평상시 미리 준비하기\n\n### 1. 대피장소 찾아두기\n\n**가장 가까운 민방위 대피소 위치를 미리 확인하세요!**\n\n#### 대피소 확인 방법:\n- **스마트폰 앱**: 안전디딤돌\n- **지도 앱**: 네이버지도, 카카오맵, 티맵\n- 검색어: "민방위 대피소"\n\n#### 대피소 종류:\n- 지하철역\n- 지하 주차장\n- 큰 건물 지하실\n- 정부 지정 민방위 대피소\n\n#### 화학무기 피해 시:\n- **높은 곳이 안전**합니다\n- 건물 내 높은 층의 실내 공간으로 대피\n\n---\n\n### 2. 비상 생존배낭 준비하기\n\n**평상시 비상 생존배낭을 미리 준비해 두세요!**\n\n#### 필수 준비물품:\n- ✅ **생수** (1인당 하루 2L 기준, 최소 3일분)\n- ✅ **간편식** (라면, 통조림, 에너지바 등)\n- ✅ **손전등 및 건전지**\n- ✅ **상비약** (진통제, 소화제, 지병약 등)\n- ✅ **라디오** (건전지 포함)\n- ✅ **화장지, 물티슈**\n- ✅ **화생방 방독면** (없을 경우 마스크)\n- ✅ **보호장갑, 장화**\n- ✅ **비닐봉투**\n- ✅ **휴대폰 보조배터리**\n- ✅ **응급처치 도구** (붕대, 소독약, 가위 등)\n- ✅ **담요, 방한용품**\n- ✅ **여벌 옷**\n- ✅ **비상금, 신분증 사본**\n\n---\n\n### 3. 가정 내 평시 비상대비 물자 준비\n\n#### 식량 및 생활필需품:\n- 쌀, 라면, 통조림 등 비상식량 (최소 2주분)\n- 식수 (1인당 하루 2L × 14일 = 28L)\n- 휴대용 가스버너 및 부탄가스\n- 양초, 성냥, 라이터\n\n#### 화재 대비:\n- 소화기 비치 및 사용법 숙지\n- 가스 차단 방법 숙지\n- 전기 코드 점검\n\n#### 야간 대비:\n- 전등을 끄고 불빛이 밖으로 나가지 않도록 커튼이나 블라인드 준비\n\n---\n\n## 민방공 경보 체계\n\n정부는 적의 지상·해상·공중 전력에 의한 공격이 예상되거나 진행 중일 때, 그 사실을 국민에게 신속히 알리기 위하여 **전국적인 민방공 경보체계**를 운영하고 있습니다.\n\n### 민방공 경보의 종류 (5가지)\n\n---\n\n### 1️⃣ **경계경보**\n\n#### 발령 상황:\n- 적의 공격이 예상될 때\n\n#### 전달 수단:\n- 음성방송\n- 민방공 경보 문자\n\n#### 행동요령:\n- 즉시 TV나 라디오를 청취하며 정부의 안내에 따라 행동\n- 낙하물 유의\n- 야외활동 자제\n- 정부 안내방송 청취\n- 어린이와 노약자는 미리 대피소로 대피 권장\n- 비상용품 미리 챙겨 놓기\n- 화재 대비: 가스 차단, 전기코드 분리\n- 야간: 전등을 끄고 불빛이 밖으로 나가지 않도록 차단\n- 극장, 운동장, 음식점 등 다중이용시설: 영업 중단, 손님들에게 경보 내용 알리고 순차적으로 대피\n\n---\n\n### 2️⃣ **공습경보**\n\n#### 발령 상황:\n- 적의 항공기, 미사일 등 공격이 임박하거나 진행 중일 때\n\n#### 전달 수단:\n- **사이렌** (1분간 울림)\n- 음성방송\n- 민방공 경보 문자\n\n#### 행동요령:\n\n##### 즉시 대피:\n- **민방위 대피소** 또는 **가까운 지하시설**로 신속히 대피\n- **콘크리트 건물 내 유리창이 없는 곳**으로 대피\n\n##### 대피 시 주의사항:\n- 화재 또는 단전이 있을 수 있으니 **엘리베이터 사용 금지**, 반드시 **계단** 이용\n- 차량 운전 중: 도로 오른쪽에 차를 세우고 **시동키는 차에 놓아둔 채** 가까운 대피시설로 신속히 대피\n\n##### 신체 보호:\n- 대피 후 **엎드려 눈과 귀를 막고 입은 벌림**\n- 배는 바닥에 닿지 않게 함\n\n---\n\n### 3️⃣ **화생방 경보**\n\n#### 발령 상황:\n- 적의 화학무기 또는 생물학무기 공격이 있거나 예상될 때\n\n#### 전달 수단:\n- 음성방송\n- 민방공 경보 문자\n\n#### 행동요령:\n\n##### 호흡기 보호:\n- **화생방 방독면, 마스크, 수건** 등으로 호흡기를 보호\n\n##### 대피 방향:\n- **건물 내 높은 층의 실내 공간** 또는 **바람 반대 방향**으로 대피\n- 외부 공기를 차단할 수 있는 곳으로 대피\n\n##### 화학무기 공격 시:\n- 건물 내: 높은 곳으로 이동하여 외부 공기가 차단되는 곳에 대피\n- 외부: 바람의 반대 방향으로 대피\n  - **오염된 지역으로 바람이 분다면**: 바람의 반대 방향으로 대피\n  - **오염된 지역에서 내가 있는 곳으로 바람이 불면**: 바람이 불어오는 방향의 좌측이나 우측으로 대피\n\n##### 생물학 무기 공격 시:\n- 화생방 방독면, 마스크나 손수건 등으로 호흡기 보호\n- 화생방 대피소 또는 실내에 머물며 위생관리 철저\n- 음식은 **15분 이상 조리하여 섭취**\n- 생물학 무기로 의심되는 우편물: 개봉하지 말고 격리된 곳에 보관 후 보건소나 행정기관에 신속 신고\n\n---\n\n### 4️⃣ **핵 경보**\n\n#### 발령 상황:\n- 핵 폭발 상황이 있거나 예상될 때\n\n#### 전달 수단:\n- **사이렌**\n- 음성방송\n- 민방공 경보 문자\n\n#### 행동요령:\n\n##### 즉시 대피:\n- 최대한 가까운 **지하시설** 또는 **화장실 등 건물 내 유리창이 없는 안전한 곳**으로 대피\n\n##### 핵폭발 섬광을 보았을 때:\n- **몇 초 이내 지하로 이동** 또는 **핵 폭발 반대 방향으로 엎드림**\n- **눈과 귀를 막고 입은 벌림**\n- **배는 바닥에 닿지 않게 함**\n\n---\n\n### 5️⃣ **경보해제**\n\n#### 발령 상황:\n- 공격 직후 및 추가 공격이 예상되지 않을 때\n\n#### 전달 수단:\n- 음성방송\n- 민방공 경보 문자\n\n#### 행동요령:\n- 부상자 구조에 동참\n- 추가 공습에 대비\n- 정부 안내방송 계속 청취\n\n---\n\n## 민방공 경보 발령 시 행동요령\n\n### 경계경보 발령 시\n\n✅ TV나 라디오를 켜고 정부의 안내방송 청취  \n✅ 어린이와 노약자는 미리 대피  \n✅ 비상용품 준비  \n✅ 화재 대비: 가스 차단, 전기코드 분리  \n✅ 야간: 전등을 끄고 불 ...
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""네, 노후 시설물은 붕괴 위험을 증가시킬 수 있습니다. 이는 재난 대응 관점에서 매우 중요한 요소로 인식되고 있으며, 시설물의 노화는 심각한 사회 재난으로 이어질 수 있는 직접적인 원인 중 하나입니다.
#
# **구체적인 근거 및 재난 간 연쇄 관계 설명:**
#
# 1.  **Graph RAG 검색 결과 활용:**
#     *   제시된 Graph RAG 검색 결과에 따르면, 명확하게 **'노화' (hazard_type: 노화)**가 **'붕괴' (hazard_type: 붕괴)**의 위험을 **'INCREASES_RISK_OF' (위험 증가)**하는 관계가 확인되었습니다.
#     *   이는 시스템적으로 노화된 시설물이 붕괴 재난으로 이어질 가능성을 높인다는 것을 의미하며, 재난 발생의 직접적인 연쇄 고리 중 하나입니다. 시설물의 노후화는 구조적 안정성을 저해하고, 작은 외부 충격이나 자연 현상에도 취약하게 만들어 최종적으로 붕괴에 이르게 할 수 있습니다.
#
# 2.  **재난 발생의 연쇄 관계:**
#     *   **노화 -> 구조적 결함 증가:** 시설물이 오랜 시간 사용되면서 재료의 피로 누적, 부식, 균열, 침하, 지지력 약화 등 다양한 형태의 노후화가 진행됩니다. 이러한 현상은 시설물의 구조적 안정성을 점진적으로 약화시킵니다.
#     *   **구조적 결함 증가 -> 붕괴 위험 증대:** 약화된 구조는 지진, 태풍, 폭설과 같은 자연재해는 물론, 과도한 하중, 인근 공사로 인한 진동, 유지보수 부족 등 예상치 못한 외부 요인에 더욱 취약해집니다. 이로 인해 시설물이 본래 견딜 수 있는 한계를 초과하게 되면, 부분적인 손상을 넘어 갑작스러운 전체 붕괴로 이어질 위험이 크게 증가합니다.
#     *   **붕괴 -> 인명 피해 및 재산 손실:** 시설물 붕괴는 대규모 인명 피해와 심각한 재산 손실을 초래하며, 사회 기반 시설 마비, 2차 재해 발생(가스 폭발, 전기 화재 등) 등 광범위한 사회경제적 영향을 미칠 수 있습니다.
#
# **결론적으로,** 노후 시설물은 단순한 불편함을 넘어 국민의 생명과 안전을 위협하는 심각한 붕괴 위험을 내포하고 있습니다. 따라서 노후 시설물에 대한 정기적인 안전 점검, 유지보수 및 보강, 그리고 필요한 경우 재건축 등을 통해 이러한 위험을 사전에 예방하고 관리하는 것이 재난 대응 전문가로서 매우 중요합니다.
#
# **[참고: Vector RAG 결과에 대한 평가]**
# Vector RAG 검색 결과는 주로 '비상시 국민행동요령', '철도·지하철 사고', '정전 및 전력부족', '사회재난 행동요령(화재)' 등 특정 재난 상황 발생 시의 행동 지침이나 대응 방법에 대한 정보를 제공하고 있습니다. 이 문서들은 노후 시설물의 붕괴 위험 증가라는 질문에 대한 직접적인 정보나 근거를 포함하고 있지는 않습니다. 따라서 본 답변은 Graph RAG 검색 결과의 명확한 관계에 중점을 두어 구성되었습니다."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='gJIGaZr3Eta6vr0PhqvH8AQ',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=734,
#     prompt_token_count=2067,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=2067
#       ),
#     ],
#     thoughts_token_count=1354,
#     total_token_count=4155
#   )
# )}
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""네, 노후 시설물은 붕괴 위험을 증가시킬 수 있습니다. 이는 재난 대응 관점에서 매우 중요한 요소로 인식되고 있으며, 시설물의 노화는 심각한 사회 재난으로 이어질 수 있는 직접적인 원인 중 하나입니다.
#
# **구체적인 근거 및 재난 간 연쇄 관계 설명:**
#
# 1.  **Graph RAG 검색 결과 활용:**
#     *   제시된 Graph RAG 검색 결과에 따르면, 명확하게 **'노화' (hazard_type: 노화)**가 **'붕괴' (hazard_type: 붕괴)**의 위험을 **'INCREASES_RISK_OF' (위험 증가)**하는 관계가 확인되었습니다.
#     *   이는 시스템적으로 노화된 시설물이 붕괴 재난으로 이어질 가능성을 높인다는 것을 의미하며, 재난 발생의 직접적인 연쇄 고리 중 하나입니다. 시설물의 노후화는 구조적 안정성을 저해하고, 작은 외부 충격이나 자연 현상에도 취약하게 만들어 최종적으로 붕괴에 이르게 할 수 있습니다.
#
# 2.  **재난 발생의 연쇄 관계:**
#     *   **노화 -> 구조적 결함 증가:** 시설물이 오랜 시간 사용되면서 재료의 피로 누적, 부식, 균열, 침하, 지지력 약화 등 다양한 형태의 노후화가 진행됩니다. 이러한 현상은 시설물의 구조적 안정성을 점진적으로 약화시킵니다.
#     *   **구조적 결함 증가 -> 붕괴 위험 증대:** 약화된 구조는 지진, 태풍, 폭설과 같은 자연재해는 물론, 과도한 하중, 인근 공사로 인한 진동, 유지보수 부족 등 예상치 못한 외부 요인에 더욱 취약해집니다. 이로 인해 시설물이 본래 견딜 수 있는 한계를 초과하게 되면, 부분적인 손상을 넘어 갑작스러운 전체 붕괴로 이어질 위험이 크게 증가합니다.
#     *   **붕괴 -> 인명 피해 및 재산 손실:** 시설물 붕괴는 대규모 인명 피해와 심각한 재산 손실을 초래하며, 사회 기반 시설 마비, 2차 재해 발생(가스 폭발, 전기 화재 등) 등 광범위한 사회경제적 영향을 미칠 수 있습니다.
#
# **결론적으로,** 노후 시설물은 단순한 불편함을 넘어 국민의 생명과 안전을 위협하는 심각한 붕괴 위험을 내포하고 있습니다. 따라서 노후 시설물에 대한 정기적인 안전 점검, 유지보수 및 보강, 그리고 필요한 경우 재건축 등을 통해 이러한 위험을 사전에 예방하고 관리하는 것이 재난 대응 전문가로서 매우 중요합니다.
#
# **[참고: Vector RAG 결과에 대한 평가]**
# Vector RAG 검색 결과는 주로 '비상시 국민행동요령', '철도·지하철 사고', '정전 및 전력부족', '사회재난 행동요령(화재)' 등 특정 재난 상황 발생 시의 행동 지침이나 대응 방법에 대한 정보를 제공하고 있습니다. 이 문서들은 노후 시설물의 붕괴 위험 증가라는 질문에 대한 직접적인 정보나 근거를 포함하고 있지는 않습니다. 따라서 본 답변은 Graph RAG 검색 결과의 명확한 관계에 중점을 두어 구성되었습니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='gJIGaZr3Eta6vr0PhqvH8AQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=734,
#   prompt_token_count=2067,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2067
#     ),
#   ],
#   thoughts_token_count=1354,
#   total_token_count=4155
# ) automatic_function_calling_history=[] parsed=None
#
# ============================================================

# %% [markdown]
# ## 7. 결과 분석

# %%
# 결과 요약
print("\n" + "="*60)
print("# Hybrid RAG 검색 결과 요약")
print("="*60 + "\n")

for i, result in enumerate(results, 1):
    question = result.get("question", "N/A")
    graph_count = result.get("graph_results", {}).get("count", 0)
    vector_count = result.get("vector_results", {}).get("count", 0)
    has_answer = result.get("answer") is not None
    
    print(f"질의 {i}: {question}")
    print(f"  - Graph RAG: {graph_count}개 결과")
    print(f"  - Vector RAG: {vector_count}개 결과")
    print(f"  - 최종 답변: {'✓ 생성됨' if has_answer else '✗ 생성 실패'}")
    print(result.get("answer", "답변 생성 실패"))
    print()
# Out:
# ============================================================
# # Hybrid RAG 검색 결과 요약
# ============================================================
#
# 질의 1: 2025-11-02 15:00 서울특별시 동남쪽 2km 지역 M6.3 지진 / 낙하물, 여진주의  국민재난안전포털 참고 대응
#   - Graph RAG: 5개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""재난대응 전문가로서 2025년 11월 2일 15시 서울특별시 동남쪽 2km 지역에서 발생한 규모 6.3 지진 발생 상황에 대해 다음과 같이 대응 방안을 제시합니다. 낙하물 및 여진에 대한 특별한 주의가 필요하며, 국민재난안전포털의 정보를 기반으로 대응하겠습니다.
#
# ---
#
# ### **[Graph RAG 결과 분석 및 활용]**
#
# 제공된 Graph RAG 검색 결과는 `p.name`과 `p.content` 모두 비어 있는(None) 상태로, 특정 지진, 낙하물, 여진 관련 정책 콘텐츠를 직접적으로 반환하지 않았습니다. 이는 현재 Graph RAG 데이터베이스 내에 해당 조건에 부합하는 정책 노드와 콘텐츠가 직접적으로 연결되어 있지 않거나, 검색 결과가 비어 있음을 의미합니다.
#
# 그러나 Cypher 쿼리(`MATCH (p:Policy)-[:GUIDES]->(h:Hazard) WHERE h.hazard_type = '지진' OR h.name CONTAINS '낙하물' OR h.name CONTAINS '여진'`)는 **지진(Hazard), 낙하물(Hazard), 여진(Hazard)**이라는 재난 유형 간의 연관성과, 이에 대한 정책(Policy)이 존재할 것이라는 구조적 가정을 보여줍니다. 따라서 Graph RAG 결과가 비어 있음에도 불구하고, 지진으로 인한 주요 2차 피해 및 연쇄 효과를 분석하고 이에 대한 대응 원칙을 수립하는 데 있어 Hazard 노드 및 관계의 개념을 활용할 것입니다.
#
# ---
#
# ### **[M6.3 지진 발생 시 재난 간 연쇄 관계 및 대응 방안]**
#
# 규모 6.3의 지진은 서울과 같은 인구 밀집 지역에서 발생할 경우, 광범위한 직접적인 피해와 더불어 다양한 연쇄 재난을 유발할 수 있습니다. 국민재난안전포털의 일반적인 지침과 제공된 Vector RAG 결과를 바탕으로 주요 연쇄 관계 및 대응 방안을 설명합니다.
#
# **1. 지진 → 낙하물 발생 및 건물 붕괴 위험 (직접적 연쇄)**
# *   **관계:** 지진은 건물 및 구조물의 흔들림을 유발하여 **낙하물**(`TRIGGERS` Hazard) 발생의 직접적인 원인이 되며, 심각할 경우 건물 붕괴(`CAUSES` Hazard)로 이어집니다.
# *   **대응:**
#     *   **지진 발생 즉시:** "DROP, COVER, HOLD ON" 원칙에 따라 몸을 낮추고, 튼튼한 탁자 아래 등으로 숨어 머리와 목을 보호하며, 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡습니다. 유리창, 가구 등 낙하물이 떨어질 수 있는 곳에서 멀리 떨어집니다.
#     *   **흔들림이 멈춘 후:** 주변을 살피고 안전이 확보된 후 대피합니다. 건물 밖으로 대피 시에는 떨어지는 간판, 유리창, 외벽 등에 특히 주의하며, 열린 공간으로 이동합니다.
#
# **2. 지진 → 여진 발생 (지속적 연쇄)**
# *   **관계:** 본 지진(`CAUSES` Hazard) 발생 후에는 크고 작은 **여진**(`TRIGGERS` Hazard)이 수일, 수주간 지속될 수 있으며, 이는 이미 약화된 구조물에 추가적인 피해를 주거나 심리적 불안감을 조성합니다.
# *   **대응:**
#     *   **대피 후:** 안전한 장소로 대피하더라도 여진에 대비하여 항상 주변 상황을 주시하고, 추가적인 흔들림 발생 시 즉각적으로 다시 "DROP, COVER, HOLD ON" 자세를 취할 준비를 합니다.
#     *   **피해 점검:** 거주지나 근무지로 돌아갈 때에는 전문가의 안전 점검 후 진입하며, 여진으로 인한 추가적인 피해 가능성을 염두에 둡니다.
#
# **3. 지진 → 정전 및 전력 부족 (2차 연쇄)**
# *   **관계:** 지진으로 인해 전력선, 변압기 등 전력 공급 시설이 파손되어 광범위한 **정전**(`TRIGGERS` Hazard)이 발생할 수 있습니다. 이는 통신 두절, 교통 마비, 냉난방 불가 등 추가적인 피해를 유발합니다.
# *   **근거:** **Vector RAG 문서 4 ("국민재난안전포털 정전 및 전력부족 국민행동요령 (2025)")**는 정전 발생 시의 대응 요령을 제시합니다.
# *   **대응:**
#     *   **정전 발생 시:** 침착하게 행동하며, 비상 랜턴이나 휴대용 손전등을 사용하여 어둠에 적응합니다. 휴대폰 충전량을 아껴두고, 필요한 경우 비상 발전기를 가동합니다. 엘리베이터 내부에 갇히지 않도록 주의하고, 만약 갇혔다면 비상벨을 누릅니다.
#     *   **비상 대비:** 평소 비상용품(손전등, 라디오, 건전지, 응급약품, 식수 등)을 미리 준비하여 정전 상황에 대비합니다.
#
# **4. 지진 → 가스 누출 및 폭발 사고 (2차 연쇄)**
# *   **관계:** 지진으로 인해 가스 배관이 파손될 경우 **가스 누출**(`CAUSES` Hazard)이 발생하고, 이는 작은 불씨나 스파크에도 **폭발 사고**(`TRIGGERS` Hazard)로 이어질 수 있어 매우 위험합니다.
# *   **근거:** **Vector RAG 문서 2 ("국민재난안전포털 폭발사고 국민행동요령 (2025)")**는 가스 누출 시 즉시 환기, 전기 스위치 사용 금지, 화기 사용 절대 금지 등의 조치를 강조합니다. 통계적으로 공동주택 및 단독주택에서의 폭발사고가 37%를 차지합니다.
# *   **대응:**
#     *   **가스 냄새 감지 시:** 즉시 창문과 출입문을 활짝 열어 환기시키고, 도시가스 밸브를 잠급니다. 절대 전기 스위치를 조작하거나 성냥, 라이터 등 화기를 사용해서는 안 됩니다.
#     *   **신고:** 안전한 곳으로 대피한 후 관리사무소 또는 가스회사에 신고합니다.
#
# **5. 지진 → 철도/지하철 및 도로 터널 사고 (교통 인프라 연쇄)**
# *   **관계:** 지진은 철도 선로, 지하철 터널, 도로 및 터널 구조물에 손상을 주어 **철도·지하철 사고**(`INCREASES_RISK_OF` Hazard)나 **도로 터널 사고**(`INCREASES_RISK_OF` Hazard) 발생 위험을 증가시키고, 대피를 어렵게 만들 수 있습니다.
# *   **근거:** **Vector RAG 문서 1 ("국민재난안전포털 철도·지하철 사고 국민행동요령 (2025)")**과 **Vector RAG 문서 3 ("국민재난안전포털 도로 터널사고 국민행동요령 (2025)")**은 폐쇄된 공간에서의 신속한 대피와 침착한 대응의 중요성을 강조합니다.
# *   **대응:**
#     *   **지하철/열차 내:** 승무원 및 안내방송에 따라 침착하게 행동하며, 비상 버튼이나 인터폰으로 상황을 알립니다. 화재 발생 시 소화기를 사용하고, 연기 흡입 방지를 위해 코와 입을 가립니다. 승무원의 지시에 따라 질서 있게 대피합니다.
#     *   **도로 터널 내:** 차량을 갓길이나 비상주차대에 정차하고 엔진을 끈 후 키를 꽂아둔 채 하차합니다. 휴대전화 또는 터널 내 긴급전화로 신고하고, 터널 입구 방향이나 비상구, 피난연결통로를 통해 안전한 곳으로 대피합니다.
#
# ### **[종합적인 대응 원칙]**
#
# 1.  **초기 행동:** 지진 발생 시 "DROP, COVER, HOLD ON" 원칙을 준수하고, 낙하물로부터 몸을 보호합니다.
# 2.  **안전 확보 및 대피:** 흔들림이 멈추면 여진에 대비하며 안전한 장소로 대피합니다. 대피 시에는 떨어지는 물건에 주의하고, 개방된 공간으로 이동합니다.
# 3.  **2차 재난 대비:** 정전, 가스 누출, 교통 인프라 마비 등 2차 재난에 대한 정보를 습득하고 각 상황에 맞는 국민행동요령에 따라 침착하게 대응합니다. 특히 가스 누출 시 환기 및 화기 사용 금지를 철저히 지킵니다.
# 4.  **정보 확인:** 국민재난안전포털(또는 기타 공신력 있는 매체)을 통해 재난 상황과 정부의 안내를 지속적으로 확인하고 따릅니다.
# 5.  **비상용품 준비:** 평소 비상식량, 식수, 응급약품, 손전등, 라디오 등을 포함한 비상 배낭을 준비하여 예기치 않은 상황에 대비합니다.
# 6.  **가족 및 이웃 확인:** 안전한 장소로 대피 후 가족 구성원의 안전을 확인하고, 주변의 도움이 필요한 이웃을 살핍니다.
#
# 이러한 지침은 M6.3 지진 발생 시 국민의 생명과 재산을 보호하고, 연쇄 재난으로부터 피해를 최소화하는 데 중요한 역할을 할 것입니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='UJIGaeC8POvE1e8PyJOpyQk' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2165,
#   prompt_token_count=2240,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2240
#     ),
#   ],
#   thoughts_token_count=1688,
#   total_token_count=6093
# ) automatic_function_calling_history=[] parsed=None
#
# 질의 2: 지진이 발생했을 때 가까운 대피소를 찾고 싶어요. 서초구 근처 대피소를 알려주세요.
#   - Graph RAG: 10개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""지진 발생 시 서초구 인근 대피소를 찾고 계시는군요. 가까운 대피소 정보를 안내해 드리겠습니다.
#
# Graph RAG 검색 결과에 따르면 서초구 내에는 다음과 같은 주요 대피소들이 있습니다.
#
# **서초구 주요 대피소:**
#
# *   **반포고등학교 운동장** (옥외대피소)
#     *   주소: 서울특별시 서초구 고무래로 71(반포동)
# *   **본마을공원** (실내대피소)
#     *   주소: 서울특별시 서초구 신원동 445
# *   **원명초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 고무래로 90-6 (서초동)
# *   **서초초등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 서운로 178(서초동)
# *   **서초중학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로13길 48(서초동)
# *   **서초고등학교 운동장** (실내대피소)
#     *   주소: 서울특별시 서초구 반포대로27길 29(서초동)
#
# 제공된 검색 결과에서는 서초구 내 총 6개의 대피소를 확인할 수 있었습니다. 지진 발생 시에는 주변 안전을 확보한 후 가장 가까운 대피소로 이동하시는 것이 중요합니다. 실제 대피소의 위치는 '국민재난안전포털' 앱이나 웹사이트에서 실시간으로 확인할 수 있으니, 평소에 미리 확인해 두시는 것을 권장합니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='WpIGabPaDJqV1e8P9P-T2A0' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=402,
#   prompt_token_count=2638,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2638
#     ),
#   ],
#   thoughts_token_count=586,
#   total_token_count=3626
# ) automatic_function_calling_history=[] parsed=None
#
# 질의 3: 지진 발생 시 어떻게 행동해야 하나요?
#   - Graph RAG: 5개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""재난대응 전문가로서 지진 발생 시 행동 요령에 대해 말씀드리겠습니다.
#
# 제공된 Graph RAG 및 Vector RAG 검색 결과에서는 지진 발생 시의 구체적인 행동 지침이 직접적으로 확인되지 않았습니다. 다만, 재난대응 전문가의 관점에서 국민들이 반드시 알아야 할 지진 발생 시 행동 요령은 다음과 같습니다.
#
# ---
#
# **지진 발생 시 행동 요령**
#
# 지진 발생 시에는 침착하게 다음 3단계 원칙에 따라 행동하는 것이 중요합니다.
#
# 1.  **"DROP, COVER, HOLD ON" (몸을 낮추고, 숨고, 잡기)**
#     *   **몸을 낮추기 (DROP):** 지진을 느끼면 즉시 바닥에 엎드려 몸의 중심을 낮춥니다.
#     *   **숨기 (COVER):** 탁자나 책상 등 견고한 가구 아래로 들어가 머리와 목을 보호합니다. 주변에 숨을 곳이 없다면 방석 등으로 머리를 가리고 벽 모서리나 기둥 옆에 웅크립니다.
#     *   **꽉 잡기 (HOLD ON):** 흔들림이 멈출 때까지 탁자 다리 등을 꽉 잡고 몸을 보호합니다.
#
# 2.  **안전 확보 및 대피 준비**
#     *   **실내인 경우:** 창문, 거울, 높은 가구 등 떨어지거나 넘어질 수 있는 물건에서 멀리 떨어집니다. 흔들림이 멈추면 가스 밸브와 전기 스위치를 잠그고 출구를 확보한 후 안전하게 대피할 준비를 합니다. 신발은 반드시 착용하여 발을 보호합니다.
#     *   **실외인 경우:** 건물, 담벼락, 전신주, 가로등 등 낙하 또는 붕괴 위험이 있는 곳에서 멀리 떨어진 넓은 공간으로 이동합니다.
#     *   **차량 운전 중인 경우:** 서서히 속도를 줄여 도로 우측에 차를 세우고 비상등을 켭니다. 라디오를 통해 재난 방송을 청취하고, 차 안에 머무르거나 주변이 안전하다고 판단되면 차 키를 꽂아둔 채 대피합니다.
#
# 3.  **지진 후 행동**
#     *   **안전한 곳으로 대피:** 흔들림이 멈춘 후, 엘리베이터는 절대 사용하지 않고 계단을 이용하여 외부의 안전한 넓은 공간(운동장, 공원 등)으로 대피합니다.
#     *   **정보 확인 및 구조 요청:** 스마트폰, 라디오 등으로 재난 방송을 청취하여 상황을 파악하고, 부상자가 있거나 위험 상황 발생 시 119 또는 112에 신고합니다.
#     *   **여진 대비:** 여진이 발생할 수 있으므로, 재난 방송 및 관계 기관의 안내에 따라 행동하며 안전에 유의합니다.
#
# 가장 중요한 것은 당황하지 않고 침착하게 위의 행동 요령을 따르는 것입니다. 평소 가족 및 직장 동료와 비상연락망 및 대피 계획을 세워두는 것도 큰 도움이 됩니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='aZIGaZWgBMnE1e8Pyb7E2Q4' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=691,
#   prompt_token_count=2151,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2151
#     ),
#   ],
#   thoughts_token_count=1127,
#   total_token_count=3969
# ) automatic_function_calling_history=[] parsed=None
#
# 질의 4: 노후 시설물이 붕괴 위험을 증가시킬 수 있나요?
#   - Graph RAG: 1개 결과
#   - Vector RAG: 5개 결과
#   - 최종 답변: ✓ 생성됨
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""네, 노후 시설물은 붕괴 위험을 증가시킬 수 있습니다. 이는 재난 대응 관점에서 매우 중요한 요소로 인식되고 있으며, 시설물의 노화는 심각한 사회 재난으로 이어질 수 있는 직접적인 원인 중 하나입니다.
#
# **구체적인 근거 및 재난 간 연쇄 관계 설명:**
#
# 1.  **Graph RAG 검색 결과 활용:**
#     *   제시된 Graph RAG 검색 결과에 따르면, 명확하게 **'노화' (hazard_type: 노화)**가 **'붕괴' (hazard_type: 붕괴)**의 위험을 **'INCREASES_RISK_OF' (위험 증가)**하는 관계가 확인되었습니다.
#     *   이는 시스템적으로 노화된 시설물이 붕괴 재난으로 이어질 가능성을 높인다는 것을 의미하며, 재난 발생의 직접적인 연쇄 고리 중 하나입니다. 시설물의 노후화는 구조적 안정성을 저해하고, 작은 외부 충격이나 자연 현상에도 취약하게 만들어 최종적으로 붕괴에 이르게 할 수 있습니다.
#
# 2.  **재난 발생의 연쇄 관계:**
#     *   **노화 -> 구조적 결함 증가:** 시설물이 오랜 시간 사용되면서 재료의 피로 누적, 부식, 균열, 침하, 지지력 약화 등 다양한 형태의 노후화가 진행됩니다. 이러한 현상은 시설물의 구조적 안정성을 점진적으로 약화시킵니다.
#     *   **구조적 결함 증가 -> 붕괴 위험 증대:** 약화된 구조는 지진, 태풍, 폭설과 같은 자연재해는 물론, 과도한 하중, 인근 공사로 인한 진동, 유지보수 부족 등 예상치 못한 외부 요인에 더욱 취약해집니다. 이로 인해 시설물이 본래 견딜 수 있는 한계를 초과하게 되면, 부분적인 손상을 넘어 갑작스러운 전체 붕괴로 이어질 위험이 크게 증가합니다.
#     *   **붕괴 -> 인명 피해 및 재산 손실:** 시설물 붕괴는 대규모 인명 피해와 심각한 재산 손실을 초래하며, 사회 기반 시설 마비, 2차 재해 발생(가스 폭발, 전기 화재 등) 등 광범위한 사회경제적 영향을 미칠 수 있습니다.
#
# **결론적으로,** 노후 시설물은 단순한 불편함을 넘어 국민의 생명과 안전을 위협하는 심각한 붕괴 위험을 내포하고 있습니다. 따라서 노후 시설물에 대한 정기적인 안전 점검, 유지보수 및 보강, 그리고 필요한 경우 재건축 등을 통해 이러한 위험을 사전에 예방하고 관리하는 것이 재난 대응 전문가로서 매우 중요합니다.
#
# **[참고: Vector RAG 결과에 대한 평가]**
# Vector RAG 검색 결과는 주로 '비상시 국민행동요령', '철도·지하철 사고', '정전 및 전력부족', '사회재난 행동요령(화재)' 등 특정 재난 상황 발생 시의 행동 지침이나 대응 방법에 대한 정보를 제공하고 있습니다. 이 문서들은 노후 시설물의 붕괴 위험 증가라는 질문에 대한 직접적인 정보나 근거를 포함하고 있지는 않습니다. 따라서 본 답변은 Graph RAG 검색 결과의 명확한 관계에 중점을 두어 구성되었습니다."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='gJIGaZr3Eta6vr0PhqvH8AQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=734,
#   prompt_token_count=2067,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2067
#     ),
#   ],
#   thoughts_token_count=1354,
#   total_token_count=4155
# ) automatic_function_calling_history=[] parsed=None

# %%
# Neo4j 연결 종료
neo4j_driver.close()
print("✓ Neo4j 연결 종료")
# Out:
# ✓ Neo4j 연결 종료
